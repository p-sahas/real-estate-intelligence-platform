# %% [markdown]
# ### Setup & Installations

# %%
import sys
# if "google.colab" in sys.modules or True:
#     print(" Installing required packages...")
#     %pip install -q playwright>=1.40.0 python-dotenv>=1.0.0 beautifulsoup4>=4.12.0 markdownify>=0.11.6 nest-asyncio>=1.5.0
    
#     # Install Playwright browsers
#     print(" Installing Playwright browsers...")
#     import subprocess
#     subprocess.run([sys.executable, "-m", "playwright", "install", "chromium"], check=True, capture_output=True)

# print(" Packages ready")

# %% [markdown]
# ### Imports & Environment Setup

# %%
import os
import sys
import json
import time
from pathlib import Path
from urllib.parse import urlparse
from dotenv import load_dotenv
import nest_asyncio

# Enable nested asyncio
nest_asyncio.apply()

# Add project root to path
project_root = Path.cwd().parent
sys.path.insert(0, str(project_root / "src"))

# Load environment
load_dotenv(project_root / ".env")

# Check for API key (OpenRouter preferred, OpenAI as fallback)
openrouter_key = os.getenv("OPENROUTER_API_KEY")
groq_key = os.getenv("GROQ_API_KEY")

if not openrouter_key and not groq_key:
    raise EnvironmentError(
        " No API key found!\n"
        " Add OPENROUTER_API_KEY (recommended) or GROQ_API_KEY to .env"
    )

provider = "OpenRouter" if openrouter_key else "OpenAI"
print(" Environment loaded")
print(f" Provider: {provider}")
print(f" Project root: {project_root}")
# Out:
#  Environment loaded
#  Provider: OpenRouter
#  Project root: c:\Development\real-estate-intelligence-platform

# %% [markdown]
# ### Load Configuration

# %%
from context_engineering.config import (
    validate, dump, CRAWL_OUT_DIR, MARKDOWN_DIR
)

# Validate and display config
try:
    validate()
    dump()
except Exception as e:
    print(f"  Config note: {e}")

# Ensure directories exist
MARKDOWN_DIR.mkdir(parents=True, exist_ok=True)

print(f"\n Output directories ready:")
print(f"   - Markdown: {MARKDOWN_DIR}")
print(f"   - JSONL: {CRAWL_OUT_DIR}")
# Out:
# ============================================================
# CONFIGURATION (NON-SECRETS ONLY)
# ============================================================
#
#  Provider:
#    Provider: openrouter
#    Model Tier: general
#    Chat Model: openai/gpt-4o-mini
#    Embedding Model: openai/text-embedding-3-large
#
#  Directories:
#    Data Root: c:\Development\real-estate-intelligence-platform\data
#    Vector Store: c:\Development\real-estate-intelligence-platform\data\vectorstore
#    Markdown: c:\Development\real-estate-intelligence-platform\data\primelands_markdown
#    Cache: c:\Development\real-estate-intelligence-platform\data\cag_cache
#
#  Chunking:
#    Fixed Size: 800 tokens
#    Fixed Overlap: 100 tokens
#    Sliding Window: 512 tokens
#    Sliding Stride: 256 tokens
#    Parent-Child: 250 → 1200 tokens
#    Late Chunk: 1000 → 300 tokens
#
#  Retrieval:
#    Top-K Results: 4
#    Similarity Threshold: 0.7
#
#  CAG:
#    Cache TTL: 86400s
#    Max Cache Size: 1000
#
#  CRAG:
#    Confidence Threshold: 0.6
#    Expanded K: 8
#
# ============================================================
#
#
#  Output directories ready:
#    - Markdown: c:\Development\real-estate-intelligence-platform\data\primelands_markdown
#    - JSONL: c:\Development\real-estate-intelligence-platform\data

# %%
# Crawl Configuration
BASE_URL = "https://www.primelands.lk"

START_PATHS = [
    "/", "/portfolio-property", "/land", "/house",
    "/apartment/ongoing", "/upcoming-projects", "/about-us", "sell-your-land",
    "/contact-us", "/services", "/testimonial",
    "/careers", "/news",
    "/online-publications", "/blog", "/virtual-tour", "/kyc", "/terms-and-conditions"
    "/privacy-policy"
]

START_URLS = [BASE_URL + path for path in START_PATHS]

EXCLUDE_PATTERNS = [
    "/login", "/terms", "/privacy", "/admin",
    "/images/", "/downloads/", "/media/", "/sin" , "/tam", "/uploads/", "/downloads/", "/pdf/",
    ".webp", ".mp4", ".jpg", ".jpeg", ".png", ".css", ".js"
]

MAX_DEPTH = 3
REQUEST_DELAY = 2.0
JSONL_PATH = CRAWL_OUT_DIR / "primelands_docs.jsonl"

print(f" Crawl config:")
print(f"   - Start URLs: {len(START_URLS)}")
print(f"   - Max depth: {MAX_DEPTH}")
print(f"   - Request delay: {REQUEST_DELAY}s")
# Out:
#  Crawl config:
#    - Start URLs: 18
#    - Max depth: 3
#    - Request delay: 2.0s

# %% [markdown]
# ### Import Crawler Service
#
# Using `PrimeLandCrawler` from application layer

# %%
# Import Web Crawler Service
from context_engineering.application.ingest_documents_service import PrimeLandWebCrawler

print(" PrimeLandWebCrawler loaded from service layer")
print(" Location: context_engineering.application.ingest_documents_service.web_crawler")
# Out:
#  PrimeLandWebCrawler loaded from service layer
#  Location: context_engineering.application.ingest_documents_service.web_crawler

# %%
# Run Crawl with Service
import asyncio
from concurrent.futures import ThreadPoolExecutor

start_time = time.time()

# Initialize crawler service
crawler = PrimeLandWebCrawler(
    base_url=BASE_URL,
    max_depth=MAX_DEPTH,
    exclude_patterns=EXCLUDE_PATTERNS
)

def run_crawler_thread():
    # 1. Set Proactor policy (required for Playwright on Windows)
    asyncio.set_event_loop_policy(asyncio.WindowsProactorEventLoopPolicy())
    
    # 2. Create a new event loop for this thread
    loop = asyncio.new_event_loop()
    asyncio.set_event_loop(loop)
    
    try:
        # 3. Process the async crawl directly on this loop
        return loop.run_until_complete(crawler.crawl_async(START_URLS, request_delay=REQUEST_DELAY))
    finally:
        loop.close()

print(f"\n Starting crawl at {time.strftime('%H:%M:%S')}\n")

# Run in a separate thread to avoid conflict with Jupyter's running loop
with ThreadPoolExecutor(max_workers=1) as executor:
    future = executor.submit(run_crawler_thread)
    documents = future.result()

elapsed = time.time() - start_time
print(f"\n Crawl complete in {elapsed:.1f}s")
print(f" Documents collected: {len(documents)}")
print(f" URLs visited: {len(crawler.visited)}")
# Out:
#  Starting crawl at 22:20:38
#
#  [0] https://www.primelands.lk/
#     Saved (554 chars, 45 links found)
#     Added 45 new URLs to queue (depth 1)
#    Progress: 1 docs saved, 1 visited, 62 in queue
#  [0] https://www.primelands.lk/portfolio-property
#     Saved (124 chars, 0 links found)
#    Progress: 2 docs saved, 2 visited, 61 in queue
#  [0] https://www.primelands.lk/land
#     Saved (564 chars, 70 links found)
#     Added 56 new URLs to queue (depth 1)
#    Progress: 3 docs saved, 3 visited, 116 in queue
#  [0] https://www.primelands.lk/house
#     Saved (566 chars, 30 links found)
#     Added 16 new URLs to queue (depth 1)
#    Progress: 4 docs saved, 4 visited, 131 in queue
#  [0] https://www.primelands.lk/apartment/ongoing
#     Saved (124 chars, 0 links found)
#    Progress: 5 docs saved, 5 visited, 130 in queue
#  [0] https://www.primelands.lk/upcoming-projects
#     Saved (124 chars, 0 links found)
#    Progress: 6 docs saved, 6 visited, 129 in queue
#  [0] https://www.primelands.lk/about-us
#     Saved (124 chars, 0 links found)
#    Progress: 7 docs saved, 7 visited, 128 in queue
#  [0] https://www.primelands.lksell-your-land
#      Page not found (404) - skipping
#  [0] https://www.primelands.lk/contact-us
#     Error: Page.goto: Navigation to "https://www.primelands.lk/contact-us" is interrupted by another navigation
#  [0] https://www.primelands.lk/services
#     Error: Page.goto: Navigation to "https://www.primelands.lk/services" is interrupted by another navigation t
#  [0] https://www.primelands.lk/testimonial
#     Saved (124 chars, 0 links found)
#    Progress: 8 docs saved, 11 visited, 124 in queue
#  [0] https://www.primelands.lk/careers
#     Saved (124 chars, 0 links found)
#    Progress: 9 docs saved, 12 visited, 123 in queue
#  [0] https://www.primelands.lk/news
#     Saved (124 chars, 0 links found)
#    Progress: 10 docs saved, 13 visited, 122 in queue
#  [0] https://www.primelands.lk/online-publications
#     Saved (124 chars, 0 links found)
#    Progress: 11 docs saved, 14 visited, 121 in queue
#  [0] https://www.primelands.lk/blog
#     Saved (124 chars, 0 links found)
#    Progress: 12 docs saved, 15 visited, 120 in queue
#  [0] https://www.primelands.lk/virtual-tour
#     Saved (124 chars, 0 links found)
#    Progress: 13 docs saved, 16 visited, 119 in queue
#  [0] https://www.primelands.lk/kyc
#     Saved (124 chars, 0 links found)
#    Progress: 14 docs saved, 17 visited, 118 in queue
#  [1] https://www.primelands.lk/land/ADORA-NAIWALA/en
#     Saved (592 chars, 13 links found)
#     Added 7 new URLs to queue (depth 2)
#    Progress: 15 docs saved, 18 visited, 123 in queue
#  [1] https://www.primelands.lk/house/THE-RESIDENCE-SAMAGI-MAWATHA-THALAWATHUGODA/en
#     Saved (654 chars, 12 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 16 docs saved, 19 visited, 125 in queue
#  [1] https://www.primelands.lk/house/THALAWATHUGODA-CLOVER/en
#     Saved (610 chars, 14 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 17 docs saved, 20 visited, 126 in queue
#  [1] https://www.primelands.lk/apartment/THE-REFLECTION-SAMAGI-MAWATHA-THALAWATHUGODA/en
#     Saved (664 chars, 12 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 18 docs saved, 21 visited, 127 in queue
#  [1] https://www.primelands.lk/contact-us/en
#     Saved (576 chars, 7 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 19 docs saved, 22 visited, 128 in queue
#  [1] https://www.primelands.lk/portfolio-property/ALUTHGAMA-WELIPENNA/en
#     Saved (632 chars, 11 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 20 docs saved, 23 visited, 129 in queue
#  [1] https://www.primelands.lk/land/LUXORA-KIRIBATHGODA/en
#     Saved (604 chars, 13 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 21 docs saved, 24 visited, 130 in queue
#  [1] https://www.primelands.lk/house/VIVA-LA-VIDA-KOTTAWA/en
#     Saved (608 chars, 14 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 22 docs saved, 25 visited, 131 in queue
#  [1] https://www.primelands.lk/portfolio-property/ELLA-NUWARA-ELIYA/en
#     Saved (628 chars, 11 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 23 docs saved, 26 visited, 132 in queue
#  [1] https://www.primelands.lk/house/en
#     Saved (566 chars, 29 links found)
#    Progress: 24 docs saved, 27 visited, 131 in queue
#  [1] https://www.primelands.lk/portfolio-property/en
#     Saved (592 chars, 46 links found)
#     Added 35 new URLs to queue (depth 2)
#    Progress: 25 docs saved, 28 visited, 165 in queue
#  [1] https://www.primelands.lk/apartment/MON-VIE-COLOMBO-05/en
#     Saved (612 chars, 11 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 26 docs saved, 29 visited, 167 in queue
#  [1] https://www.primelands.lk/news/98/Prime-Group-Expands-Its-Footprint-to-Elevate-Customer-Experience-and-Reinforce-Its-Commitment-to-Excellence-with-the-Launch-of-the-Kalutara-Branch/en
#     Saved (864 chars, 19 links found)
#     Added 8 new URLs to queue (depth 2)
#    Progress: 27 docs saved, 30 visited, 174 in queue
#  [1] https://www.primelands.lk/apartment/SKYE-BLOSSOM-KOTTAWA/en
#     Saved (616 chars, 11 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 28 docs saved, 31 visited, 175 in queue
#  [1] https://www.primelands.lk/portfolio-property/WARIYAPOLA-KURUNEGALA/en
#     Saved (636 chars, 11 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 29 docs saved, 32 visited, 176 in queue
#  [1] https://www.primelands.lk/sin
#     Saved (561 chars, 44 links found)
#     Added 26 new URLs to queue (depth 2)
#    Progress: 30 docs saved, 33 visited, 201 in queue
#  [1] https://www.primelands.lk/tam
#     Saved (580 chars, 44 links found)
#     Added 26 new URLs to queue (depth 2)
#    Progress: 31 docs saved, 34 visited, 226 in queue
#  [1] https://www.primelands.lk/about-us/en
#     Saved (572 chars, 30 links found)
#     Added 21 new URLs to queue (depth 2)
#    Progress: 32 docs saved, 35 visited, 246 in queue
#  [1] https://www.primelands.lk/news/97/Prime-Group-Stands-with-the-Children-of-Police-Families-Affected-by-Cyclone-Ditwah/en
#     Saved (736 chars, 18 links found)
#    Progress: 33 docs saved, 36 visited, 245 in queue
#  [1] https://www.primelands.lk/house/DALUGAMA-PRIME-VILLAS/en
#     Saved (610 chars, 12 links found)
#    Progress: 34 docs saved, 37 visited, 244 in queue
#  [1] https://www.primelands.lk/apartment/en
#     Saved (590 chars, 26 links found)
#     Added 13 new URLs to queue (depth 2)
#    Progress: 35 docs saved, 38 visited, 256 in queue
#  [1] https://www.primelands.lk/land/en
#     Saved (564 chars, 69 links found)
#    Progress: 36 docs saved, 39 visited, 255 in queue
#  [1] https://www.primelands.lk/house/DIGANA-SCOTTISH-ISLAND/en
#     Saved (612 chars, 12 links found)
#    Progress: 37 docs saved, 40 visited, 254 in queue
#  [1] https://www.primelands.lk/land/LUXE-THALAHENA/en
#     Saved (594 chars, 12 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 38 docs saved, 41 visited, 256 in queue
#  [1] https://www.primelands.lk/land/GREEN-CREST-HORANA/en
#     Saved (602 chars, 11 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 39 docs saved, 42 visited, 257 in queue
#  [1] https://www.primelands.lk/house/KAHATHUDUWA-88-RESIDENCE/en
#     Saved (616 chars, 13 links found)
#    Progress: 40 docs saved, 43 visited, 256 in queue
#  [1] https://www.primelands.lk/portfolio-property/MATARA-WELIGAMA/en
#     Saved (624 chars, 11 links found)
#    Progress: 41 docs saved, 44 visited, 255 in queue
#  [1] https://www.primelands.lk/portfolio-property/GALLE-HAPUGALA/en
#     Saved (622 chars, 11 links found)
#    Progress: 42 docs saved, 45 visited, 254 in queue
#  [1] https://www.primelands.lk/land/EVARA-NAWALAPITIYA/en
#     Saved (602 chars, 13 links found)
#     Added 5 new URLs to queue (depth 2)
#    Progress: 43 docs saved, 46 visited, 258 in queue
#  [1] https://www.primelands.lk/en
#     Saved (554 chars, 44 links found)
#    Progress: 44 docs saved, 47 visited, 257 in queue
#  [1] https://www.primelands.lk/land/AURELIA-ALUBOMULLA/en
#     Saved (602 chars, 14 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 45 docs saved, 48 visited, 260 in queue
#  [1] https://www.primelands.lk/news/en
#     Saved (564 chars, 15 links found)
#    Progress: 46 docs saved, 49 visited, 259 in queue
#  [1] https://www.primelands.lk/apartment/THE-GOLF-COLOMBO-08/en
#     Saved (614 chars, 11 links found)
#    Progress: 47 docs saved, 50 visited, 258 in queue
#  [1] https://www.primelands.lk/apartment/THE-SEASONS-COLOMBO-08/en
#     Saved (620 chars, 10 links found)
#    Progress: 48 docs saved, 51 visited, 257 in queue
#  [1] https://www.primelands.lk/news/99/Prime-Melwa-Acquire-4-Acres-of-Premium-Waterfront-Land-in-Port-City-Colombo-for-USD-576Mn/en
#     Saved (750 chars, 18 links found)
#    Progress: 49 docs saved, 52 visited, 256 in queue
#  [1] https://www.primelands.lk/land/ELITE-AVENUE-KAHATHUDUWA/en
#     Saved (614 chars, 11 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 50 docs saved, 53 visited, 257 in queue
#  [1] https://www.primelands.lk/news/94/Prime-Group-builds-nations-most-connected-property-experience-with-firstofitskind-technology-ecosystem/en
#     Saved (776 chars, 18 links found)
#    Progress: 51 docs saved, 54 visited, 256 in queue
#  [1] https://www.primelands.lk/land/LUXCORE-CITY-MALABE/en
#     Saved (604 chars, 14 links found)
#     Added 6 new URLs to queue (depth 2)
#    Progress: 52 docs saved, 55 visited, 261 in queue
#  [1] https://www.primelands.lk/house/GAMPAHA-ELEMINT-SUITES/en
#     Saved (612 chars, 12 links found)
#    Progress: 53 docs saved, 56 visited, 260 in queue
#  [1] https://www.primelands.lk/apartment/YOLO-KIRIBATHGODA/en
#     Saved (610 chars, 11 links found)
#    Progress: 54 docs saved, 57 visited, 259 in queue
#  [1] https://www.primelands.lk/house/CEST-LA-VIE-THALAWATHUGODA/en
#     Saved (620 chars, 14 links found)
#    Progress: 55 docs saved, 58 visited, 258 in queue
#  [1] https://www.primelands.lk/portfolio-property/KALUTARA-NAGODA/en
#     Saved (624 chars, 11 links found)
#    Progress: 56 docs saved, 59 visited, 257 in queue
#  [1] https://www.primelands.lk/apartment/J-ADORE-NEGOMBO/en
#     Saved (606 chars, 11 links found)
#    Progress: 57 docs saved, 60 visited, 256 in queue
#  [1] https://www.primelands.lk/apartment/VENEZIA-NEGOMBO/en
#     Saved (606 chars, 11 links found)
#    Progress: 58 docs saved, 61 visited, 255 in queue
#  [1] https://www.primelands.lk/news/93/Prime-Group-makes-history-with-Sri-Lankas-first-luxury-real-estate-client-experience-initiative-Prime-Premier/en
#     Saved (790 chars, 18 links found)
#    Progress: 59 docs saved, 62 visited, 254 in queue
#  [1] https://www.primelands.lk/up-country-lands/en
#     Saved (588 chars, 74 links found)
#     Added 5 new URLs to queue (depth 2)
#    Progress: 60 docs saved, 63 visited, 258 in queue
#  [1] https://www.primelands.lk/coconut-land/en
#     Saved (580 chars, 72 links found)
#     Added 5 new URLs to queue (depth 2)
#    Progress: 61 docs saved, 64 visited, 262 in queue
#  [1] https://www.primelands.lk/close-to-Airport/en
#     Saved (588 chars, 74 links found)
#     Added 7 new URLs to queue (depth 2)
#    Progress: 62 docs saved, 65 visited, 268 in queue
#  [1] https://www.primelands.lk/land/district/Ratnapura/en
#     Saved (602 chars, 74 links found)
#     Added 8 new URLs to queue (depth 2)
#    Progress: 63 docs saved, 66 visited, 275 in queue
#  [1] https://www.primelands.lk/land/district/Kurunegala/en
#     Saved (604 chars, 74 links found)
#     Added 6 new URLs to queue (depth 2)
#    Progress: 64 docs saved, 67 visited, 280 in queue
#  [1] https://www.primelands.lk/close-to-ancient-city-lands/en
#     Saved (610 chars, 73 links found)
#     Added 7 new URLs to queue (depth 2)
#    Progress: 65 docs saved, 68 visited, 286 in queue
#  [1] https://www.primelands.lk/agriculture-land/en
#     Saved (588 chars, 73 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 66 docs saved, 69 visited, 287 in queue
#  [1] https://www.primelands.lk/land/district/Gampaha/en
#     Saved (598 chars, 72 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 67 docs saved, 70 visited, 289 in queue
#  [1] https://www.primelands.lk/land/GREATE-10-GALLE/en
#     Saved (596 chars, 12 links found)
#     Added 6 new URLs to queue (depth 2)
#    Progress: 68 docs saved, 71 visited, 294 in queue
#  [1] https://www.primelands.lk/waterfront-land/en
#     Saved (586 chars, 74 links found)
#     Added 8 new URLs to queue (depth 2)
#    Progress: 69 docs saved, 72 visited, 301 in queue
#  [1] https://www.primelands.lk/land/district/Kalutara/en
#     Saved (600 chars, 71 links found)
#     Added 5 new URLs to queue (depth 2)
#    Progress: 70 docs saved, 73 visited, 305 in queue
#  [1] https://www.primelands.lk/land/city/Malabe/en
#     Saved (588 chars, 73 links found)
#     Added 7 new URLs to queue (depth 2)
#    Progress: 71 docs saved, 74 visited, 311 in queue
#  [1] https://www.primelands.lk/land/city/Kadawatha/en
#     Saved (594 chars, 74 links found)
#     Added 5 new URLs to queue (depth 2)
#    Progress: 72 docs saved, 75 visited, 315 in queue
#  [1] https://www.primelands.lk/land/city/Panadura/en
#     Saved (592 chars, 72 links found)
#     Added 5 new URLs to queue (depth 2)
#    Progress: 73 docs saved, 76 visited, 319 in queue
#  [1] https://www.primelands.lk/land/NEXUS-TOWN-ALUTHGAMA/en
#     Saved (606 chars, 14 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 74 docs saved, 77 visited, 321 in queue
#  [1] https://www.primelands.lk/land/city/Bandaragama/en
#     Saved (598 chars, 71 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 75 docs saved, 78 visited, 324 in queue
#  [1] https://www.primelands.lk/down-south-lands/en
#     Saved (588 chars, 73 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 76 docs saved, 79 visited, 326 in queue
#  [1] https://www.primelands.lk/land/city/Kalutara/en
#     Saved (592 chars, 74 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 77 docs saved, 80 visited, 328 in queue
#  [1] https://www.primelands.lk/land/city/Kottawa/en
#     Saved (590 chars, 73 links found)
#     Added 7 new URLs to queue (depth 2)
#    Progress: 78 docs saved, 81 visited, 334 in queue
#  [1] https://www.primelands.lk/paddy-field-facing-lands/en
#     Saved (604 chars, 74 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 79 docs saved, 82 visited, 337 in queue
#  [1] https://www.primelands.lk/land/tam
#     Saved (590 chars, 69 links found)
#     Added 35 new URLs to queue (depth 2)
#    Progress: 80 docs saved, 83 visited, 371 in queue
#  [1] https://www.primelands.lk/land/city/Anuradhapura/en
#     Saved (600 chars, 74 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 81 docs saved, 84 visited, 374 in queue
#  [1] https://www.primelands.lk/land/district/Kandy/en
#     Saved (594 chars, 73 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 82 docs saved, 85 visited, 375 in queue
#  [1] https://www.primelands.lk/land/DENVER-KAHATHUDUWA/en
#     Saved (602 chars, 12 links found)
#     Added 1 new URLs to queue (depth 2)
#    Progress: 83 docs saved, 86 visited, 375 in queue
#  [1] https://www.primelands.lk/land/district/Kegalle/en
#     Saved (598 chars, 69 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 84 docs saved, 87 visited, 376 in queue
#  [1] https://www.primelands.lk/land/sin
#     Saved (571 chars, 69 links found)
#     Added 31 new URLs to queue (depth 2)
#    Progress: 85 docs saved, 88 visited, 406 in queue
#  [1] https://www.primelands.lk/mountain-view/en
#     Saved (582 chars, 73 links found)
#    Progress: 86 docs saved, 89 visited, 405 in queue
#  [1] https://www.primelands.lk/land/city/Homagama/en
#     Saved (592 chars, 74 links found)
#    Progress: 87 docs saved, 90 visited, 404 in queue
#  [1] https://www.primelands.lk/land/district/Matara/en
#     Saved (596 chars, 74 links found)
#     Added 5 new URLs to queue (depth 2)
#    Progress: 88 docs saved, 91 visited, 408 in queue
#  [1] https://www.primelands.lk/land/city/Nittambuwa/en
#     Saved (596 chars, 71 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 89 docs saved, 92 visited, 411 in queue
#  [1] https://www.primelands.lk/residential/en
#     Saved (578 chars, 69 links found)
#    Progress: 90 docs saved, 93 visited, 410 in queue
#  [1] https://www.primelands.lk/land/district/Galle/en
#     Saved (594 chars, 74 links found)
#    Progress: 91 docs saved, 94 visited, 409 in queue
#  [1] https://www.primelands.lk/close-to-highways/en
#     Saved (590 chars, 68 links found)
#    Progress: 92 docs saved, 95 visited, 408 in queue
#  [1] https://www.primelands.lk/land/district/Anuradhapura/en
#     Saved (608 chars, 74 links found)
#     Added 1 new URLs to queue (depth 2)
#    Progress: 93 docs saved, 96 visited, 408 in queue
#  [1] https://www.primelands.lk/land/city/Veyangoda/en
#     Saved (594 chars, 73 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 94 docs saved, 97 visited, 411 in queue
#  [1] https://www.primelands.lk/close-to-railway-stations/en
#     Saved (606 chars, 74 links found)
#     Added 1 new URLs to queue (depth 2)
#    Progress: 95 docs saved, 98 visited, 411 in queue
#  [1] https://www.primelands.lk/land/city/Athurugiriya/en
#     Saved (600 chars, 72 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 96 docs saved, 99 visited, 414 in queue
#  [1] https://www.primelands.lk/land/district/Hambantota/en
#     Saved (604 chars, 70 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 97 docs saved, 100 visited, 415 in queue
#  [1] https://www.primelands.lk/land/city/Horana/en
#     Saved (588 chars, 73 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 98 docs saved, 101 visited, 418 in queue
#  [1] https://www.primelands.lk/land/city/Negombo/en
#     Saved (590 chars, 73 links found)
#     Added 5 new URLs to queue (depth 2)
#    Progress: 99 docs saved, 102 visited, 422 in queue
#  [1] https://www.primelands.lk/land/district/Colombo/en
#     Saved (598 chars, 70 links found)
#    Progress: 100 docs saved, 103 visited, 421 in queue
#  [1] https://www.primelands.lk/commercial/en
#     Saved (576 chars, 74 links found)
#     Added 1 new URLs to queue (depth 2)
#    Progress: 101 docs saved, 104 visited, 421 in queue
#  [1] https://www.primelands.lk/land/district/Nuwara-Eliya/en
#     Saved (608 chars, 74 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 102 docs saved, 105 visited, 423 in queue
#  [1] https://www.primelands.lk/land/city/Kahathuduwa/en
#     Saved (598 chars, 71 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 103 docs saved, 106 visited, 424 in queue
#  [1] https://www.primelands.lk/land/city/Kiribathgoda/en
#     Saved (600 chars, 72 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 104 docs saved, 107 visited, 427 in queue
#  [1] https://www.primelands.lk/land/city/Matara/en
#     Saved (588 chars, 72 links found)
#    Progress: 105 docs saved, 108 visited, 426 in queue
#  [1] https://www.primelands.lk/land/district/Matale/en
#     Saved (596 chars, 71 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 106 docs saved, 109 visited, 428 in queue
#  [1] https://www.primelands.lk/land/city/Kurunegala/en
#     Saved (596 chars, 74 links found)
#     Added 5 new URLs to queue (depth 2)
#    Progress: 107 docs saved, 110 visited, 432 in queue
#  [1] https://www.primelands.lk/land/city/Kandy/en
#     Saved (586 chars, 73 links found)
#     Added 1 new URLs to queue (depth 2)
#    Progress: 108 docs saved, 111 visited, 432 in queue
#  [1] https://www.primelands.lk/land/city/Embilipitiya/en
#     Saved (600 chars, 73 links found)
#    Progress: 109 docs saved, 112 visited, 431 in queue
#  [1] https://www.primelands.lk/land/city/Artigala/en
#     Saved (592 chars, 73 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 110 docs saved, 113 visited, 434 in queue
#  [1] https://www.primelands.lk/land/city/Moratuwa/en
#     Saved (592 chars, 72 links found)
#     Added 1 new URLs to queue (depth 2)
#    Progress: 111 docs saved, 114 visited, 434 in queue
#  [1] https://www.primelands.lk/land/city/Galle/en
#     Saved (586 chars, 74 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 112 docs saved, 115 visited, 436 in queue
#  [1] https://www.primelands.lk/land/city/Nuwara-Eliya/en
#     Saved (600 chars, 73 links found)
#    Progress: 113 docs saved, 116 visited, 435 in queue
#  [1] https://www.primelands.lk/land/city/Minuwangoda/en
#     Saved (598 chars, 72 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 114 docs saved, 117 visited, 436 in queue
#  [1] https://www.primelands.lk/land/city/Gampaha/en
#     Saved (590 chars, 71 links found)
#     Added 1 new URLs to queue (depth 2)
#    Progress: 115 docs saved, 118 visited, 436 in queue
#  [1] https://www.primelands.lk/house/district/Gampaha/en
#     Saved (600 chars, 31 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 116 docs saved, 119 visited, 439 in queue
#  [1] https://www.primelands.lk/house/city/Piliyandala/en
#     Saved (600 chars, 29 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 117 docs saved, 120 visited, 440 in queue
#  [1] https://www.primelands.lk/house/city/Kelaniya/en
#     Saved (594 chars, 29 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 118 docs saved, 121 visited, 441 in queue
#  [1] https://www.primelands.lk/house/city/Kadawatha/en
#     Saved (596 chars, 31 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 119 docs saved, 122 visited, 442 in queue
#  [1] https://www.primelands.lk/house/city/Moratuwa/en
#     Saved (594 chars, 30 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 120 docs saved, 123 visited, 444 in queue
#  [1] https://www.primelands.lk/house/city/Kottawa/en
#     Saved (592 chars, 31 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 121 docs saved, 124 visited, 447 in queue
#  [1] https://www.primelands.lk/house/city/Gampaha/en
#     Saved (592 chars, 29 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 122 docs saved, 125 visited, 448 in queue
#  [1] https://www.primelands.lk/house/district/Colombo/en
#     Saved (600 chars, 29 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 123 docs saved, 126 visited, 449 in queue
#  [1] https://www.primelands.lk/house/city/Malabe/en
#     Saved (590 chars, 29 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 124 docs saved, 127 visited, 450 in queue
#  [1] https://www.primelands.lk/house/tam
#     Saved (592 chars, 29 links found)
#     Added 5 new URLs to queue (depth 2)
#    Progress: 125 docs saved, 128 visited, 454 in queue
#  [1] https://www.primelands.lk/house/city/Thalawathugoda/en
#     Saved (606 chars, 30 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 126 docs saved, 129 visited, 455 in queue
#  [1] https://www.primelands.lk/house/sin
#     Saved (573 chars, 29 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 127 docs saved, 130 visited, 458 in queue
#  [1] https://www.primelands.lk/house/MALABE-WATERFALL-RESIDENCIES/en
#     Saved (624 chars, 12 links found)
#    Progress: 128 docs saved, 131 visited, 457 in queue
#  [1] https://www.primelands.lk/house/district/Kandy/en
#     Saved (596 chars, 29 links found)
#    Progress: 129 docs saved, 132 visited, 456 in queue
#  [1] https://www.primelands.lk/house/city/Nugegoda/en
#     Saved (594 chars, 30 links found)
#     Added 1 new URLs to queue (depth 2)
#    Progress: 130 docs saved, 133 visited, 456 in queue
#  [1] https://www.primelands.lk/house/city/Kandy/en
#     Saved (588 chars, 29 links found)
#    Progress: 131 docs saved, 134 visited, 455 in queue
#  [2] https://www.primelands.lk/land/ADORA-NAIWALA/sin
#     Saved (599 chars, 13 links found)
#     Added 5 new URLs to queue (depth 3)
#    Progress: 132 docs saved, 135 visited, 459 in queue
#  [2] https://www.primelands.lk/land/GREEN-HIDE-YAKKALA/en
#     Saved (602 chars, 12 links found)
#     Added 1 new URLs to queue (depth 3)
#    Progress: 133 docs saved, 136 visited, 459 in queue
#  [2] https://www.primelands.lk/land/CALLISTO-KADAWATHA/en
#     Saved (602 chars, 12 links found)
#     Added 1 new URLs to queue (depth 3)
#    Progress: 134 docs saved, 137 visited, 459 in queue
#  [2] https://www.primelands.lk/land/LUANA-KADAWATHA/en
#     Saved (596 chars, 14 links found)
#     Added 3 new URLs to queue (depth 3)
#    Progress: 135 docs saved, 138 visited, 461 in queue
#  [2] https://www.primelands.lk/land/AVENLY-KADAWATHA/en
#     Saved (598 chars, 13 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 136 docs saved, 139 visited, 462 in queue
#  [2] https://www.primelands.lk/land/GAMPAHA-THE-SEQUOR/en
#     Saved (602 chars, 12 links found)
#     Added 1 new URLs to queue (depth 3)
#    Progress: 137 docs saved, 140 visited, 462 in queue
#  [2] https://www.primelands.lk/land/ADORA-NAIWALA/tam
#     Saved (618 chars, 13 links found)
#    Progress: 138 docs saved, 141 visited, 461 in queue
#  [2] https://www.primelands.lk/house/THE-RESIDENCE-SAMAGI-MAWATHA-THALAWATHUGODA/tam
#     Saved (680 chars, 12 links found)
#     Added 1 new URLs to queue (depth 3)
#    Progress: 139 docs saved, 142 visited, 461 in queue
#  [2] https://www.primelands.lk/house/THE-RESIDENCE-SAMAGI-MAWATHA-THALAWATHUGODA/sin
#     Saved (661 chars, 12 links found)
#     Added 1 new URLs to queue (depth 3)
#    Progress: 140 docs saved, 143 visited, 461 in queue
#  [2] https://www.primelands.lk/house/THALAWATHUGODA-CLOVER/tam
#     Saved (636 chars, 14 links found)
#    Progress: 141 docs saved, 144 visited, 459 in queue
#  [2] https://www.primelands.lk/house/THALAWATHUGODA-CLOVER/sin
#     Saved (617 chars, 14 links found)
#    Progress: 142 docs saved, 145 visited, 458 in queue
#  [2] https://www.primelands.lk/apartment/THE-REFLECTION-SAMAGI-MAWATHA-THALAWATHUGODA/tam
#     Saved (690 chars, 12 links found)
#    Progress: 143 docs saved, 146 visited, 457 in queue
#  [2] https://www.primelands.lk/apartment/THE-REFLECTION-SAMAGI-MAWATHA-THALAWATHUGODA/sin
#     Saved (671 chars, 12 links found)
#    Progress: 144 docs saved, 147 visited, 456 in queue
#  [2] https://www.primelands.lk/contact-us/tam
#     Saved (602 chars, 7 links found)
#    Progress: 145 docs saved, 148 visited, 455 in queue
#  [2] https://www.primelands.lk/contact-us/sin
#     Saved (583 chars, 7 links found)
#    Progress: 146 docs saved, 149 visited, 454 in queue
#  [2] https://www.primelands.lk/portfolio-property/ALUTHGAMA-WELIPENNA/sin
#     Saved (639 chars, 11 links found)
#    Progress: 147 docs saved, 150 visited, 453 in queue
#  [2] https://www.primelands.lk/portfolio-property/ALUTHGAMA-WELIPENNA/tam
#     Saved (658 chars, 11 links found)
#    Progress: 148 docs saved, 151 visited, 452 in queue
#  [2] https://www.primelands.lk/land/LUXORA-KIRIBATHGODA/tam
#     Saved (630 chars, 13 links found)
#    Progress: 149 docs saved, 152 visited, 451 in queue
#  [2] https://www.primelands.lk/land/LUXORA-KIRIBATHGODA/sin
#     Saved (611 chars, 13 links found)
#    Progress: 150 docs saved, 153 visited, 450 in queue
#  [2] https://www.primelands.lk/house/VIVA-LA-VIDA-KOTTAWA/sin
#     Saved (615 chars, 14 links found)
#    Progress: 151 docs saved, 154 visited, 449 in queue
#  [2] https://www.primelands.lk/house/VIVA-LA-VIDA-KOTTAWA/tam
#     Saved (634 chars, 14 links found)
#    Progress: 152 docs saved, 155 visited, 448 in queue
#  [2] https://www.primelands.lk/portfolio-property/ELLA-NUWARA-ELIYA/tam
#     Saved (654 chars, 11 links found)
#    Progress: 153 docs saved, 156 visited, 447 in queue
#  [2] https://www.primelands.lk/portfolio-property/ELLA-NUWARA-ELIYA/sin
#     Saved (635 chars, 11 links found)
#    Progress: 154 docs saved, 157 visited, 446 in queue
#  [2] https://www.primelands.lk/portfolio-property/city/Homagama/en
#     Saved (620 chars, 41 links found)
#     Added 3 new URLs to queue (depth 3)
#    Progress: 155 docs saved, 158 visited, 448 in queue
#  [2] https://www.primelands.lk/portfolio-property/district/Nuwara-Eliya/en
#     Saved (636 chars, 41 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 156 docs saved, 159 visited, 449 in queue
#  [2] https://www.primelands.lk/portfolio-property/paddy-field-facing-lands/en
#     Saved (642 chars, 40 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 157 docs saved, 160 visited, 450 in queue
#  [2] https://www.primelands.lk/portfolio-property/mountain-view/en
#     Saved (620 chars, 41 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 158 docs saved, 161 visited, 451 in queue
#  [2] https://www.primelands.lk/portfolio-property/city/Weligama/en
#     Saved (620 chars, 41 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 159 docs saved, 162 visited, 452 in queue
#  [2] https://www.primelands.lk/portfolio-property/city/Negombo/en
#     Saved (618 chars, 41 links found)
#     Added 3 new URLs to queue (depth 3)
#    Progress: 160 docs saved, 163 visited, 454 in queue
#  [2] https://www.primelands.lk/portfolio-property/district/Anuradhapura/en
#     Saved (636 chars, 41 links found)
#     Added 3 new URLs to queue (depth 3)
#    Progress: 161 docs saved, 164 visited, 456 in queue
#  [2] https://www.primelands.lk/portfolio-property/land/en
#     Saved (602 chars, 46 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 162 docs saved, 165 visited, 457 in queue
#  [2] https://www.primelands.lk/portfolio-property/waterfront-land/en
#     Saved (624 chars, 40 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 163 docs saved, 166 visited, 458 in queue
#  [2] https://www.primelands.lk/portfolio-property/down-south-lands/en
#     Saved (626 chars, 42 links found)
#     Added 3 new URLs to queue (depth 3)
#    Progress: 164 docs saved, 167 visited, 460 in queue
#  [2] https://www.primelands.lk/portfolio-property/agriculture-land/en
#     Saved (626 chars, 40 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 165 docs saved, 168 visited, 461 in queue
#  [2] https://www.primelands.lk/portfolio-property/district/Kalutara/en
#     Saved (628 chars, 42 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 166 docs saved, 169 visited, 462 in queue
#  [2] https://www.primelands.lk/portfolio-property/district/Galle/en
#     Saved (622 chars, 42 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 167 docs saved, 170 visited, 463 in queue
#  [2] https://www.primelands.lk/portfolio-property/city/Colombo/en
#     Saved (618 chars, 41 links found)
#     Added 3 new URLs to queue (depth 3)
#    Progress: 168 docs saved, 171 visited, 465 in queue
#  [2] https://www.primelands.lk/portfolio-property/district/Colombo/en
#     Saved (626 chars, 43 links found)
#     Added 3 new URLs to queue (depth 3)
#    Progress: 169 docs saved, 172 visited, 467 in queue
#  [2] https://www.primelands.lk/portfolio-property/city/Kaduwela-/en
#     Saved (622 chars, 41 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 170 docs saved, 173 visited, 468 in queue
#  [2] https://www.primelands.lk/portfolio-property/residential/en
#     Saved (616 chars, 46 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 171 docs saved, 174 visited, 469 in queue
#  [2] https://www.primelands.lk/portfolio-property/city/Galle/en
#     Saved (614 chars, 42 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 172 docs saved, 175 visited, 470 in queue
#  [2] https://www.primelands.lk/portfolio-property/close-to-Airport/en
#     Saved (626 chars, 40 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 173 docs saved, 176 visited, 471 in queue
#  [2] https://www.primelands.lk/portfolio-property/district/Matara/en
#     Saved (624 chars, 41 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 174 docs saved, 177 visited, 472 in queue
#  [2] https://www.primelands.lk/portfolio-property/coconut-land/en
#     Saved (618 chars, 40 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 175 docs saved, 178 visited, 473 in queue
#  [2] https://www.primelands.lk/portfolio-property/close-to-ancient-city-lands/en
#     Saved (648 chars, 41 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 176 docs saved, 179 visited, 474 in queue
#  [2] https://www.primelands.lk/portfolio-property/up-country-lands/en
#     Saved (626 chars, 41 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 177 docs saved, 180 visited, 475 in queue
#  [2] https://www.primelands.lk/portfolio-property/city/Kalutara/en
#     Saved (620 chars, 41 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 178 docs saved, 181 visited, 476 in queue
#  [2] https://www.primelands.lk/portfolio-property/commercial/en
#     Saved (614 chars, 44 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 179 docs saved, 182 visited, 477 in queue
#  [2] https://www.primelands.lk/portfolio-property/district/Kurunegala/en
#     Saved (632 chars, 41 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 180 docs saved, 183 visited, 478 in queue
#  [2] https://www.primelands.lk/portfolio-property/sin
#     Saved (599 chars, 46 links found)
#     Added 7 new URLs to queue (depth 3)
#    Progress: 181 docs saved, 184 visited, 484 in queue
#  [2] https://www.primelands.lk/portfolio-property/city/Wariyapola/en
#     Saved (624 chars, 41 links found)
#     Added 1 new URLs to queue (depth 3)
#    Progress: 182 docs saved, 185 visited, 484 in queue
#  [2] https://www.primelands.lk/portfolio-property/city/Aluthgama/en
#     Saved (622 chars, 41 links found)
#     Added 1 new URLs to queue (depth 3)
#    Progress: 183 docs saved, 186 visited, 484 in queue
#  [2] https://www.primelands.lk/portfolio-property/city/Anuradhapura/en
#     Saved (628 chars, 41 links found)
#     Added 1 new URLs to queue (depth 3)
#    Progress: 184 docs saved, 187 visited, 484 in queue
#  [2] https://www.primelands.lk/portfolio-property/close-to-railway-stations/en
#     Saved (644 chars, 40 links found)
#     Added 1 new URLs to queue (depth 3)
#    Progress: 185 docs saved, 188 visited, 484 in queue
#  [2] https://www.primelands.lk/portfolio-property/city/Nuwara-Eliya/en
#     Saved (628 chars, 41 links found)
#     Added 1 new URLs to queue (depth 3)
#    Progress: 186 docs saved, 189 visited, 484 in queue
#  [2] https://www.primelands.lk/portfolio-property/district/Gampaha/en
#     Saved (626 chars, 41 links found)
#     Added 1 new URLs to queue (depth 3)
#    Progress: 187 docs saved, 190 visited, 484 in queue
#  [2] https://www.primelands.lk/portfolio-property/close-to-highways/en
#     Saved (628 chars, 42 links found)
#     Added 1 new URLs to queue (depth 3)
#    Progress: 188 docs saved, 191 visited, 484 in queue
#  [2] https://www.primelands.lk/portfolio-property/tam
#     Saved (618 chars, 46 links found)
#    Progress: 189 docs saved, 192 visited, 483 in queue
#  [2] https://www.primelands.lk/apartment/MON-VIE-COLOMBO-05/sin
#     Saved (619 chars, 11 links found)
#     Added 1 new URLs to queue (depth 3)
#    Progress: 190 docs saved, 193 visited, 483 in queue
#  [2] https://www.primelands.lk/apartment/MON-VIE-COLOMBO-05/tam
#     Saved (638 chars, 11 links found)
#     Added 1 new URLs to queue (depth 3)
#    Progress: 191 docs saved, 194 visited, 483 in queue
#  [2] https://www.primelands.lk/apartment/THE-COLOMBO-BORDER-PELIYAGODA/en
#     Saved (634 chars, 11 links found)
#    Progress: 192 docs saved, 195 visited, 482 in queue
#  [2] https://www.primelands.lk/news/98/Prime-Group-Expands-Its-Footprint-to-Elevate-Customer-Experience-and-Reinforce-Its-Commitment-to-Excellence-with-the-Launch-of-the-Kalutara-Branch/sin
#     Saved (871 chars, 19 links found)
#     Added 6 new URLs to queue (depth 3)
#    Progress: 193 docs saved, 196 visited, 487 in queue
#  [2] https://www.primelands.lk/news/88/Prime-Group-appoints-international-music-icon-Umaria-Sinhawansa-as-Global-Brand-Ambassador/en
#     Saved (752 chars, 18 links found)
#     Added 1 new URLs to queue (depth 3)
#    Progress: 194 docs saved, 197 visited, 487 in queue
#  [2] https://www.primelands.lk/news/87/Prime-Lands-Recognized-as-Most-Innovative-Property-Developer-Sri-Lanka-2025-by-World-Economic-Magazine-Awards-USA/en
#     Saved (798 chars, 18 links found)
#     Added 1 new URLs to queue (depth 3)
#    Progress: 195 docs saved, 198 visited, 487 in queue
#  [2] https://www.primelands.lk/news/89/Marking-a-Historic-Milestone-Prime-Group-and-FSLGA-seal-public-private-synergy-to-elevate-Local-Government-capacity-nationwide/en
#     Saved (824 chars, 18 links found)
#     Added 1 new URLs to queue (depth 3)
#    Progress: 196 docs saved, 199 visited, 487 in queue
#  [2] https://www.primelands.lk/news/86/Prime-Group-unveils-innovative-Public-Private-collaboration-initiative-to-enhance-Government-service-excellence/en
#     Saved (794 chars, 18 links found)
#     Added 1 new URLs to queue (depth 3)
#    Progress: 197 docs saved, 200 visited, 487 in queue
#  [2] https://www.primelands.lk/news/90/Prime-Groups-Legacy-in-Real-Estate-Featured-in-Kotlers-Essential-of-Modern-Marketing/en
#     Saved (740 chars, 18 links found)
#     Added 1 new URLs to queue (depth 3)
#    Progress: 198 docs saved, 201 visited, 487 in queue
#  [2] https://www.primelands.lk/news/98/Prime-Group-Expands-Its-Footprint-to-Elevate-Customer-Experience-and-Reinforce-Its-Commitment-to-Excellence-with-the-Launch-of-the-Kalutara-Branch/tam
#     Saved (890 chars, 19 links found)
#     Added 1 new URLs to queue (depth 3)
#    Progress: 199 docs saved, 202 visited, 487 in queue
#  [2] https://www.primelands.lk/news/91/Prime-Group-launches-Prime-Edge-as-Sri-Lankas-first-all-in-one-real-estate-mobile-app/en
#     Saved (742 chars, 18 links found)
#    Progress: 200 docs saved, 203 visited, 486 in queue
#  [2] https://www.primelands.lk/apartment/SKYE-BLOSSOM-KOTTAWA/tam
#     Saved (642 chars, 11 links found)
#    Progress: 201 docs saved, 204 visited, 485 in queue
#  [2] https://www.primelands.lk/apartment/SKYE-BLOSSOM-KOTTAWA/sin
#     Saved (623 chars, 11 links found)
#    Progress: 202 docs saved, 205 visited, 484 in queue
#  [2] https://www.primelands.lk/portfolio-property/WARIYAPOLA-KURUNEGALA/sin
#     Saved (643 chars, 11 links found)
#    Progress: 203 docs saved, 206 visited, 483 in queue
#  [2] https://www.primelands.lk/portfolio-property/WARIYAPOLA-KURUNEGALA/tam
#     Saved (662 chars, 11 links found)
#    Progress: 204 docs saved, 207 visited, 482 in queue
#  [2] https://www.primelands.lk/apartment/THE-GOLF-COLOMBO-08/sin
#     Saved (621 chars, 11 links found)
#    Progress: 205 docs saved, 208 visited, 481 in queue
#  [2] https://www.primelands.lk/land/GREEN-CREST-HORANA/sin
#     Saved (609 chars, 11 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 206 docs saved, 209 visited, 482 in queue
#  [2] https://www.primelands.lk/house/DIGANA-SCOTTISH-ISLAND/sin
#     Saved (619 chars, 12 links found)
#    Progress: 207 docs saved, 210 visited, 481 in queue
#  [2] https://www.primelands.lk/house/DALUGAMA-PRIME-VILLAS/sin
#     Saved (617 chars, 12 links found)
#    Progress: 208 docs saved, 211 visited, 480 in queue
#  [2] https://www.primelands.lk/news/sin
#     Saved (571 chars, 15 links found)
#    Progress: 209 docs saved, 212 visited, 479 in queue
#  [2] https://www.primelands.lk/land/EVARA-NAWALAPITIYA/sin
#     Saved (609 chars, 13 links found)
#     Added 5 new URLs to queue (depth 3)
#    Progress: 210 docs saved, 213 visited, 483 in queue
#  [2] https://www.primelands.lk/land/ELITE-AVENUE-KAHATHUDUWA/sin
#     Saved (621 chars, 11 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 211 docs saved, 214 visited, 484 in queue
#  [2] https://www.primelands.lk/house/KAHATHUDUWA-88-RESIDENCE/sin
#     Saved (623 chars, 13 links found)
#    Progress: 212 docs saved, 215 visited, 483 in queue
#  [2] https://www.primelands.lk/news/93/Prime-Group-makes-history-with-Sri-Lankas-first-luxury-real-estate-client-experience-initiative-Prime-Premier/sin
#     Saved (797 chars, 18 links found)
#    Progress: 213 docs saved, 216 visited, 482 in queue
#  [2] https://www.primelands.lk/apartment/sin
#     Saved (597 chars, 26 links found)
#     Added 10 new URLs to queue (depth 3)
#    Progress: 214 docs saved, 217 visited, 491 in queue
#  [2] https://www.primelands.lk/news/99/Prime-Melwa-Acquire-4-Acres-of-Premium-Waterfront-Land-in-Port-City-Colombo-for-USD-576Mn/sin
#     Saved (757 chars, 18 links found)
#    Progress: 215 docs saved, 218 visited, 490 in queue
#  [2] https://www.primelands.lk/house/CEST-LA-VIE-THALAWATHUGODA/sin
#     Saved (627 chars, 14 links found)
#    Progress: 216 docs saved, 219 visited, 489 in queue
#  [2] https://www.primelands.lk/news/97/Prime-Group-Stands-with-the-Children-of-Police-Families-Affected-by-Cyclone-Ditwah/sin
#     Saved (743 chars, 18 links found)
#    Progress: 217 docs saved, 220 visited, 488 in queue
#  [2] https://www.primelands.lk/apartment/J-ADORE-NEGOMBO/sin
#     Saved (613 chars, 11 links found)
#    Progress: 218 docs saved, 221 visited, 487 in queue
#  [2] https://www.primelands.lk/news/94/Prime-Group-builds-nations-most-connected-property-experience-with-firstofitskind-technology-ecosystem/sin
#     Saved (783 chars, 18 links found)
#    Progress: 219 docs saved, 222 visited, 486 in queue
#  [2] https://www.primelands.lk/apartment/THE-SEASONS-COLOMBO-08/sin
#     Saved (627 chars, 10 links found)
#    Progress: 220 docs saved, 223 visited, 485 in queue
#  [2] https://www.primelands.lk/portfolio-property/GALLE-HAPUGALA/sin
#     Saved (629 chars, 11 links found)
#    Progress: 221 docs saved, 224 visited, 484 in queue
#  [2] https://www.primelands.lk/portfolio-property/MATARA-WELIGAMA/sin
#     Saved (631 chars, 11 links found)
#    Progress: 222 docs saved, 225 visited, 483 in queue
#  [2] https://www.primelands.lk/portfolio-property/KALUTARA-NAGODA/sin
#     Saved (631 chars, 11 links found)
#    Progress: 223 docs saved, 226 visited, 482 in queue
#  [2] https://www.primelands.lk/land/LUXE-THALAHENA/sin
#     Saved (601 chars, 12 links found)
#     Added 3 new URLs to queue (depth 3)
#    Progress: 224 docs saved, 227 visited, 484 in queue
#  [2] https://www.primelands.lk/land/LUXCORE-CITY-MALABE/sin
#     Saved (611 chars, 14 links found)
#     Added 6 new URLs to queue (depth 3)
#    Progress: 225 docs saved, 228 visited, 489 in queue
#  [2] https://www.primelands.lk/apartment/VENEZIA-NEGOMBO/sin
#     Saved (613 chars, 11 links found)
#    Progress: 226 docs saved, 229 visited, 488 in queue
#  [2] https://www.primelands.lk/apartment/YOLO-KIRIBATHGODA/sin
#     Saved (617 chars, 11 links found)
#    Progress: 227 docs saved, 230 visited, 487 in queue
#  [2] https://www.primelands.lk/house/GAMPAHA-ELEMINT-SUITES/sin
#     Saved (619 chars, 12 links found)
#    Progress: 228 docs saved, 231 visited, 486 in queue
#  [2] https://www.primelands.lk/about-us/sin
#     Saved (579 chars, 30 links found)
#     Added 21 new URLs to queue (depth 3)
#    Progress: 229 docs saved, 232 visited, 506 in queue
#  [2] https://www.primelands.lk/land/AURELIA-ALUBOMULLA/sin
#     Saved (609 chars, 14 links found)
#     Added 4 new URLs to queue (depth 3)
#    Progress: 230 docs saved, 233 visited, 509 in queue
#  [2] https://www.primelands.lk/portfolio-property/MATARA-WELIGAMA/tam
#     Saved (650 chars, 11 links found)
#    Progress: 231 docs saved, 234 visited, 508 in queue
#  [2] https://www.primelands.lk/land/LUXCORE-CITY-MALABE/tam
#     Saved (630 chars, 14 links found)
#     Added 6 new URLs to queue (depth 3)
#    Progress: 232 docs saved, 235 visited, 513 in queue
#  [2] https://www.primelands.lk/about-us/tam
#     Saved (598 chars, 30 links found)
#     Added 21 new URLs to queue (depth 3)
#    Progress: 233 docs saved, 236 visited, 533 in queue
#  [2] https://www.primelands.lk/news/99/Prime-Melwa-Acquire-4-Acres-of-Premium-Waterfront-Land-in-Port-City-Colombo-for-USD-576Mn/tam
#     Saved (776 chars, 18 links found)
#    Progress: 234 docs saved, 237 visited, 532 in queue
#  [2] https://www.primelands.lk/house/GAMPAHA-ELEMINT-SUITES/tam
#     Saved (638 chars, 12 links found)
#    Progress: 235 docs saved, 238 visited, 531 in queue
#  [2] https://www.primelands.lk/apartment/VENEZIA-NEGOMBO/tam
#     Saved (632 chars, 11 links found)
#    Progress: 236 docs saved, 239 visited, 530 in queue
#  [2] https://www.primelands.lk/land/ELITE-AVENUE-KAHATHUDUWA/tam
#     Saved (640 chars, 11 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 237 docs saved, 240 visited, 531 in queue
#  [2] https://www.primelands.lk/apartment/THE-SEASONS-COLOMBO-08/tam
#     Saved (646 chars, 10 links found)
#    Progress: 238 docs saved, 241 visited, 530 in queue
#  [2] https://www.primelands.lk/portfolio-property/KALUTARA-NAGODA/tam
#     Saved (650 chars, 11 links found)
#    Progress: 239 docs saved, 242 visited, 529 in queue
#  [2] https://www.primelands.lk/news/94/Prime-Group-builds-nations-most-connected-property-experience-with-firstofitskind-technology-ecosystem/tam
#     Saved (802 chars, 18 links found)
#    Progress: 240 docs saved, 243 visited, 528 in queue
#  [2] https://www.primelands.lk/portfolio-property/GALLE-HAPUGALA/tam
#     Saved (648 chars, 11 links found)
#    Progress: 241 docs saved, 244 visited, 527 in queue
#  [2] https://www.primelands.lk/news/97/Prime-Group-Stands-with-the-Children-of-Police-Families-Affected-by-Cyclone-Ditwah/tam
#     Saved (762 chars, 18 links found)
#    Progress: 242 docs saved, 245 visited, 526 in queue
#  [2] https://www.primelands.lk/land/LUXE-THALAHENA/tam
#     Saved (620 chars, 12 links found)
#     Added 3 new URLs to queue (depth 3)
#    Progress: 243 docs saved, 246 visited, 528 in queue
#  [2] https://www.primelands.lk/house/CEST-LA-VIE-THALAWATHUGODA/tam
#     Saved (646 chars, 14 links found)
#    Progress: 244 docs saved, 247 visited, 527 in queue
#  [2] https://www.primelands.lk/news/tam
#     Saved (590 chars, 15 links found)
#    Progress: 245 docs saved, 248 visited, 526 in queue
#  [2] https://www.primelands.lk/land/GREEN-CREST-HORANA/tam
#     Saved (628 chars, 11 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 246 docs saved, 249 visited, 527 in queue
#  [2] https://www.primelands.lk/apartment/J-ADORE-NEGOMBO/tam
#     Saved (632 chars, 11 links found)
#    Progress: 247 docs saved, 250 visited, 526 in queue
#  [2] https://www.primelands.lk/house/DIGANA-SCOTTISH-ISLAND/tam
#     Saved (638 chars, 12 links found)
#    Progress: 248 docs saved, 251 visited, 525 in queue
#  [2] https://www.primelands.lk/house/DALUGAMA-PRIME-VILLAS/tam
#     Saved (636 chars, 12 links found)
#    Progress: 249 docs saved, 252 visited, 524 in queue
#  [2] https://www.primelands.lk/land/EVARA-NAWALAPITIYA/tam
#     Saved (628 chars, 13 links found)
#     Added 5 new URLs to queue (depth 3)
#    Progress: 250 docs saved, 253 visited, 528 in queue
#  [2] https://www.primelands.lk/house/KAHATHUDUWA-88-RESIDENCE/tam
#     Saved (642 chars, 13 links found)
#    Progress: 251 docs saved, 254 visited, 527 in queue
#  [2] https://www.primelands.lk/apartment/YOLO-KIRIBATHGODA/tam
#     Saved (636 chars, 11 links found)
#     Added 1 new URLs to queue (depth 3)
#    Progress: 252 docs saved, 255 visited, 527 in queue
#  [2] https://www.primelands.lk/apartment/tam
#     Saved (616 chars, 26 links found)
#     Added 9 new URLs to queue (depth 3)
#    Progress: 253 docs saved, 256 visited, 535 in queue
#  [2] https://www.primelands.lk/land/AURELIA-ALUBOMULLA/tam
#     Saved (628 chars, 14 links found)
#     Added 4 new URLs to queue (depth 3)
#    Progress: 254 docs saved, 257 visited, 538 in queue
#  [2] https://www.primelands.lk/apartment/THE-GOLF-COLOMBO-08/tam
#     Saved (640 chars, 11 links found)
#    Progress: 255 docs saved, 258 visited, 537 in queue
#  [2] https://www.primelands.lk/news/93/Prime-Group-makes-history-with-Sri-Lankas-first-luxury-real-estate-client-experience-initiative-Prime-Premier/tam
#     Saved (816 chars, 18 links found)
#    Progress: 256 docs saved, 259 visited, 536 in queue
#  [2] https://www.primelands.lk/news/12/GREAT-PLACE-TO-WORK-IN-SRI-LANKA-FOR-2017/en
#     Saved (654 chars, 18 links found)
#    Progress: 257 docs saved, 260 visited, 535 in queue
#  [2] https://www.primelands.lk/news/80/Prime-Lands-recognised-for-excellence-on-global-stage-with-double-wins-at-World-Business-Outlook-Awards 2024/en
#     Saved (788 chars, 19 links found)
#    Progress: 258 docs saved, 261 visited, 534 in queue
#  [2] https://www.primelands.lk/news/4/WCRC-LEADERS-ASIA-WE-AWARD---2014/en
#     Saved (636 chars, 18 links found)
#    Progress: 259 docs saved, 262 visited, 533 in queue
#  [2] https://www.primelands.lk/news/18/PRIME-GROUP-CROWNED-BEST-DEVELOPER-IN-SRI-LANKA-YET-AGAIN/en
#     Saved (686 chars, 18 links found)
#    Progress: 260 docs saved, 263 visited, 532 in queue
# ...
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/HARITHAPURA-ANUR
#  [3] https://www.primelands.lk/land/PREMIA-ANURADHAPURA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/PREMIA-ANURADHAP
#  [3] https://www.primelands.lk/land/PRIME-KINGS-BOULEVARD-ANURADHAPURA/en
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/PRIME-KINGS-BOUL
#  [3] https://www.primelands.lk/land/SINHARAGAMA-LION-GATE/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/SINHARAGAMA-LION
#  [3] https://www.primelands.lk/land/NELUMDENIYA-LOTUS-AVENUE/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/NELUMDENIYA-LOTU
#  [3] https://www.primelands.lk/land/SHINE-VALLEY-DIKWELLA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/SHINE-VALLEY-DIK
#  [3] https://www.primelands.lk/land/MAGNETISM-WELIGAMA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/MAGNETISM-WELIGA
#  [3] https://www.primelands.lk/land/LAKE-FRONT-MAKAVITA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/LAKE-FRONT-MAKAV
#  [3] https://www.primelands.lk/land/SUNREACH-MATARA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/SUNREACH-MATARA/
#  [3] https://www.primelands.lk/land/SUNBAY-MATARA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/SUNBAY-MATARA/si
#  [3] https://www.primelands.lk/land/CIVIC-20-MUNAGAMA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/CIVIC-20-MUNAGAM
#  [3] https://www.primelands.lk/land/PRIME-CAPITAL-HORANA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/PRIME-CAPITAL-HO
#  [3] https://www.primelands.lk/land/WONDERY-MORONTHUDUWA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/WONDERY-MORONTHU
#  [3] https://www.primelands.lk/land/THALAGALA-EDEN-PLACE/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/THALAGALA-EDEN-P
#  [3] https://www.primelands.lk/land/GREEN-WOOD-KIRIBATHGODA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/GREEN-WOOD-KIRIB
#  [3] https://www.primelands.lk/land/PRIME-CITY-NEST-MAKOLA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/PRIME-CITY-NEST-
#  [3] https://www.primelands.lk/land/PRESTIGE-PALACE-KIRIBATHGODA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/PRESTIGE-PALACE-
#  [3] https://www.primelands.lk/land/PRIME-INNER-CITY/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/PRIME-INNER-CITY
#  [3] https://www.primelands.lk/land/PARADISE-AVENUE-NEGOMBO/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/PARADISE-AVENUE-
#  [3] https://www.primelands.lk/land/NEGOMBO-CITY-BASE/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/NEGOMBO-CITY-BAS
#  [3] https://www.primelands.lk/land/PRIME-ORIGIN-II-NEGOMBO/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/PRIME-ORIGIN-II-
#  [3] https://www.primelands.lk/land/THE-LAGOON-KATUNAYAKE/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/THE-LAGOON-KATUN
#  [3] https://www.primelands.lk/land/PRIME-ORIGIN/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/PRIME-ORIGIN/sin
#  [3] https://www.primelands.lk/land/NUWARAELIYA-THE-RIPPLES/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/NUWARAELIYA-THE-
#  [3] https://www.primelands.lk/land/NUWARAELIYA-BLACKPOOL/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/NUWARAELIYA-BLAC
#  [3] https://www.primelands.lk/land/PRIME-DAWN-ARTIGALA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/PRIME-DAWN-ARTIG
#  [3] https://www.primelands.lk/land/ARTIGALA-LUSH-LIFE/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/ARTIGALA-LUSH-LI
#  [3] https://www.primelands.lk/land/PRIME-ASTERIN-ARTIGALA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/PRIME-ASTERIN-AR
#  [3] https://www.primelands.lk/land/PRIME-GREENVALE-ARTIGALA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/PRIME-GREENVALE-
#  [3] https://www.primelands.lk/land/TANGALLE-THE-SAND/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/TANGALLE-THE-SAN
#  [3] https://www.primelands.lk/land/URBAN-CENTRE-WALASMULLA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/URBAN-CENTRE-WAL
#  [3] https://www.primelands.lk/land/MAJESTINO-MORATUWA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/MAJESTINO-MORATU
#  [3] https://www.primelands.lk/land/LAVISH-GARDEN/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/LAVISH-GARDEN/si
#  [3] https://www.primelands.lk/land/CITY-GLAZE-MINUWANGODA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/CITY-GLAZE-MINUW
#  [3] https://www.primelands.lk/land/FELICITY-MINUWANGODA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/FELICITY-MINUWAN
#  [3] https://www.primelands.lk/land/UNITY-VEYANGODA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/UNITY-VEYANGODA/
#  [3] https://www.primelands.lk/land/MAXON-VEYANGODA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/MAXON-VEYANGODA/
#  [3] https://www.primelands.lk/land/PRIME-UNITY-STAGE-3/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/PRIME-UNITY-STAG
#  [3] https://www.primelands.lk/land/ZERENITY-WEYANGODA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/ZERENITY-WEYANGO
#  [3] https://www.primelands.lk/land/PRIME-FUTURA-UDUGAMPOLA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/PRIME-FUTURA-UDU
#  [3] https://www.primelands.lk/land/SISIL-SEWANA-PARASANGASWEWA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/SISIL-SEWANA-PAR
#  [3] https://www.primelands.lk/land/WATAREKA-GREEN-STREAM/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/WATAREKA-GREEN-S
#  [3] https://www.primelands.lk/land/city/Meegoda/en
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/city/Meegoda/en"
#  [3] https://www.primelands.lk/land/GREEN-HEAVEN-ARTIGALA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/GREEN-HEAVEN-ART
#  [3] https://www.primelands.lk/land/SYNERGY-MEEGODA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/SYNERGY-MEEGODA/
#  [3] https://www.primelands.lk/land/city/Meegoda/tam
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/city/Meegoda/tam
#  [3] https://www.primelands.lk/land/PRIME-FAIRY-LAKE-DAMBULLA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/PRIME-FAIRY-LAKE
#  [3] https://www.primelands.lk/land/GREEN-CITY-PHASE-2-MATALE/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/GREEN-CITY-PHASE
#  [3] https://www.primelands.lk/land/CAELUM-DAMBULLA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/CAELUM-DAMBULLA/
#  [3] https://www.primelands.lk/land/SUPREME-PLACE-AMBATHENNA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/SUPREME-PLACE-AM
#  [3] https://www.primelands.lk/land/CAPITAL-POINT-GAMPAHA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/CAPITAL-POINT-GA
#  [3] https://www.primelands.lk/land/NITTAMBUWA-IMPERIUM/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/NITTAMBUWA-IMPER
#  [3] https://www.primelands.lk/land/PRIME-ZONE-5/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/PRIME-ZONE-5/sin
#  [3] https://www.primelands.lk/land/KURUNEGALA-YOKE/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/KURUNEGALA-YOKE/
#  [3] https://www.primelands.lk/land/PRIME-KESHARA-ADAWIYA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/PRIME-KESHARA-AD
#  [3] https://www.primelands.lk/land/WOODLAND-ESTATE-IV-KURUNEGALA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/WOODLAND-ESTATE-
#  [3] https://www.primelands.lk/land/KURUNEGALA-WEHERA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/KURUNEGALA-WEHER
#  [3] https://www.primelands.lk/land/3RD-LANE-KURUNEGALA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/3RD-LANE-KURUNEG
#  [3] https://www.primelands.lk/land/BOGAHAGODA-PRIME-BLISS/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/BOGAHAGODA-PRIME
#  [3] https://www.primelands.lk/land/PRIME-SERENE-GALLE/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/PRIME-SERENE-GAL
#  [3] https://www.primelands.lk/land/GREEN-TOWN-PODDALA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/GREEN-TOWN-PODDA
#  [3] https://www.primelands.lk/land/BORALESGAMUWA-THE-GROVE/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/BORALESGAMUWA-TH
#  [3] https://www.primelands.lk/land/PRIME-NEST-KAHATHUDUWA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/PRIME-NEST-KAHAT
#  [3] https://www.primelands.lk/land/OREN-KAHATHUDUWA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/OREN-KAHATHUDUWA
#  [3] https://www.primelands.lk/land/WINTER-STORY-KANDAPOLA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/WINTER-STORY-KAN
#  [3] https://www.primelands.lk/land/TOWN-AVENUE-ATHURUGIRIYA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/TOWN-AVENUE-ATHU
#  [3] https://www.primelands.lk/land/PRIME-FIELD-BREEZE/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/PRIME-FIELD-BREE
#  [3] https://www.primelands.lk/land/GOLDEN-FIELD-HABARAKADA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/GOLDEN-FIELD-HAB
#  [3] https://www.primelands.lk/land/ATHURUGIRIYA-RADIANCE-GARDEN/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/ATHURUGIRIYA-RAD
#  [3] https://www.primelands.lk/land/CAPITAL-POINT-GAMPAHA/tam
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/CAPITAL-POINT-GA
#  [3] https://www.primelands.lk/land/NITTAMBUWA-IMPERIUM/tam
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/NITTAMBUWA-IMPER
#  [3] https://www.primelands.lk/land/CAZELLE-WATTALA/en
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/CAZELLE-WATTALA/
#  [3] https://www.primelands.lk/land/PRIME-ZONE-5/tam
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/PRIME-ZONE-5/tam
#  [3] https://www.primelands.lk/land/PRIME-ARUNALU-DIVULAPITIYA/en
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/PRIME-ARUNALU-DI
#  [3] https://www.primelands.lk/land/PRIME-ATRIUM-KADAWATHA/en
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/PRIME-ATRIUM-KAD
#  [3] https://www.primelands.lk/land/PRIME-LIFE-2/en
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/PRIME-LIFE-2/en"
#  [3] https://www.primelands.lk/land/PREMIER-RADDOLUGAMA/en
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/PREMIER-RADDOLUG
#  [3] https://www.primelands.lk/land/WATTALA-QUEENS-AVENUE-2/en
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/land/WATTALA-QUEENS-A
#  [3] https://www.primelands.lk/house/PRIME-EVOKE/tam
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/house/PRIME-EVOKE/tam
#  [3] https://www.primelands.lk/house/PRIME-EVOKE/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/house/PRIME-EVOKE/sin
#  [3] https://www.primelands.lk/house/PRIME-LIFE-KADAWATHA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/house/PRIME-LIFE-KADA
#  [3] https://www.primelands.lk/house/PRIME-LIFE-KADAWATHA/tam
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/house/PRIME-LIFE-KADA
#  [3] https://www.primelands.lk/house/WATER-ESTATE-MORATUWA/tam
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/house/WATER-ESTATE-MO
#  [3] https://www.primelands.lk/house/WATER-ESTATE-MORATUWA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/house/WATER-ESTATE-MO
#  [3] https://www.primelands.lk/house/MAGNA-MATTEGODA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/house/MAGNA-MATTEGODA
#  [3] https://www.primelands.lk/house/MAGNA-MATTEGODA/tam
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/house/MAGNA-MATTEGODA
#  [3] https://www.primelands.lk/house/KOTTAWA-PRIME-URBAN-ART/tam
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/house/KOTTAWA-PRIME-U
#  [3] https://www.primelands.lk/house/KOTTAWA-PRIME-URBAN-ART/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/house/KOTTAWA-PRIME-U
#  [3] https://www.primelands.lk/house/PRIME-VILLAS-NUGEGODA/tam
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/house/PRIME-VILLAS-NU
#  [3] https://www.primelands.lk/house/PRIME-VILLAS-THALAWATHUGODA-WEERA-MAWATHA/tam
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/house/PRIME-VILLAS-TH
#  [3] https://www.primelands.lk/house/PRIME-VILLAS-THALAWATHUGODA-WEERA-MAWATHA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/house/PRIME-VILLAS-TH
#  [3] https://www.primelands.lk/house/PRIME-VILLAS-NUGEGODA/sin
#     Error: Page.goto: Page crashed
# Call log:
#   - navigating to "https://www.primelands.lk/house/PRIME-VILLAS-NU
#
#  Crawl complete in 18388.6s
#  Documents collected: 714
#  URLs visited: 1136

# %% [markdown]
# ### Save Outputs

# %%
# Save markdown files
for i, doc in enumerate(documents):
    url_path = urlparse(doc['url']).path.strip('/').replace('/', '_')
    if not url_path:
        url_path = "homepage"
    filename = f"{i:03d}_{url_path}.md"
    
    md_file = MARKDOWN_DIR / filename
    with open(md_file, 'w', encoding='utf-8') as f:
        f.write(f"# {doc['title']}\n\n")
        f.write(f"**URL**: {doc['url']}\n\n")
        f.write(f"**Depth**: {doc['depth_level']}\n\n")
        f.write("---\n\n")
        f.write(doc['content'])

print(f" Saved {len(documents)} markdown files to {MARKDOWN_DIR}")

# Save JSONL
with open(JSONL_PATH, 'w', encoding='utf-8') as f:
    for doc in documents:
        f.write(json.dumps(doc, ensure_ascii=False) + '\n')

print(f" Saved JSONL corpus to {JSONL_PATH}")
# Out:
#  Saved 714 markdown files to c:\Development\real-estate-intelligence-platform\data\primelands_markdown
#  Saved JSONL corpus to c:\Development\real-estate-intelligence-platform\data\primelands_docs.jsonl

# %% [markdown]
# ### Quality Checks

# %%
import random

print(" Quality Checks:\n")

# Check markdown files
md_files = list(MARKDOWN_DIR.glob("*.md"))
print(f"1  Markdown files: {len(md_files)}")

if len(md_files) >= 20:
    print(f"    Good! Got {len(md_files)} pages")
elif len(md_files) >= 10:
    print(f"     Only {len(md_files)} pages (site may be small)")
else:
    raise AssertionError(f" Too few pages: {len(md_files)}")

# Check JSONL
assert JSONL_PATH.exists(), f" JSONL not found"
print(f"\n2  JSONL file: {JSONL_PATH.stat().st_size:,} bytes")

# Sample inspection
with open(JSONL_PATH, 'r', encoding='utf-8') as f:
    all_docs = [json.loads(line) for line in f]

samples = random.sample(all_docs, min(3, len(all_docs)))
print(f"\n3  Random samples:\n")

for i, doc in enumerate(samples, 1):
    print(f"   Sample {i}:")
    print(f"   - URL: {doc['url']}")
    print(f"   - Title: {doc['title']}")
    print(f"   - Words: {len(doc['content'].split())}")
    print()

print(" All quality checks passed!")
# Out:
#  Quality Checks:
#
# 1  Markdown files: 714
#     Good! Got 714 pages
#
# 2  JSONL file: 2,724,992 bytes
#
# 3  Random samples:
#
#    Sample 1:
#    - URL: https://www.primelands.lk/portfolio-property/city/Anuradhapura/tam
#    - Title: Land Sales In Sri Lanka | Prime Lands
#    - Words: 14
#
#    Sample 2:
#    - URL: https://www.primelands.lk/land/district/Matara/sin
#    - Title: Land for sale in Matara | Prime Lands
#    - Words: 18
#
#    Sample 3:
#    - URL: https://www.primelands.lk/land/city/Minuwangoda/en
#    - Title: Minuwangoda Lands in Sri Lanka
#    - Words: 14
#
#  All quality checks passed!
