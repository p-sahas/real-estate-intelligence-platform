# %% [markdown]
# ### Setup & Installations

# %%
import sys
# if "google.colab" in sys.modules or True:
#     print(" Installing required packages...")
#     %pip install -q playwright>=1.40.0 python-dotenv>=1.0.0 beautifulsoup4>=4.12.0 markdownify>=0.11.6 nest-asyncio>=1.5.0
    
#     # Install Playwright browsers
#     print(" Installing Playwright browsers...")
#     import subprocess
#     subprocess.run([sys.executable, "-m", "playwright", "install", "chromium"], check=True, capture_output=True)

# print(" Packages ready")

# %% [markdown]
# ### Imports & Environment Setup

# %%
import os
import sys
import json
import time
from pathlib import Path
from urllib.parse import urlparse
from dotenv import load_dotenv
import nest_asyncio

# Enable nested asyncio
nest_asyncio.apply()

# Add project root to path
project_root = Path.cwd().parent
sys.path.insert(0, str(project_root / "src"))

# Load environment
load_dotenv(project_root / ".env")

# Check for API key (OpenRouter preferred, OpenAI as fallback)
openrouter_key = os.getenv("OPENROUTER_API_KEY")
groq_key = os.getenv("GROQ_API_KEY")

if not openrouter_key and not groq_key:
    raise EnvironmentError(
        " No API key found!\n"
        " Add OPENROUTER_API_KEY (recommended) or GROQ_API_KEY to .env"
    )

provider = "OpenRouter" if openrouter_key else "OpenAI"
print(" Environment loaded")
print(f" Provider: {provider}")
print(f" Project root: {project_root}")
# Out:
#  Environment loaded
#  Provider: OpenRouter
#  Project root: c:\Development\real-estate-intelligence-platform

# %% [markdown]
# ### Load Configuration

# %%
from context_engineering.config import (validate, dump, CRAWL_OUT_DIR, MARKDOWN_DIR)

# Validate and display config
try:
    validate()
    dump()
except Exception as e:
    print(f"  Config note: {e}")

# Ensure directories exist
MARKDOWN_DIR.mkdir(parents=True, exist_ok=True)

print(f"\n Output directories ready:")
print(f"   - Markdown: {MARKDOWN_DIR}")
print(f"   - JSONL: {CRAWL_OUT_DIR}")
# Out:
# ============================================================
# CONFIGURATION (NON-SECRETS ONLY)
# ============================================================
#
#  Provider:
#    Provider: openrouter
#    Model Tier: general
#    Chat Model: openai/gpt-4o-mini
#    Embedding Model: openai/text-embedding-3-large
#
#  Directories:
#    Data Root: c:\Development\real-estate-intelligence-platform\data
#    Vector Store: c:\Development\real-estate-intelligence-platform\data\vectorstore
#    Markdown: c:\Development\real-estate-intelligence-platform\data\primelands_markdown
#    Cache: c:\Development\real-estate-intelligence-platform\data\cag_cache
#
#  Chunking:
#    Fixed Size: 800 tokens
#    Fixed Overlap: 100 tokens
#    Sliding Window: 512 tokens
#    Sliding Stride: 256 tokens
#    Parent-Child: 250 → 1200 tokens
#    Late Chunk: 1000 → 300 tokens
#
#  Retrieval:
#    Top-K Results: 4
#    Similarity Threshold: 0.7
#
#  CAG:
#    Cache TTL: 86400s
#    Max Cache Size: 1000
#
#  CRAG:
#    Confidence Threshold: 0.6
#    Expanded K: 8
#
# ============================================================
#
#
#  Output directories ready:
#    - Markdown: c:\Development\real-estate-intelligence-platform\data\primelands_markdown
#    - JSONL: c:\Development\real-estate-intelligence-platform\data

# %%
# Crawl Configuration
BASE_URL = "https://www.primelands.lk"

START_PATHS = [
    "/", "/portfolio-property", "/land", "/house",
    "/apartment/ongoing", "/upcoming-projects", "/about-us",
    "sell-your-land", "/contact-us", "/services",
     "/testimonial", "/careers", "/news",
    "/online-publications", "/blog", "/virtual-tour", 
    "/kyc", "/terms-and-conditions", "/privacy-policy"
]

START_URLS = [BASE_URL + path for path in START_PATHS]

INCLUDE_PATTERNS = [
    r'/house/', r'/apartment/', r'/land/', r'/commercial/',
    r'/villa/', r'/condo/', r'/penthouse/',
    r'/property/', r'/listing/', r'/sale/', r'/rent/'
]

EXCLUDE_PATTERNS = [
    "/login", "/terms", "/privacy", "/admin",
    "/images/", "/downloads/", "/media/", "/sin", 
    "/tam", "/uploads/", "/downloads/", "/pdf/",
    ".webp", ".mp4", ".jpg", ".jpeg",
     ".png", ".css", ".js"
]

MAX_DEPTH = 5
REQUEST_DELAY = 2.0
JSONL_PATH = CRAWL_OUT_DIR / "primelands_docs.jsonl"

print(f" Crawl config:")
print(f"   - Start URLs: {len(START_URLS)}")
print(f"   - Max depth: {MAX_DEPTH}")
print(f"   - Request delay: {REQUEST_DELAY}s")
# Out:
#  Crawl config:
#    - Start URLs: 19
#    - Max depth: 5
#    - Request delay: 2.0s

# %% [markdown]
# ### Import Crawler Service
#
# Using `PrimeLandCrawler` from application layer

# %%
# Import Web Crawler Service
from context_engineering.application.ingest_documents_service import PrimeLandWebCrawler

print(" PrimeLandWebCrawler loaded from service layer")
print(" Location: context_engineering.application.ingest_documents_service.web_crawler")
# Out:
#  PrimeLandWebCrawler loaded from service layer
#  Location: context_engineering.application.ingest_documents_service.web_crawler

# %%
# Run Crawl with Service
import asyncio
from concurrent.futures import ThreadPoolExecutor

start_time = time.time()

# Initialize crawler service
crawler = PrimeLandWebCrawler(
    base_url=BASE_URL,
    max_depth=MAX_DEPTH,
    exclude_patterns=EXCLUDE_PATTERNS,
    include_patterns=INCLUDE_PATTERNS
)

def run_crawler_thread():
    # 1. Set Proactor policy (required for Playwright on Windows)
    asyncio.set_event_loop_policy(asyncio.WindowsProactorEventLoopPolicy())
    
    # 2. Create a new event loop for this thread
    loop = asyncio.new_event_loop()
    asyncio.set_event_loop(loop)
    
    try:
        # 3. Process the async crawl directly on this loop
        return loop.run_until_complete(crawler.crawl_async(START_URLS, request_delay=REQUEST_DELAY))
    finally:
        loop.close()

print(f"\n Starting crawl at {time.strftime('%H:%M:%S')}\n")

# Run in a separate thread to avoid conflict with Jupyter's running loop
with ThreadPoolExecutor(max_workers=1) as executor:
    future = executor.submit(run_crawler_thread)
    documents = future.result()

elapsed = time.time() - start_time
print(f"\n Crawl complete in {elapsed:.1f}s")
print(f" Documents collected: {len(documents)}")
print(f" URLs visited: {len(crawler.visited)}")
# Out:
#  Starting crawl at 19:38:57
#
#  [0] https://www.primelands.lk/
#      Skipped (does not match include patterns)
#     Added 40 new URLs to queue (depth 1)
#    Progress: 0 docs saved, 1 visited, 58 in queue
#  [0] https://www.primelands.lk/portfolio-property
#      Skipped (does not match include patterns)
#    Progress: 0 docs saved, 2 visited, 57 in queue
#  [0] https://www.primelands.lk/land
#      Skipped (does not match include patterns)
#     Added 55 new URLs to queue (depth 1)
#    Progress: 0 docs saved, 3 visited, 111 in queue
#  [0] https://www.primelands.lk/house
#      Skipped (does not match include patterns)
#     Added 14 new URLs to queue (depth 1)
#    Progress: 0 docs saved, 4 visited, 124 in queue
#  [0] https://www.primelands.lk/apartment/ongoing
#     Saved (124 chars, 0 links found)
#    Progress: 1 docs saved, 5 visited, 123 in queue
#  [0] https://www.primelands.lk/upcoming-projects
#      Skipped (does not match include patterns)
#    Progress: 1 docs saved, 6 visited, 122 in queue
#  [0] https://www.primelands.lk/about-us
#      Skipped (does not match include patterns)
#    Progress: 1 docs saved, 7 visited, 121 in queue
#  [0] https://www.primelands.lksell-your-land
#      Page not found (404) - skipping
#  [0] https://www.primelands.lk/contact-us
#     Error: Page.goto: Navigation to "https://www.primelands.lk/contact-us" is interrupted by another navigation
#  [0] https://www.primelands.lk/services
#     Error: Page.goto: Navigation to "https://www.primelands.lk/services" is interrupted by another navigation t
#  [0] https://www.primelands.lk/testimonial
#     Error: Page.goto: Navigation to "https://www.primelands.lk/testimonial" is interrupted by another navigatio
#  [0] https://www.primelands.lk/careers
#      Skipped (does not match include patterns)
#    Progress: 1 docs saved, 12 visited, 116 in queue
#  [0] https://www.primelands.lk/news
#      Skipped (does not match include patterns)
#    Progress: 1 docs saved, 13 visited, 115 in queue
#  [0] https://www.primelands.lk/online-publications
#      Skipped (does not match include patterns)
#    Progress: 1 docs saved, 14 visited, 114 in queue
#  [0] https://www.primelands.lk/blog
#      Skipped (does not match include patterns)
#    Progress: 1 docs saved, 15 visited, 113 in queue
#  [0] https://www.primelands.lk/virtual-tour
#      Skipped (does not match include patterns)
#    Progress: 1 docs saved, 16 visited, 112 in queue
#  [0] https://www.primelands.lk/kyc
#      Skipped (does not match include patterns)
#    Progress: 1 docs saved, 17 visited, 111 in queue
#  [1] https://www.primelands.lk/portfolio-property/ELLA-NUWARA-ELIYA/en
#      Skipped (does not match include patterns)
#     Added 1 new URLs to queue (depth 2)
#    Progress: 1 docs saved, 18 visited, 109 in queue
#  [1] https://www.primelands.lk/house/KAHATHUDUWA-88-RESIDENCE/en
#     Saved (18654 chars, 6 links found)
#     Added 1 new URLs to queue (depth 2)
#    Progress: 2 docs saved, 19 visited, 109 in queue
#  [1] https://www.primelands.lk/apartment/THE-REFLECTION-SAMAGI-MAWATHA-THALAWATHUGODA/en
#     Saved (14285 chars, 4 links found)
#    Progress: 3 docs saved, 20 visited, 108 in queue
#  [1] https://www.primelands.lk/house/CEST-LA-VIE-THALAWATHUGODA/en
#     Saved (18687 chars, 7 links found)
#    Progress: 4 docs saved, 21 visited, 107 in queue
#  [1] https://www.primelands.lk/land/GREEN-CREST-HORANA/en
#     Saved (12230 chars, 4 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 5 docs saved, 22 visited, 108 in queue
#  [1] https://www.primelands.lk/house/THALAWATHUGODA-CLOVER/en
#     Saved (23100 chars, 7 links found)
#    Progress: 6 docs saved, 23 visited, 107 in queue
#  [1] https://www.primelands.lk/land/LUXCORE-CITY-MALABE/en
#     Saved (13229 chars, 7 links found)
#     Added 6 new URLs to queue (depth 2)
#    Progress: 7 docs saved, 24 visited, 112 in queue
#  [1] https://www.primelands.lk/news/99/Prime-Melwa-Acquire-4-Acres-of-Premium-Waterfront-Land-in-Port-City-Colombo-for-USD-576Mn/en
#      Skipped (does not match include patterns)
#     Added 6 new URLs to queue (depth 2)
#    Progress: 7 docs saved, 25 visited, 117 in queue
#  [1] https://www.primelands.lk/house/DIGANA-SCOTTISH-ISLAND/en
#     Saved (16658 chars, 5 links found)
#    Progress: 8 docs saved, 26 visited, 116 in queue
#  [1] https://www.primelands.lk/land/AURELIA-ALUBOMULLA/en
#     Saved (10822 chars, 7 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 9 docs saved, 27 visited, 119 in queue
#  [1] https://www.primelands.lk/house/en
#     Saved (14040 chars, 22 links found)
#    Progress: 10 docs saved, 28 visited, 118 in queue
#  [1] https://www.primelands.lk/news/94/Prime-Group-builds-nations-most-connected-property-experience-with-firstofitskind-technology-ecosystem/en
#      Skipped (does not match include patterns)
#    Progress: 10 docs saved, 29 visited, 117 in queue
#  [1] https://www.primelands.lk/land/ADORA-NAIWALA/en
#     Saved (12539 chars, 6 links found)
#     Added 5 new URLs to queue (depth 2)
#    Progress: 11 docs saved, 30 visited, 121 in queue
#  [1] https://www.primelands.lk/portfolio-property/ALUTHGAMA-WELIPENNA/en
#      Skipped (does not match include patterns)
#    Progress: 11 docs saved, 31 visited, 120 in queue
#  [1] https://www.primelands.lk/house/DALUGAMA-PRIME-VILLAS/en
#     Saved (22564 chars, 5 links found)
#    Progress: 12 docs saved, 32 visited, 119 in queue
#  [1] https://www.primelands.lk/apartment/THE-GOLF-COLOMBO-08/en
#     Saved (12756 chars, 3 links found)
#     Added 1 new URLs to queue (depth 2)
#    Progress: 13 docs saved, 33 visited, 119 in queue
#  [1] https://www.primelands.lk/apartment/SKYE-BLOSSOM-KOTTAWA/en
#     Saved (14325 chars, 3 links found)
#    Progress: 14 docs saved, 34 visited, 118 in queue
#  [1] https://www.primelands.lk/portfolio-property/GALLE-HAPUGALA/en
#      Skipped (does not match include patterns)
#    Progress: 14 docs saved, 35 visited, 117 in queue
#  [1] https://www.primelands.lk/about-us/en
#      Skipped (does not match include patterns)
#     Added 21 new URLs to queue (depth 2)
#    Progress: 14 docs saved, 36 visited, 137 in queue
#  [1] https://www.primelands.lk/apartment/YOLO-KIRIBATHGODA/en
#     Saved (25946 chars, 3 links found)
#     Added 1 new URLs to queue (depth 2)
#    Progress: 15 docs saved, 37 visited, 137 in queue
#  [1] https://www.primelands.lk/house/GAMPAHA-ELEMINT-SUITES/en
#     Saved (16069 chars, 5 links found)
#    Progress: 16 docs saved, 38 visited, 136 in queue
#  [1] https://www.primelands.lk/land/LUXE-THALAHENA/en
#     Saved (10199 chars, 5 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 17 docs saved, 39 visited, 138 in queue
#  [1] https://www.primelands.lk/land/LUXORA-KIRIBATHGODA/en
#     Saved (14922 chars, 6 links found)
#    Progress: 18 docs saved, 40 visited, 137 in queue
#  [1] https://www.primelands.lk/apartment/MON-VIE-COLOMBO-05/en
#     Saved (15300 chars, 3 links found)
#    Progress: 19 docs saved, 41 visited, 136 in queue
#  [1] https://www.primelands.lk/portfolio-property/WARIYAPOLA-KURUNEGALA/en
#      Skipped (does not match include patterns)
#    Progress: 19 docs saved, 42 visited, 135 in queue
#  [1] https://www.primelands.lk/news/en
#      Skipped (does not match include patterns)
#    Progress: 19 docs saved, 43 visited, 134 in queue
#  [1] https://www.primelands.lk/news/97/Prime-Group-Stands-with-the-Children-of-Police-Families-Affected-by-Cyclone-Ditwah/en
#      Skipped (does not match include patterns)
#    Progress: 19 docs saved, 44 visited, 133 in queue
#  [1] https://www.primelands.lk/apartment/en
#     Saved (13575 chars, 19 links found)
#     Added 10 new URLs to queue (depth 2)
#    Progress: 20 docs saved, 45 visited, 142 in queue
#  [1] https://www.primelands.lk/house/VIVA-LA-VIDA-KOTTAWA/en
#     Saved (26267 chars, 7 links found)
#    Progress: 21 docs saved, 46 visited, 141 in queue
#  [1] https://www.primelands.lk/land/en
#     Saved (18943 chars, 63 links found)
#    Progress: 22 docs saved, 47 visited, 140 in queue
#  [1] https://www.primelands.lk/house/THE-RESIDENCE-SAMAGI-MAWATHA-THALAWATHUGODA/en
#     Saved (14562 chars, 5 links found)
#    Progress: 23 docs saved, 48 visited, 139 in queue
#  [1] https://www.primelands.lk/apartment/VENEZIA-NEGOMBO/en
#     Saved (21887 chars, 3 links found)
#    Progress: 24 docs saved, 49 visited, 138 in queue
#  [1] https://www.primelands.lk/news/93/Prime-Group-makes-history-with-Sri-Lankas-first-luxury-real-estate-client-experience-initiative-Prime-Premier/en
#      Skipped (does not match include patterns)
#    Progress: 24 docs saved, 50 visited, 137 in queue
#  [1] https://www.primelands.lk/land/ELITE-AVENUE-KAHATHUDUWA/en
#     Saved (11764 chars, 4 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 25 docs saved, 51 visited, 138 in queue
#  [1] https://www.primelands.lk/portfolio-property/KALUTARA-NAGODA/en
#      Skipped (does not match include patterns)
#    Progress: 25 docs saved, 52 visited, 137 in queue
#  [1] https://www.primelands.lk/apartment/THE-SEASONS-COLOMBO-08/en
#     Saved (14096 chars, 2 links found)
#    Progress: 26 docs saved, 53 visited, 136 in queue
#  [1] https://www.primelands.lk/apartment/J-ADORE-NEGOMBO/en
#     Saved (18369 chars, 3 links found)
#    Progress: 27 docs saved, 54 visited, 135 in queue
#  [1] https://www.primelands.lk/portfolio-property/MATARA-WELIGAMA/en
#      Skipped (does not match include patterns)
#    Progress: 27 docs saved, 55 visited, 134 in queue
#  [1] https://www.primelands.lk/land/EVARA-NAWALAPITIYA/en
#     Saved (10173 chars, 6 links found)
#     Added 5 new URLs to queue (depth 2)
#    Progress: 28 docs saved, 56 visited, 138 in queue
#  [1] https://www.primelands.lk/news/98/Prime-Group-Expands-Its-Footprint-to-Elevate-Customer-Experience-and-Reinforce-Its-Commitment-to-Excellence-with-the-Launch-of-the-Kalutara-Branch/en
#      Skipped (does not match include patterns)
#    Progress: 28 docs saved, 57 visited, 137 in queue
#  [1] https://www.primelands.lk/close-to-railway-stations/en
#      Skipped (does not match include patterns)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 28 docs saved, 58 visited, 140 in queue
#  [1] https://www.primelands.lk/land/GREATE-10-GALLE/en
#     Saved (9919 chars, 5 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 29 docs saved, 59 visited, 142 in queue
#  [1] https://www.primelands.lk/land/city/Nuwara-Eliya/en
#     Saved (18835 chars, 66 links found)
#     Added 5 new URLs to queue (depth 2)
#    Progress: 30 docs saved, 60 visited, 146 in queue
#  [1] https://www.primelands.lk/commercial/en
#     Saved (20975 chars, 67 links found)
#     Added 6 new URLs to queue (depth 2)
#    Progress: 31 docs saved, 61 visited, 151 in queue
#  [1] https://www.primelands.lk/land/city/Panadura/en
#     Saved (18780 chars, 65 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 32 docs saved, 62 visited, 154 in queue
#  [1] https://www.primelands.lk/land/district/Matara/en
#     Saved (18899 chars, 67 links found)
#     Added 5 new URLs to queue (depth 2)
#    Progress: 33 docs saved, 63 visited, 158 in queue
#  [1] https://www.primelands.lk/mountain-view/en
#      Skipped (does not match include patterns)
#    Progress: 33 docs saved, 64 visited, 157 in queue
#  [1] https://www.primelands.lk/land/district/Kegalle/en
#     Saved (18245 chars, 62 links found)
#     Added 1 new URLs to queue (depth 2)
#    Progress: 34 docs saved, 65 visited, 157 in queue
#  [1] https://www.primelands.lk/land/district/Kalutara/en
#     Saved (18947 chars, 64 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 35 docs saved, 66 visited, 159 in queue
#  [1] https://www.primelands.lk/land/city/Malabe/en
#     Saved (18857 chars, 66 links found)
#     Added 5 new URLs to queue (depth 2)
#    Progress: 36 docs saved, 67 visited, 163 in queue
#  [1] https://www.primelands.lk/land/city/Kurunegala/en
#     Saved (18932 chars, 67 links found)
#     Added 5 new URLs to queue (depth 2)
#    Progress: 37 docs saved, 68 visited, 167 in queue
#  [1] https://www.primelands.lk/land/city/Embilipitiya/en
#     Saved (18836 chars, 66 links found)
#     Added 5 new URLs to queue (depth 2)
#    Progress: 38 docs saved, 69 visited, 171 in queue
#  [1] https://www.primelands.lk/land/city/Minuwangoda/en
#     Saved (18640 chars, 65 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 39 docs saved, 70 visited, 174 in queue
#  [1] https://www.primelands.lk/land/city/Moratuwa/en
#     Saved (18631 chars, 65 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 40 docs saved, 71 visited, 176 in queue
#  [1] https://www.primelands.lk/land/city/Gampaha/en
#     Saved (18662 chars, 64 links found)
#     Added 1 new URLs to queue (depth 2)
#    Progress: 41 docs saved, 72 visited, 176 in queue
#  [1] https://www.primelands.lk/land/city/Homagama/en
#     Saved (18946 chars, 67 links found)
#    Progress: 42 docs saved, 73 visited, 175 in queue
#  [1] https://www.primelands.lk/land/city/Negombo/en
#     Saved (18733 chars, 66 links found)
#     Added 5 new URLs to queue (depth 2)
#    Progress: 43 docs saved, 74 visited, 179 in queue
#  [1] https://www.primelands.lk/down-south-lands/en
#      Skipped (does not match include patterns)
#    Progress: 43 docs saved, 75 visited, 178 in queue
#  [1] https://www.primelands.lk/land/city/Matara/en
#     Saved (18639 chars, 65 links found)
#    Progress: 44 docs saved, 76 visited, 177 in queue
#  [1] https://www.primelands.lk/agriculture-land/en
#      Skipped (does not match include patterns)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 44 docs saved, 77 visited, 178 in queue
#  [1] https://www.primelands.lk/land/district/Hambantota/en
#     Saved (18370 chars, 63 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 45 docs saved, 78 visited, 179 in queue
#  [1] https://www.primelands.lk/land/city/Kandy/en
#     Saved (18991 chars, 66 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 46 docs saved, 79 visited, 180 in queue
#  [1] https://www.primelands.lk/land/NEXUS-TOWN-ALUTHGAMA/en
#     Saved (12038 chars, 7 links found)
#     Added 1 new URLs to queue (depth 2)
#    Progress: 47 docs saved, 80 visited, 180 in queue
#  [1] https://www.primelands.lk/land/district/Ratnapura/en
#     Saved (18975 chars, 67 links found)
#     Added 1 new URLs to queue (depth 2)
#    Progress: 48 docs saved, 81 visited, 180 in queue
#  [1] https://www.primelands.lk/land/city/Artigala/en
#     Saved (18795 chars, 66 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 49 docs saved, 82 visited, 183 in queue
#  [1] https://www.primelands.lk/coconut-land/en
#      Skipped (does not match include patterns)
#    Progress: 49 docs saved, 83 visited, 182 in queue
#  [1] https://www.primelands.lk/land/district/Colombo/en
#     Saved (21712 chars, 63 links found)
#     Added 1 new URLs to queue (depth 2)
#    Progress: 50 docs saved, 84 visited, 182 in queue
#  [1] https://www.primelands.lk/land/city/Thalawathugoda/en
#     Saved (18543 chars, 64 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 51 docs saved, 85 visited, 183 in queue
#  [1] https://www.primelands.lk/close-to-highways/en
#      Skipped (does not match include patterns)
#    Progress: 51 docs saved, 86 visited, 182 in queue
#  [1] https://www.primelands.lk/land/ZENZA-GANEMULLA/en
#     Saved (10854 chars, 7 links found)
#     Added 1 new URLs to queue (depth 2)
#    Progress: 52 docs saved, 87 visited, 182 in queue
#  [1] https://www.primelands.lk/residential/en
#      Skipped (does not match include patterns)
#    Progress: 52 docs saved, 88 visited, 181 in queue
#  [1] https://www.primelands.lk/land/city/Veyangoda/en
#     Saved (18790 chars, 66 links found)
#     Added 5 new URLs to queue (depth 2)
#    Progress: 53 docs saved, 89 visited, 185 in queue
#  [1] https://www.primelands.lk/land/city/Anuradhapura/en
#     Saved (18959 chars, 67 links found)
#     Added 5 new URLs to queue (depth 2)
#    Progress: 54 docs saved, 90 visited, 189 in queue
#  [1] https://www.primelands.lk/waterfront-land/en
#      Skipped (does not match include patterns)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 54 docs saved, 91 visited, 191 in queue
#  [1] https://www.primelands.lk/land/district/Nuwara-Eliya/en
#     Saved (22741 chars, 67 links found)
#     Added 1 new URLs to queue (depth 2)
#    Progress: 55 docs saved, 92 visited, 191 in queue
#  [1] https://www.primelands.lk/close-to-Airport/en
#      Skipped (does not match include patterns)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 55 docs saved, 93 visited, 192 in queue
#  [1] https://www.primelands.lk/land/city/Horana/en
#     Saved (18957 chars, 66 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 56 docs saved, 94 visited, 195 in queue
#  [1] https://www.primelands.lk/land/city/Kahathuduwa/en
#     Saved (18816 chars, 64 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 57 docs saved, 95 visited, 196 in queue
#  [1] https://www.primelands.lk/land/district/Galle/en
#     Saved (18992 chars, 67 links found)
#    Progress: 58 docs saved, 96 visited, 195 in queue
#  [1] https://www.primelands.lk/land/DENVER-KAHATHUDUWA/en
#     Saved (12077 chars, 5 links found)
#     Added 1 new URLs to queue (depth 2)
#    Progress: 59 docs saved, 97 visited, 195 in queue
#  [1] https://www.primelands.lk/land/city/Kalutara/en
#     Saved (18931 chars, 67 links found)
#     Added 1 new URLs to queue (depth 2)
#    Progress: 60 docs saved, 98 visited, 195 in queue
#  [1] https://www.primelands.lk/land/city/Kottawa/en
#     Saved (18768 chars, 66 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 61 docs saved, 99 visited, 197 in queue
#  [1] https://www.primelands.lk/close-to-ancient-city-lands/en
#      Skipped (does not match include patterns)
#     Added 1 new URLs to queue (depth 2)
#    Progress: 61 docs saved, 100 visited, 197 in queue
#  [1] https://www.primelands.lk/land/district/Anuradhapura/en
#     Saved (19014 chars, 67 links found)
#     Added 1 new URLs to queue (depth 2)
#    Progress: 62 docs saved, 101 visited, 197 in queue
#  [1] https://www.primelands.lk/land/district/Kurunegala/en
#     Saved (19026 chars, 67 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 63 docs saved, 102 visited, 198 in queue
#  [1] https://www.primelands.lk/land/city/Galle/en
#     Saved (18905 chars, 67 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 64 docs saved, 103 visited, 200 in queue
#  [1] https://www.primelands.lk/land/district/Matale/en
#     Saved (18511 chars, 64 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 65 docs saved, 104 visited, 202 in queue
#  [1] https://www.primelands.lk/land/city/Meegoda/en
#     Saved (18505 chars, 64 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 66 docs saved, 105 visited, 204 in queue
#  [1] https://www.primelands.lk/land/district/Gampaha/en
#     Saved (18951 chars, 65 links found)
#    Progress: 67 docs saved, 106 visited, 203 in queue
#  [1] https://www.primelands.lk/paddy-field-facing-lands/en
#      Skipped (does not match include patterns)
#     Added 1 new URLs to queue (depth 2)
#    Progress: 67 docs saved, 107 visited, 203 in queue
#  [1] https://www.primelands.lk/land/district/Kandy/en
#     Saved (21573 chars, 66 links found)
#    Progress: 68 docs saved, 108 visited, 202 in queue
#  [1] https://www.primelands.lk/land/city/Kadawatha/en
#     Saved (18976 chars, 67 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 69 docs saved, 109 visited, 203 in queue
#  [1] https://www.primelands.lk/land/city/Athurugiriya/en
#     Saved (20312 chars, 65 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 70 docs saved, 110 visited, 206 in queue
#  [1] https://www.primelands.lk/land/city/Kiribathgoda/en
#     Saved (18807 chars, 65 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 71 docs saved, 111 visited, 209 in queue
#  [1] https://www.primelands.lk/up-country-lands/en
#      Skipped (does not match include patterns)
#    Progress: 71 docs saved, 112 visited, 208 in queue
#  [1] https://www.primelands.lk/house/district/Gampaha/en
#     Saved (12573 chars, 24 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 72 docs saved, 113 visited, 209 in queue
#  [1] https://www.primelands.lk/house/MALABE-WATERFALL-RESIDENCIES/en
#     Saved (17820 chars, 5 links found)
#    Progress: 73 docs saved, 114 visited, 208 in queue
#  [1] https://www.primelands.lk/house/district/Colombo/en
#     Saved (14055 chars, 22 links found)
#    Progress: 74 docs saved, 115 visited, 207 in queue
#  [1] https://www.primelands.lk/house/city/Gampaha/en
#     Saved (11698 chars, 22 links found)
#    Progress: 75 docs saved, 116 visited, 206 in queue
#  [1] https://www.primelands.lk/house/city/Moratuwa/en
#     Saved (11694 chars, 23 links found)
#     Added 1 new URLs to queue (depth 2)
#    Progress: 76 docs saved, 117 visited, 206 in queue
#  [1] https://www.primelands.lk/house/city/Kelaniya/en
#     Saved (11709 chars, 22 links found)
#    Progress: 77 docs saved, 118 visited, 205 in queue
#  [1] https://www.primelands.lk/house/city/Kadawatha/en
#     Saved (11686 chars, 24 links found)
#    Progress: 78 docs saved, 119 visited, 204 in queue
#  [1] https://www.primelands.lk/house/city/Nugegoda/en
#     Saved (13265 chars, 23 links found)
#     Added 1 new URLs to queue (depth 2)
#    Progress: 79 docs saved, 120 visited, 204 in queue
#  [1] https://www.primelands.lk/house/district/Kandy/en
#     Saved (13225 chars, 22 links found)
#    Progress: 80 docs saved, 121 visited, 203 in queue
#  [1] https://www.primelands.lk/house/city/Kottawa/en
#     Saved (12352 chars, 24 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 81 docs saved, 122 visited, 204 in queue
#  [1] https://www.primelands.lk/house/city/Malabe/en
#     Saved (13546 chars, 22 links found)
#    Progress: 82 docs saved, 123 visited, 203 in queue
#  [1] https://www.primelands.lk/house/city/Piliyandala/en
#     Saved (11720 chars, 22 links found)
#    Progress: 83 docs saved, 124 visited, 202 in queue
#  [1] https://www.primelands.lk/house/city/Kandy/en
#     Saved (11762 chars, 22 links found)
#    Progress: 84 docs saved, 125 visited, 201 in queue
#  [1] https://www.primelands.lk/house/city/Thalawathugoda/en
#     Saved (14718 chars, 23 links found)
#     Added 1 new URLs to queue (depth 2)
#    Progress: 85 docs saved, 126 visited, 201 in queue
#  [2] https://www.primelands.lk/portfolio-property/en
#      Skipped (does not match include patterns)
#     Added 33 new URLs to queue (depth 3)
#    Progress: 85 docs saved, 127 visited, 233 in queue
#  [2] https://www.primelands.lk/land/BANDARAGAMA-GREEN-PARADISE/en
#     Saved (18964 chars, 15 links found)
#     Added 4 new URLs to queue (depth 3)
#    Progress: 86 docs saved, 128 visited, 235 in queue
#  [2] https://www.primelands.lk/land/TEAL-KUMBUKA/en
#     Saved (11618 chars, 4 links found)
#    Progress: 87 docs saved, 129 visited, 234 in queue
#  [2] https://www.primelands.lk/land/VELASIS-HOMAGAMA/en
#     Saved (12824 chars, 5 links found)
#    Progress: 88 docs saved, 130 visited, 233 in queue
#  [2] https://www.primelands.lk/land/AURORA-HOMAGAMA/en
#     Saved (15442 chars, 6 links found)
#    Progress: 89 docs saved, 131 visited, 232 in queue
#  [2] https://www.primelands.lk/land/LUSH-DALE-HOMAGAMA/en
#     Saved (13458 chars, 7 links found)
#    Progress: 90 docs saved, 132 visited, 231 in queue
#  [2] https://www.primelands.lk/land/GREEN-EMBAZY-HOMAGAMA/en
#     Saved (15630 chars, 5 links found)
#    Progress: 91 docs saved, 133 visited, 230 in queue
#  [2] https://www.primelands.lk/land/FRUITS-BURY-ARTIGALA/en
#     Saved (12314 chars, 5 links found)
#    Progress: 92 docs saved, 134 visited, 229 in queue
#  [2] https://www.primelands.lk/land/ELENI-HOMAGAMA/en
#     Saved (27406 chars, 38 links found)
#     Added 8 new URLs to queue (depth 3)
#    Progress: 93 docs saved, 135 visited, 236 in queue
#  [2] https://www.primelands.lk/news/87/Prime-Lands-Recognized-as-Most-Innovative-Property-Developer-Sri-Lanka-2025-by-World-Economic-Magazine-Awards-USA/en
#      Skipped (does not match include patterns)
#    Progress: 93 docs saved, 136 visited, 235 in queue
#  [2] https://www.primelands.lk/news/89/Marking-a-Historic-Milestone-Prime-Group-and-FSLGA-seal-public-private-synergy-to-elevate-Local-Government-capacity-nationwide/en
#      Skipped (does not match include patterns)
#    Progress: 93 docs saved, 137 visited, 234 in queue
#  [2] https://www.primelands.lk/news/86/Prime-Group-unveils-innovative-Public-Private-collaboration-initiative-to-enhance-Government-service-excellence/en
#      Skipped (does not match include patterns)
#    Progress: 93 docs saved, 138 visited, 233 in queue
#  [2] https://www.primelands.lk/news/91/Prime-Group-launches-Prime-Edge-as-Sri-Lankas-first-all-in-one-real-estate-mobile-app/en
#      Skipped (does not match include patterns)
#    Progress: 93 docs saved, 139 visited, 232 in queue
#  [2] https://www.primelands.lk/news/88/Prime-Group-appoints-international-music-icon-Umaria-Sinhawansa-as-Global-Brand-Ambassador/en
#      Skipped (does not match include patterns)
#    Progress: 93 docs saved, 140 visited, 231 in queue
#  [2] https://www.primelands.lk/news/90/Prime-Groups-Legacy-in-Real-Estate-Featured-in-Kotlers-Essential-of-Modern-Marketing/en
#      Skipped (does not match include patterns)
#    Progress: 93 docs saved, 141 visited, 230 in queue
#  [2] https://www.primelands.lk/land/LILIUM-KALUTARA/en
#     Saved (11979 chars, 6 links found)
#    Progress: 94 docs saved, 142 visited, 229 in queue
#  [2] https://www.primelands.lk/land/ALUTHGAMA-REGAL-CITY/en
#     Saved (11914 chars, 5 links found)
#    Progress: 95 docs saved, 143 visited, 228 in queue
#  [2] https://www.primelands.lk/land/GREEN-HUB-KALUTARA/en
#     Saved (12639 chars, 5 links found)
#    Progress: 96 docs saved, 144 visited, 227 in queue
#  [2] https://www.primelands.lk/land/KALUTARA-NAGODA-NOVA/en
#     Saved (17703 chars, 15 links found)
#    Progress: 97 docs saved, 145 visited, 226 in queue
#  [2] https://www.primelands.lk/land/AVENLY-KADAWATHA/en
#     Saved (13630 chars, 6 links found)
#     Added 1 new URLs to queue (depth 3)
#    Progress: 98 docs saved, 146 visited, 226 in queue
#  [2] https://www.primelands.lk/land/LUANA-KADAWATHA/en
#     Saved (13468 chars, 7 links found)
#     Added 3 new URLs to queue (depth 3)
#    Progress: 99 docs saved, 147 visited, 228 in queue
#  [2] https://www.primelands.lk/land/GAMPAHA-THE-SEQUOR/en
#     Saved (13790 chars, 5 links found)
#    Progress: 100 docs saved, 148 visited, 227 in queue
#  [2] https://www.primelands.lk/land/GREEN-HIDE-YAKKALA/en
#     Saved (15130 chars, 5 links found)
#    Progress: 101 docs saved, 149 visited, 226 in queue
#  [2] https://www.primelands.lk/land/CALLISTO-KADAWATHA/en
#     Saved (15660 chars, 5 links found)
#    Progress: 102 docs saved, 150 visited, 225 in queue
#  [2] https://www.primelands.lk/apartment/THE-COLOMBO-BORDER-PELIYAGODA/en
#     Saved (21490 chars, 3 links found)
#    Progress: 103 docs saved, 151 visited, 224 in queue
#  [2] https://www.primelands.lk/news/55/Prime-Group-Strengthen-The-Financial-Stability-to-SL-A-Stable/en
#      Skipped (does not match include patterns)
#    Progress: 103 docs saved, 152 visited, 223 in queue
#  [2] https://www.primelands.lk/news/57/Prime-Group-Crowned-Most-Valuable-Real-Estate-Consumer-Brand-in-Sri-Lanka/en
#      Skipped (does not match include patterns)
#    Progress: 103 docs saved, 153 visited, 222 in queue
#  [2] https://www.primelands.lk/news/18/PRIME-GROUP-CROWNED-BEST-DEVELOPER-IN-SRI-LANKA-YET-AGAIN/en
#      Skipped (does not match include patterns)
#    Progress: 103 docs saved, 154 visited, 221 in queue
#  [2] https://www.primelands.lk/news/64/Prime-Wins-Gold-in-Land-and-Property-Sector-at-TAGS-Awards-2022/en
#      Skipped (does not match include patterns)
#    Progress: 103 docs saved, 155 visited, 220 in queue
#  [2] https://www.primelands.lk/news/79/Prime-Group-crowned-with-prestigious-Sri-Lanka-Best-Employer-Brand-Award-2024/en
#      Skipped (does not match include patterns)
#    Progress: 103 docs saved, 156 visited, 219 in queue
#  [2] https://www.primelands.lk/news/60/Prime-Group-Listed-Among-Asias-100-Best-Workplaces-in-the-SME-Category-for-2022-by-Great-Place-to-Work992/en
#      Skipped (does not match include patterns)
#    Progress: 103 docs saved, 157 visited, 218 in queue
#  [2] https://www.primelands.lk/news/61/Prime-Group-Wins-Two-Gold-Awards-for-Customer-Engagement/en
#      Skipped (does not match include patterns)
#    Progress: 103 docs saved, 158 visited, 217 in queue
#  [2] https://www.primelands.lk/news/12/GREAT-PLACE-TO-WORK-IN-SRI-LANKA-FOR-2017/en
#      Skipped (does not match include patterns)
#    Progress: 103 docs saved, 159 visited, 216 in queue
#  [2] https://www.primelands.lk/news/17/BEST-DEVELOPER-OF-SRI-LANKA-2018/en
#      Skipped (does not match include patterns)
#    Progress: 103 docs saved, 160 visited, 215 in queue
#  [2] https://www.primelands.lk/news/68/Prime-Group-Completes-its-Latest-Masterpiece-The-Grand-Ward-Place-a-Triumph-of-Sri-Lankan-Excellence/en
#      Skipped (does not match include patterns)
#    Progress: 103 docs saved, 161 visited, 214 in queue
#  [2] https://www.primelands.lk/news/21/PRIME-GROUPS-WEBSITE-CROWNED-AS-THE-BEST-CORPORATE-WEBSITE/en
#      Skipped (does not match include patterns)
#    Progress: 103 docs saved, 162 visited, 213 in queue
#  [2] https://www.primelands.lk/news/69/Prime-Group-to-soon-complete-the-only-Lifestyle-Apartment-Complex-in-Gampaha/en
#      Skipped (does not match include patterns)
#    Progress: 103 docs saved, 163 visited, 212 in queue
#  [2] https://www.primelands.lk/news/5/BEST-REAL-ESTATE-COMPANY/en
#      Skipped (does not match include patterns)
#    Progress: 103 docs saved, 164 visited, 211 in queue
#  [2] https://www.primelands.lk/news/8/GREAT-PLACE-TO-WORK-IN-SRI-LANKA-FOR-2016/en
#      Skipped (does not match include patterns)
#    Progress: 103 docs saved, 165 visited, 210 in queue
#  [2] https://www.primelands.lk/news/15/WOMAN-SUPER-ACHIEVER-OF-THE-YEAR-UNDER-REAL-ESTATE-SECTOR/en
#      Skipped (does not match include patterns)
#    Progress: 103 docs saved, 166 visited, 209 in queue
#  [2] https://www.primelands.lk/news/4/WCRC-LEADERS-ASIA-WE-AWARD---2014/en
#      Skipped (does not match include patterns)
#    Progress: 103 docs saved, 167 visited, 208 in queue
#  [2] https://www.primelands.lk/news/80/Prime-Lands-recognised-for-excellence-on-global-stage-with-double-wins-at-World-Business-Outlook-Awards 2024/en
#      Skipped (does not match include patterns)
#    Progress: 103 docs saved, 168 visited, 207 in queue
#  [2] https://www.primelands.lk/news/16/GREAT-PLACE-TO-WORK-2018/en
#      Skipped (does not match include patterns)
#    Progress: 103 docs saved, 169 visited, 206 in queue
#  [2] https://www.primelands.lk/news/76/Prime-Group-Relocates-Galle-Branch-to-Elevate-Customer-Experience-and-Reinforce-Commitment-to-Excellence/en
#      Skipped (does not match include patterns)
#    Progress: 103 docs saved, 170 visited, 205 in queue
#  [2] https://www.primelands.lk/news/24/ACEF-GLOBAL-CUSTOMER-ENGAGEMENT-AWARDS/en
#      Skipped (does not match include patterns)
#    Progress: 103 docs saved, 171 visited, 204 in queue
#  [2] https://www.primelands.lk/news/70/Prime-Lands-clinches-coveted-Gold-Award-for-elevated-online-presence-at-13th-BestWeblk-2023-Competition-for-02nd-Time/en
#      Skipped (does not match include patterns)
#    Progress: 103 docs saved, 172 visited, 203 in queue
#  [2] https://www.primelands.lk/apartment/GAMPAHA-THE-PALACE/en
#     Saved (12529 chars, 4 links found)
#    Progress: 104 docs saved, 173 visited, 202 in queue
#  [2] https://www.primelands.lk/land/PRIME-EXPRESS-FIVE-MATTEGODA/en
#     Saved (13679 chars, 6 links found)
#    Progress: 105 docs saved, 174 visited, 201 in queue
#  [2] https://www.primelands.lk/land/ZEAL-MALABE/en
#     Saved (7301 chars, 0 links found)
#    Progress: 106 docs saved, 175 visited, 200 in queue
#  [2] https://www.primelands.lk/land/ROOTS-THALAWATHUGODA/en
#     Saved (12923 chars, 5 links found)
#    Progress: 107 docs saved, 176 visited, 199 in queue
#  [2] https://www.primelands.lk/apartment/ongoing/city/Colombo/en
#     Saved (11778 chars, 18 links found)
#    Progress: 108 docs saved, 177 visited, 198 in queue
#  [2] https://www.primelands.lk/apartment/ongoing/city/Kottawa/en
#     Saved (10532 chars, 18 links found)
#    Progress: 109 docs saved, 178 visited, 197 in queue
#  [2] https://www.primelands.lk/apartment/ongoing/district/Galle/en
#     Saved (10568 chars, 19 links found)
#     Added 1 new URLs to queue (depth 3)
#    Progress: 110 docs saved, 179 visited, 197 in queue
#  [2] https://www.primelands.lk/apartment/ongoing/district/Gampaha/en
#     Saved (12318 chars, 19 links found)
#    Progress: 111 docs saved, 180 visited, 196 in queue
#  [2] https://www.primelands.lk/apartment/ongoing/city/Negombo/en
#     Saved (11095 chars, 18 links found)
#    Progress: 112 docs saved, 181 visited, 195 in queue
#  [2] https://www.primelands.lk/apartment/ongoing/city/Thalawathugoda/en
#     Saved (10675 chars, 18 links found)
#    Progress: 113 docs saved, 182 visited, 194 in queue
#  [2] https://www.primelands.lk/apartment/ongoing/city/Galle/en
#     Saved (9269 chars, 13 links found)
#     Added 3 new URLs to queue (depth 3)
#    Progress: 114 docs saved, 183 visited, 196 in queue
#  [2] https://www.primelands.lk/apartment/ongoing/district/Colombo/en
#     Saved (13061 chars, 18 links found)
#    Progress: 115 docs saved, 184 visited, 195 in queue
#  [2] https://www.primelands.lk/apartment/ongoing/en
#     Saved (13575 chars, 18 links found)
#    Progress: 116 docs saved, 185 visited, 194 in queue
#  [2] https://www.primelands.lk/apartment/ongoing/city/Kiribathgoda/en
#     Saved (11185 chars, 19 links found)
#    Progress: 117 docs saved, 186 visited, 193 in queue
#  [2] https://www.primelands.lk/land/ABODE-POINT-KAHATHUDUWA/en
#     Saved (13013 chars, 8 links found)
#    Progress: 118 docs saved, 187 visited, 192 in queue
#  [2] https://www.primelands.lk/land/HIGH-POINT-HOMAGAMA/en
#     Saved (13977 chars, 4 links found)
#    Progress: 119 docs saved, 188 visited, 191 in queue
#  [2] https://www.primelands.lk/land/LA-SIERRA-HADENIYA/en
#     Saved (12634 chars, 6 links found)
#     Added 1 new URLs to queue (depth 3)
#    Progress: 120 docs saved, 189 visited, 191 in queue
#  [2] https://www.primelands.lk/land/MOUNT-GATE-MADANA/en
#     Saved (10940 chars, 4 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 121 docs saved, 190 visited, 192 in queue
#  [2] https://www.primelands.lk/land/CELESTIA-PILIMATHALAWA/en
#     Saved (10066 chars, 4 links found)
#    Progress: 122 docs saved, 191 visited, 191 in queue
#  [2] https://www.primelands.lk/land/NILLAMBA-SATURDAY/en
#     Saved (14167 chars, 11 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 123 docs saved, 192 visited, 192 in queue
#  [2] https://www.primelands.lk/land/DELTOTA-MISTY-MOUNTAIN/en
#     Saved (13497 chars, 9 links found)
#    Progress: 124 docs saved, 193 visited, 191 in queue
#  [2] https://www.primelands.lk/land/GLORIA-STAGE-II-AHANGAMA/en
#     Saved (12252 chars, 3 links found)
#    Progress: 125 docs saved, 194 visited, 190 in queue
#  [2] https://www.primelands.lk/land/PRESTIGE-PLACE-KURUNEGALA/en
#     Saved (15516 chars, 9 links found)
#     Added 4 new URLs to queue (depth 3)
#    Progress: 126 docs saved, 195 visited, 193 in queue
#  [2] https://www.primelands.lk/land/MAJESTINO-MORATUWA/en
#     Saved (13240 chars, 4 links found)
#    Progress: 127 docs saved, 196 visited, 192 in queue
#  [2] https://www.primelands.lk/land/URBAN-PARK-ANURADHAPURA/en
#     Saved (11940 chars, 6 links found)
#     Added 1 new URLs to queue (depth 3)
#    Progress: 128 docs saved, 197 visited, 192 in queue
#  [2] https://www.primelands.lk/land/PRIME-ELITE-AMBALANGODA/en
#     Saved (8846 chars, 3 links found)
#    Progress: 129 docs saved, 198 visited, 191 in queue
#  [2] https://www.primelands.lk/land/SUN-CREST-HIKKADUWA/en
#     Saved (10279 chars, 5 links found)
#    Progress: 130 docs saved, 199 visited, 190 in queue
#  [2] https://www.primelands.lk/land/PRIME-LEGACY-ELPITIYA/en
#     Saved (8922 chars, 4 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 131 docs saved, 200 visited, 191 in queue
#  [2] https://www.primelands.lk/land/NUWARAELIYA-BLACKPOOL/en
#     Saved (11402 chars, 5 links found)
#    Progress: 132 docs saved, 201 visited, 190 in queue
#  [2] https://www.primelands.lk/land/NUWARAELIYA-THE-RIPPLES/en
#     Saved (11556 chars, 3 links found)
#    Progress: 133 docs saved, 202 visited, 189 in queue
#  [2] https://www.primelands.lk/land/MEEPILIMANA-URBAN-HILLS/en
#     Saved (11899 chars, 5 links found)
#    Progress: 134 docs saved, 203 visited, 188 in queue
#  [2] https://www.primelands.lk/land/RAMBODA-GLENLOCH/en
#     Saved (13552 chars, 4 links found)
#    Progress: 135 docs saved, 204 visited, 187 in queue
#  [2] https://www.primelands.lk/land/THE-MORNINGS-GIFT-PUNDALUOYA/en
#     Saved (13158 chars, 6 links found)
#    Progress: 136 docs saved, 205 visited, 186 in queue
#  [2] https://www.primelands.lk/land/EMERALD-FOREST-KURUNEGALA/en
#     Saved (12761 chars, 5 links found)
#     Added 1 new URLs to queue (depth 3)
#    Progress: 137 docs saved, 206 visited, 186 in queue
#  [2] https://www.primelands.lk/land/MATARA-THE-KINGDOM/en
#     Saved (16132 chars, 3 links found)
#    Progress: 138 docs saved, 207 visited, 185 in queue
#  [2] https://www.primelands.lk/land/LAKE-SHORE-2-BULALANKULAMA/en
#     Saved (11789 chars, 5 links found)
#    Progress: 139 docs saved, 208 visited, 184 in queue
#  [2] https://www.primelands.lk/land/BORALESGAMUWA-THE-GROVE/en
#     Saved (19074 chars, 20 links found)
#    Progress: 140 docs saved, 209 visited, 183 in queue
#  [2] https://www.primelands.lk/land/HABARADUWA-BLUE-SHORE/en
#     Saved (12119 chars, 5 links found)
#    Progress: 141 docs saved, 210 visited, 182 in queue
#  [2] https://www.primelands.lk/land/NEW-CITY-ARCADE-BINGIRIYA/en
#     Saved (13516 chars, 8 links found)
#    Progress: 142 docs saved, 211 visited, 181 in queue
#  [2] https://www.primelands.lk/land/HIRANA-GLEAMS-CREEK/en
#     Saved (18671 chars, 12 links found)
#    Progress: 143 docs saved, 212 visited, 180 in queue
#  [2] https://www.primelands.lk/land/APOLLO-PANADURA/en
#     Saved (9829 chars, 4 links found)
#    Progress: 144 docs saved, 213 visited, 179 in queue
#  [2] https://www.primelands.lk/land/VESPER-PANADURA/en
#     Saved (14526 chars, 7 links found)
#     Added 1 new URLs to queue (depth 3)
#    Progress: 145 docs saved, 214 visited, 179 in queue
#  [2] https://www.primelands.lk/land/AUTUMN-LUSTER-PANADURA/en
#     Saved (10855 chars, 4 links found)
#    Progress: 146 docs saved, 215 visited, 178 in queue
#  [2] https://www.primelands.lk/land/LAKE-FRONT-MAKAVITA/en
#     Saved (8346 chars, 0 links found)
#    Progress: 147 docs saved, 216 visited, 177 in queue
#  [2] https://www.primelands.lk/land/SUNREACH-MATARA/en
#     Saved (9796 chars, 3 links found)
#    Progress: 148 docs saved, 217 visited, 176 in queue
#  [2] https://www.primelands.lk/land/MAGNETISM-WELIGAMA/en
#     Saved (7676 chars, 0 links found)
#    Progress: 149 docs saved, 218 visited, 175 in queue
#  [2] https://www.primelands.lk/land/SHINE-VALLEY-DIKWELLA/en
#     Saved (6886 chars, 0 links found)
#    Progress: 150 docs saved, 219 visited, 174 in queue
#  [2] https://www.primelands.lk/land/SUNBAY-MATARA/en
#     Saved (11230 chars, 5 links found)
#    Progress: 151 docs saved, 220 visited, 173 in queue
#  [2] https://www.primelands.lk/land/NELUMDENIYA-LOTUS-AVENUE/en
#     Saved (6502 chars, 0 links found)
#    Progress: 152 docs saved, 221 visited, 172 in queue
#  [2] https://www.primelands.lk/land/REGAL-POINT-KALUTARA/en
#     Saved (12575 chars, 6 links found)
#    Progress: 153 docs saved, 222 visited, 171 in queue
#  [2] https://www.primelands.lk/land/KALUTARA-ARISTA/en
#     Saved (16482 chars, 16 links found)
#    Progress: 154 docs saved, 223 visited, 170 in queue
#  [2] https://www.primelands.lk/land/SPACE-HALTHOTA/en
#     Saved (11795 chars, 6 links found)
#    Progress: 155 docs saved, 224 visited, 169 in queue
#  [2] https://www.primelands.lk/land/ZENGARY-MALABE/en
#     Saved (9362 chars, 4 links found)
#    Progress: 156 docs saved, 225 visited, 168 in queue
#  [2] https://www.primelands.lk/land/PRIME-FINEST-MALABE/en
#     Saved (10150 chars, 3 links found)
#    Progress: 157 docs saved, 226 visited, 167 in queue
#  [2] https://www.primelands.lk/land/MAXIMUS-MALABE/en
#     Saved (10393 chars, 4 links found)
#    Progress: 158 docs saved, 227 visited, 166 in queue
#  [2] https://www.primelands.lk/land/ZENITH-MALABE/en
#     Saved (22995 chars, 31 links found)
#    Progress: 159 docs saved, 228 visited, 165 in queue
#  [2] https://www.primelands.lk/land/ELIRA-MALABE/en
#     Saved (9290 chars, 4 links found)
#    Progress: 160 docs saved, 229 visited, 164 in queue
#  [2] https://www.primelands.lk/land/KURUNEGALA-YOKE/en
#     Saved (14731 chars, 10 links found)
#    Progress: 161 docs saved, 230 visited, 163 in queue
#  [2] https://www.primelands.lk/land/KURUNEGALA-WEHERA/en
#     Saved (12064 chars, 5 links found)
#    Progress: 162 docs saved, 231 visited, 162 in queue
#  [2] https://www.primelands.lk/land/3RD-LANE-KURUNEGALA/en
#     Saved (11501 chars, 7 links found)
#    Progress: 163 docs saved, 232 visited, 161 in queue
#  [2] https://www.primelands.lk/land/WOODLAND-ESTATE-IV-KURUNEGALA/en
#     Saved (11651 chars, 5 links found)
#    Progress: 164 docs saved, 233 visited, 160 in queue
#  [2] https://www.primelands.lk/land/PRIME-KESHARA-ADAWIYA/en
#     Saved (10846 chars, 6 links found)
#    Progress: 165 docs saved, 234 visited, 159 in queue
#  [2] https://www.primelands.lk/land/EMBILIPITIYA-GREEN-EVOKE/en
#     Saved (14365 chars, 4 links found)
#    Progress: 166 docs saved, 235 visited, 158 in queue
#  [2] https://www.primelands.lk/land/PRIME-AVAKASHA-MIDDENIYA/en
#     Saved (9289 chars, 2 links found)
#    Progress: 167 docs saved, 236 visited, 157 in queue
#  [2] https://www.primelands.lk/land/CITY-DALE-GODAKAWELA/en
#     Saved (11595 chars, 4 links found)
#    Progress: 168 docs saved, 237 visited, 156 in queue
#  [2] https://www.primelands.lk/land/PRIME-GREEN-TOWN-UDAGAMA/en
#     Saved (10277 chars, 3 links found)
#    Progress: 169 docs saved, 238 visited, 155 in queue
#  [2] https://www.primelands.lk/land/PRIME-FREEDOM-PARK-EMBILIPITIYA/en
#     Saved (7028 chars, 0 links found)
#    Progress: 170 docs saved, 239 visited, 154 in queue
#  [2] https://www.primelands.lk/land/CITY-GLAZE-MINUWANGODA/en
#     Saved (11237 chars, 7 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 171 docs saved, 240 visited, 155 in queue
#  [2] https://www.primelands.lk/land/ETERNITY-MINUWANGODA/en
#     Saved (12775 chars, 5 links found)
#     Added 1 new URLs to queue (depth 3)
#    Progress: 172 docs saved, 241 visited, 155 in queue
#  [2] https://www.primelands.lk/land/FELICITY-MINUWANGODA/en
#     Saved (11014 chars, 5 links found)
#     Added 1 new URLs to queue (depth 3)
#    Progress: 173 docs saved, 242 visited, 155 in queue
#  [2] https://www.primelands.lk/land/SUPREME-MINUWANGODA/en
#     Saved (7869 chars, 0 links found)
#    Progress: 174 docs saved, 243 visited, 154 in queue
#  [2] https://www.primelands.lk/land/ZILLION-MORATUWA/en
#     Saved (25353 chars, 33 links found)
#    Progress: 175 docs saved, 244 visited, 153 in queue
#  [2] https://www.primelands.lk/land/LAVISH-GARDEN/en
#     Saved (11153 chars, 5 links found)
#    Progress: 176 docs saved, 245 visited, 152 in queue
#  [2] https://www.primelands.lk/land/LAKEFRONT-BOLGODA/en
#     Saved (9648 chars, 0 links found)
#    Progress: 177 docs saved, 246 visited, 151 in queue
#  [2] https://www.primelands.lk/land/PRIME-FUTURA-UDUGAMPOLA/en
#     Saved (9639 chars, 4 links found)
#    Progress: 178 docs saved, 247 visited, 150 in queue
#  [2] https://www.primelands.lk/land/PARADISE-AVENUE-NEGOMBO/en
#     Saved (11467 chars, 8 links found)
#    Progress: 179 docs saved, 248 visited, 149 in queue
#  [2] https://www.primelands.lk/land/THE-LAGOON-KATUNAYAKE/en
#     Saved (31892 chars, 44 links found)
#     Added 12 new URLs to queue (depth 3)
#    Progress: 180 docs saved, 249 visited, 160 in queue
#  [2] https://www.primelands.lk/land/PRIME-ORIGIN-II-NEGOMBO/en
#     Saved (11285 chars, 7 links found)
#    Progress: 181 docs saved, 250 visited, 159 in queue
#  [2] https://www.primelands.lk/land/PRIME-ORIGIN/en
#     Saved (10529 chars, 2 links found)
#    Progress: 182 docs saved, 251 visited, 158 in queue
#  [2] https://www.primelands.lk/land/NEGOMBO-CITY-BASE/en
#     Saved (12807 chars, 9 links found)
#    Progress: 183 docs saved, 252 visited, 157 in queue
#  [2] https://www.primelands.lk/land/ATH-PAURA-KURUNEGALA/en
#     Saved (13803 chars, 7 links found)
#    Progress: 184 docs saved, 253 visited, 156 in queue
#  [2] https://www.primelands.lk/land/OPAL-UDUGAMPOLA/en
#     Saved (13452 chars, 5 links found)
#    Progress: 185 docs saved, 254 visited, 155 in queue
#  [2] https://www.primelands.lk/land/URBAN-CENTRE-WALASMULLA/en
#     Saved (10290 chars, 0 links found)
#    Progress: 186 docs saved, 255 visited, 154 in queue
#  [2] https://www.primelands.lk/land/TANGALLE-THE-SAND/en
#     Saved (11989 chars, 1 links found)
#    Progress: 187 docs saved, 256 visited, 153 in queue
#  [2] https://www.primelands.lk/land/SUPREME-PLACE-AMBATHENNA/en
#     Saved (11469 chars, 5 links found)
#    Progress: 188 docs saved, 257 visited, 152 in queue
#  [2] https://www.primelands.lk/land/SINHARAGAMA-LION-GATE/en
#     Saved (12359 chars, 10 links found)
#    Progress: 189 docs saved, 258 visited, 151 in queue
#  [2] https://www.primelands.lk/land/AVALON-KALUTARA/en
#     Saved (14591 chars, 5 links found)
#    Progress: 190 docs saved, 259 visited, 150 in queue
#  [2] https://www.primelands.lk/land/PERIDOT-KURUWITA/en
#     Saved (13459 chars, 3 links found)
#    Progress: 191 docs saved, 260 visited, 149 in queue
#  [2] https://www.primelands.lk/land/PRIME-DAWN-ARTIGALA/en
#     Saved (9927 chars, 3 links found)
#    Progress: 192 docs saved, 261 visited, 148 in queue
#  [2] https://www.primelands.lk/land/PRIME-ASTERIN-ARTIGALA/en
#     Saved (7692 chars, 0 links found)
#    Progress: 193 docs saved, 262 visited, 147 in queue
#  [2] https://www.primelands.lk/land/ARTIGALA-LUSH-LIFE/en
#     Saved (17368 chars, 15 links found)
#    Progress: 194 docs saved, 263 visited, 146 in queue
#  [2] https://www.primelands.lk/land/PRIME-GREENVALE-ARTIGALA/en
#     Saved (6643 chars, 0 links found)
#    Progress: 195 docs saved, 264 visited, 145 in queue
#  [2] https://www.primelands.lk/land/LUSH-LAND-KOTTAWA/en
#     Saved (10146 chars, 4 links found)
#    Progress: 196 docs saved, 265 visited, 144 in queue
#  [2] https://www.primelands.lk/land/THALAWATHUGODA-PRIME-OSBORNE-PARK/en
#     Saved (27437 chars, 36 links found)
#    Progress: 197 docs saved, 266 visited, 143 in queue
#  [2] https://www.primelands.lk/land/NIFTY-THALAWATHUGODA/en
#     Saved (26384 chars, 34 links found)
#    Progress: 198 docs saved, 267 visited, 142 in queue
#  [2] https://www.primelands.lk/land/STARBASE-KADAWATHA/en
#     Saved (12059 chars, 5 links found)
#    Progress: 199 docs saved, 268 visited, 141 in queue
#  [2] https://www.primelands.lk/land/MAXON-VEYANGODA/en
#     Saved (12103 chars, 5 links found)
#    Progress: 200 docs saved, 269 visited, 140 in queue
#  [2] https://www.primelands.lk/land/PRIME-UNITY-STAGE-3/en
#     Saved (9564 chars, 4 links found)
#    Progress: 201 docs saved, 270 visited, 139 in queue
#  [2] https://www.primelands.lk/land/URBAN-POINT-VEYANGODA/en
#     Saved (12114 chars, 6 links found)
#    Progress: 202 docs saved, 271 visited, 138 in queue
#  [2] https://www.primelands.lk/land/UNITY-VEYANGODA/en
#     Saved (9177 chars, 3 links found)
#    Progress: 203 docs saved, 272 visited, 137 in queue
#  [2] https://www.primelands.lk/land/ZERENITY-WEYANGODA/en
#     Saved (10368 chars, 8 links found)
#    Progress: 204 docs saved, 273 visited, 136 in queue
#  [2] https://www.primelands.lk/land/PREMIA-ANURADHAPURA/en
#     Saved (16252 chars, 15 links found)
#     Added 6 new URLs to queue (depth 3)
#    Progress: 205 docs saved, 274 visited, 141 in queue
#  [2] https://www.primelands.lk/land/HARITHAPURA-ANURADHAPURA/en
#     Saved (11404 chars, 6 links found)
#    Progress: 206 docs saved, 275 visited, 140 in queue
#  [2] https://www.primelands.lk/land/PRIME-NORTH-TOWN-ANURADHAPURA/en
#     Saved (10656 chars, 4 links found)
#    Progress: 207 docs saved, 276 visited, 139 in queue
#  [2] https://www.primelands.lk/land/EMPOWER-ANURADHAPURA/en
#     Saved (12914 chars, 8 links found)
#    Progress: 208 docs saved, 277 visited, 138 in queue
#  [2] https://www.primelands.lk/land/SOUL-CITY-ANURADHAPURA/en
#     Saved (11950 chars, 4 links found)
#    Progress: 209 docs saved, 278 visited, 137 in queue
#  [2] https://www.primelands.lk/land/PRIME-AQUAVILLE-WELIWITA/en
# ...
#      Skipped (does not match include patterns)
#    Progress: 257 docs saved, 330 visited, 92 in queue
#  [3] https://www.primelands.lk/portfolio-property/city/Kalutara/en
#      Skipped (does not match include patterns)
#    Progress: 257 docs saved, 331 visited, 91 in queue
#  [3] https://www.primelands.lk/portfolio-property/district/Kalutara/en
#      Skipped (does not match include patterns)
#    Progress: 257 docs saved, 332 visited, 90 in queue
#  [3] https://www.primelands.lk/portfolio-property/city/Nuwara-Eliya/en
#      Skipped (does not match include patterns)
#    Progress: 257 docs saved, 333 visited, 89 in queue
#  [3] https://www.primelands.lk/portfolio-property/commercial/en
#     Saved (12146 chars, 37 links found)
#     Added 2 new URLs to queue (depth 4)
#    Progress: 258 docs saved, 334 visited, 90 in queue
#  [3] https://www.primelands.lk/portfolio-property/city/Aluthgama/en
#      Skipped (does not match include patterns)
#    Progress: 258 docs saved, 335 visited, 89 in queue
#  [3] https://www.primelands.lk/portfolio-property/district/Anuradhapura/en
#      Skipped (does not match include patterns)
#     Added 1 new URLs to queue (depth 4)
#    Progress: 258 docs saved, 336 visited, 89 in queue
#  [3] https://www.primelands.lk/portfolio-property/city/Kaduwela-/en
#      Skipped (does not match include patterns)
#    Progress: 258 docs saved, 337 visited, 88 in queue
#  [3] https://www.primelands.lk/portfolio-property/down-south-lands/en
#      Skipped (does not match include patterns)
#    Progress: 258 docs saved, 338 visited, 87 in queue
#  [3] https://www.primelands.lk/portfolio-property/district/Colombo/en
#      Skipped (does not match include patterns)
#     Added 1 new URLs to queue (depth 4)
#    Progress: 258 docs saved, 339 visited, 87 in queue
#  [3] https://www.primelands.lk/portfolio-property/up-country-lands/en
#      Skipped (does not match include patterns)
#    Progress: 258 docs saved, 340 visited, 86 in queue
#  [3] https://www.primelands.lk/portfolio-property/mountain-view/en
#      Skipped (does not match include patterns)
#    Progress: 258 docs saved, 341 visited, 85 in queue
#  [3] https://www.primelands.lk/portfolio-property/city/Galle/en
#      Skipped (does not match include patterns)
#    Progress: 258 docs saved, 342 visited, 84 in queue
#  [3] https://www.primelands.lk/portfolio-property/land/en
#     Saved (12389 chars, 39 links found)
#    Progress: 259 docs saved, 343 visited, 83 in queue
#  [3] https://www.primelands.lk/portfolio-property/district/Gampaha/en
#      Skipped (does not match include patterns)
#     Added 1 new URLs to queue (depth 4)
#    Progress: 259 docs saved, 344 visited, 83 in queue
#  [3] https://www.primelands.lk/portfolio-property/close-to-highways/en
#      Skipped (does not match include patterns)
#    Progress: 259 docs saved, 345 visited, 82 in queue
#  [3] https://www.primelands.lk/portfolio-property/close-to-railway-stations/en
#      Skipped (does not match include patterns)
#    Progress: 259 docs saved, 346 visited, 81 in queue
#  [3] https://www.primelands.lk/portfolio-property/city/Colombo/en
#      Skipped (does not match include patterns)
#    Progress: 259 docs saved, 347 visited, 80 in queue
#  [3] https://www.primelands.lk/portfolio-property/district/Galle/en
#      Skipped (does not match include patterns)
#    Progress: 259 docs saved, 348 visited, 79 in queue
#  [3] https://www.primelands.lk/portfolio-property/city/Negombo/en
#      Skipped (does not match include patterns)
#    Progress: 259 docs saved, 349 visited, 78 in queue
#  [3] https://www.primelands.lk/portfolio-property/district/Nuwara-Eliya/en
#      Skipped (does not match include patterns)
#    Progress: 259 docs saved, 350 visited, 77 in queue
#  [3] https://www.primelands.lk/portfolio-property/waterfront-land/en
#      Skipped (does not match include patterns)
#    Progress: 259 docs saved, 351 visited, 76 in queue
#  [3] https://www.primelands.lk/portfolio-property/city/Anuradhapura/en
#      Skipped (does not match include patterns)
#    Progress: 259 docs saved, 352 visited, 75 in queue
#  [3] https://www.primelands.lk/portfolio-property/district/Kurunegala/en
#      Skipped (does not match include patterns)
#    Progress: 259 docs saved, 353 visited, 74 in queue
#  [3] https://www.primelands.lk/portfolio-property/district/Matara/en
#      Skipped (does not match include patterns)
#    Progress: 259 docs saved, 354 visited, 73 in queue
#  [3] https://www.primelands.lk/portfolio-property/close-to-ancient-city-lands/en
#      Skipped (does not match include patterns)
#    Progress: 259 docs saved, 355 visited, 72 in queue
#  [3] https://www.primelands.lk/portfolio-property/paddy-field-facing-lands/en
#      Skipped (does not match include patterns)
#    Progress: 259 docs saved, 356 visited, 71 in queue
#  [3] https://www.primelands.lk/portfolio-property/agriculture-land/en
#      Skipped (does not match include patterns)
#    Progress: 259 docs saved, 357 visited, 70 in queue
#  [3] https://www.primelands.lk/portfolio-property/city/Weligama/en
#      Skipped (does not match include patterns)
#    Progress: 259 docs saved, 358 visited, 69 in queue
#  [3] https://www.primelands.lk/portfolio-property/residential/en
#      Skipped (does not match include patterns)
#    Progress: 259 docs saved, 359 visited, 68 in queue
#  [3] https://www.primelands.lk/land/PRIME-EVERNEST-HORANA/en
#     Saved (10873 chars, 4 links found)
#    Progress: 260 docs saved, 360 visited, 67 in queue
#  [3] https://www.primelands.lk/land/GREEN-CLASSIC-WADDUWA/en
#     Saved (12480 chars, 5 links found)
#    Progress: 261 docs saved, 361 visited, 66 in queue
#  [3] https://www.primelands.lk/land/TOWN-GROVE-BANDARAGAMA/en
#     Saved (10970 chars, 5 links found)
#    Progress: 262 docs saved, 362 visited, 65 in queue
#  [3] https://www.primelands.lk/land/PRIME-CITY-AXIS-HORANA/en
#     Saved (10155 chars, 3 links found)
#    Progress: 263 docs saved, 363 visited, 64 in queue
#  [3] https://www.primelands.lk/land/LIGHT-OF-WISDOM-HOMAGAMA/en
#     Saved (6704 chars, 0 links found)
#    Progress: 264 docs saved, 364 visited, 63 in queue
#  [3] https://www.primelands.lk/land/AUROUS-HOMAGAMA/en
#     Saved (9739 chars, 2 links found)
#    Progress: 265 docs saved, 365 visited, 62 in queue
#  [3] https://www.primelands.lk/land/SPARKLE-MEEPE/en
#     Saved (6428 chars, 0 links found)
#    Progress: 266 docs saved, 366 visited, 61 in queue
#  [3] https://www.primelands.lk/land/NEST-BORALESGAMUWA/en
#     Saved (13514 chars, 9 links found)
#    Progress: 267 docs saved, 367 visited, 60 in queue
#  [3] https://www.primelands.lk/land/LUXULIA-PANNIPITIYA/en
#     Saved (9876 chars, 2 links found)
#    Progress: 268 docs saved, 368 visited, 59 in queue
#  [3] https://www.primelands.lk/land/THE-BREATHE-HOMAGAMA/en
#     Saved (10469 chars, 3 links found)
#    Progress: 269 docs saved, 369 visited, 58 in queue
#  [3] https://www.primelands.lk/land/PRIME-SUPERIOR-PILIYANDALA/en
#     Saved (10935 chars, 6 links found)
#    Progress: 270 docs saved, 370 visited, 57 in queue
#  [3] https://www.primelands.lk/land/ELINOR-BATTARAMULLA/en
#     Saved (11798 chars, 5 links found)
#    Progress: 271 docs saved, 371 visited, 56 in queue
#  [3] https://www.primelands.lk/land/CENNET-MIRISWATTA/en
#     Saved (13087 chars, 7 links found)
#    Progress: 272 docs saved, 372 visited, 55 in queue
#  [3] https://www.primelands.lk/land/CAPITAL-POINT-GAMPAHA/en
#     Saved (9475 chars, 4 links found)
#    Progress: 273 docs saved, 373 visited, 54 in queue
#  [3] https://www.primelands.lk/land/GLIMMER-WARAGODA/en
#     Saved (11242 chars, 9 links found)
#    Progress: 274 docs saved, 374 visited, 53 in queue
#  [3] https://www.primelands.lk/land/BROAD-CITY-KADAWATHA/en
#     Saved (7938 chars, 0 links found)
#    Progress: 275 docs saved, 375 visited, 52 in queue
#  [3] https://www.primelands.lk/apartment/ONE-TANGALLE-TANGALLE/en
#     Saved (15987 chars, 5 links found)
#    Progress: 276 docs saved, 376 visited, 51 in queue
#  [3] https://www.primelands.lk/apartment/complete/en
#     Saved (9269 chars, 12 links found)
#    Progress: 277 docs saved, 377 visited, 50 in queue
#  [3] https://www.primelands.lk/apartment/complete/city/Gampaha/en
#     Saved (9269 chars, 12 links found)
#    Progress: 278 docs saved, 378 visited, 49 in queue
#  [3] https://www.primelands.lk/apartment/complete/district/Gampaha/en
#     Saved (9269 chars, 12 links found)
#    Progress: 279 docs saved, 379 visited, 48 in queue
#  [3] https://www.primelands.lk/land/REGENCY-HEIGHTS-KANDY/en
#     Saved (11258 chars, 5 links found)
#    Progress: 280 docs saved, 380 visited, 47 in queue
#  [3] https://www.primelands.lk/land/PRIME-DELTA-ESTATE-PUSELLAWA/en
#     Saved (12268 chars, 4 links found)
#    Progress: 281 docs saved, 381 visited, 46 in queue
#  [3] https://www.primelands.lk/land/PRIME-ROYAL-TERRACE-KANDY/en
#     Saved (11213 chars, 5 links found)
#    Progress: 282 docs saved, 382 visited, 45 in queue
#  [3] https://www.primelands.lk/land/PRIME-UP-TOWN-PERADENIYA/en
#     Saved (9955 chars, 4 links found)
#    Progress: 283 docs saved, 383 visited, 44 in queue
#  [3] https://www.primelands.lk/land/RIVER-EDGE-POLGAHAWELA/en
#     Saved (7032 chars, 0 links found)
#    Progress: 284 docs saved, 384 visited, 43 in queue
#  [3] https://www.primelands.lk/land/PRIME-HOPE-KULIYAPITIYA/en
#     Saved (11541 chars, 3 links found)
#    Progress: 285 docs saved, 385 visited, 42 in queue
#  [3] https://www.primelands.lk/land/PRIME-ASSEDDUMA-GOLDEN-HARVEST/en
#     Saved (11638 chars, 3 links found)
#    Progress: 286 docs saved, 386 visited, 41 in queue
#  [3] https://www.primelands.lk/land/ISURUPURA-BOWATTA/en
#     Saved (8657 chars, 0 links found)
#    Progress: 287 docs saved, 387 visited, 40 in queue
#  [3] https://www.primelands.lk/land/PRIME-RAN-VIMANA-KULIYAPITIYA/en
#     Saved (8526 chars, 5 links found)
#    Progress: 288 docs saved, 388 visited, 39 in queue
#  [3] https://www.primelands.lk/land/LAKE-SHORE-BULANKULAMA/en
#     Saved (10462 chars, 5 links found)
#    Progress: 289 docs saved, 389 visited, 38 in queue
#  [3] https://www.primelands.lk/land/PRIME-GREEN-GROW-MILIDDUWA/en
#     Saved (8418 chars, 0 links found)
#    Progress: 290 docs saved, 390 visited, 37 in queue
#  [3] https://www.primelands.lk/land/7TH-HEAVEN-GALLE/en
#     Saved (8978 chars, 3 links found)
#    Progress: 291 docs saved, 391 visited, 36 in queue
#  [3] https://www.primelands.lk/land/PRIME-CENTER-POINT-HETTIPOLA/en
#     Saved (10350 chars, 4 links found)
#    Progress: 292 docs saved, 392 visited, 35 in queue
#  [3] https://www.primelands.lk/land/ARUNODAYA-BANDARAGAMA/en
#     Saved (18872 chars, 18 links found)
#     Added 1 new URLs to queue (depth 4)
#    Progress: 293 docs saved, 393 visited, 35 in queue
#  [3] https://www.primelands.lk/land/AMITY-DIVULAPITIYA/en
#     Saved (7153 chars, 0 links found)
#    Progress: 294 docs saved, 394 visited, 34 in queue
#  [3] https://www.primelands.lk/land/EXPRESS-CORRIDOR-KADAWATHA/en
#     Saved (11413 chars, 8 links found)
#    Progress: 295 docs saved, 395 visited, 33 in queue
#  [3] https://www.primelands.lk/land/EMERALD-BROOK-WATTALA/en
#     Saved (14788 chars, 13 links found)
#    Progress: 296 docs saved, 396 visited, 32 in queue
#  [3] https://www.primelands.lk/land/PRIME-ZONE-5/en
#     Saved (11641 chars, 6 links found)
#    Progress: 297 docs saved, 397 visited, 31 in queue
#  [3] https://www.primelands.lk/land/PRIME-ARUNALU-DIVULAPITIYA/en
#     Saved (8448 chars, 4 links found)
#    Progress: 298 docs saved, 398 visited, 30 in queue
#  [3] https://www.primelands.lk/land/NITTAMBUWA-IMPERIUM/en
#     Saved (12919 chars, 8 links found)
#    Progress: 299 docs saved, 399 visited, 29 in queue
#  [3] https://www.primelands.lk/land/BIG-CITY-WEWALDENIYA/en
#     Saved (9229 chars, 3 links found)
#    Progress: 300 docs saved, 400 visited, 28 in queue
#  [3] https://www.primelands.lk/land/PREMIER-KADAWATHA/en
#     Saved (10302 chars, 6 links found)
#    Progress: 301 docs saved, 401 visited, 27 in queue
#  [3] https://www.primelands.lk/land/EMINENT-PLACE-KELANIYA/en
#     Saved (10050 chars, 3 links found)
#    Progress: 302 docs saved, 402 visited, 26 in queue
#  [3] https://www.primelands.lk/land/WATTALA-QUEENS-AVENUE-2/en
#     Saved (13048 chars, 10 links found)
#    Progress: 303 docs saved, 403 visited, 25 in queue
#  [3] https://www.primelands.lk/land/CAZELLE-WATTALA/en
#     Saved (14845 chars, 10 links found)
#    Progress: 304 docs saved, 404 visited, 24 in queue
#  [3] https://www.primelands.lk/land/PRIME-ATRIUM-KADAWATHA/en
#     Saved (8698 chars, 3 links found)
#    Progress: 305 docs saved, 405 visited, 23 in queue
#  [3] https://www.primelands.lk/land/360-AVENUE-KADAWATHA/en
#     Saved (12817 chars, 11 links found)
#    Progress: 306 docs saved, 406 visited, 22 in queue
#  [3] https://www.primelands.lk/land/PREMIER-RADDOLUGAMA/en
#     Saved (13407 chars, 10 links found)
#    Progress: 307 docs saved, 407 visited, 21 in queue
#  [3] https://www.primelands.lk/land/CITY-SPACE-KIRILLAWALA/en
#     Saved (11534 chars, 7 links found)
#    Progress: 308 docs saved, 408 visited, 20 in queue
#  [3] https://www.primelands.lk/land/PRIME-RANKETHA-II-WELIWERIYA/en
#     Saved (8493 chars, 2 links found)
#    Progress: 309 docs saved, 409 visited, 19 in queue
#  [3] https://www.primelands.lk/land/PRIME-LAKE-VIEW-ANURADHAPURA/en
#     Saved (10392 chars, 4 links found)
#    Progress: 310 docs saved, 410 visited, 18 in queue
#  [3] https://www.primelands.lk/land/PRIME-NORTH-LAKE-ANURADHAPURA/en
#     Saved (9204 chars, 3 links found)
#    Progress: 311 docs saved, 411 visited, 17 in queue
#  [3] https://www.primelands.lk/land/PRIME-KINGS-BOULEVARD-ANURADHAPURA/en
#     Saved (11098 chars, 10 links found)
#    Progress: 312 docs saved, 412 visited, 16 in queue
#  [3] https://www.primelands.lk/land/FUTURE-KINGDOM-MADAWACHCHIYA/en
#     Saved (10948 chars, 3 links found)
#    Progress: 313 docs saved, 413 visited, 15 in queue
#  [3] https://www.primelands.lk/land/PRIME-ROYAL-TERRACE-ANURADHAPURA/en
#     Saved (7934 chars, 2 links found)
#    Progress: 314 docs saved, 414 visited, 14 in queue
#  [3] https://www.primelands.lk/land/ADDERSFIELD-ANURADHAPURA/en
#     Saved (11300 chars, 5 links found)
#    Progress: 315 docs saved, 415 visited, 13 in queue
#  [3] https://www.primelands.lk/land/PRIME-VIEW-POINT-AMBALANGODA/en
#     Saved (9386 chars, 7 links found)
#    Progress: 316 docs saved, 416 visited, 12 in queue
#  [3] https://www.primelands.lk/land/GLORIA-AHANGAMA/en
#     Saved (10062 chars, 5 links found)
#    Progress: 317 docs saved, 417 visited, 11 in queue
#  [3] https://www.primelands.lk/land/DIKKUMBURA-SOUTHBURY/en
#     Saved (13107 chars, 10 links found)
#    Progress: 318 docs saved, 418 visited, 10 in queue
#  [3] https://www.primelands.lk/land/ARCADE-CITY-AMBALANGODA/en
#     Saved (11605 chars, 8 links found)
#    Progress: 319 docs saved, 419 visited, 9 in queue
#  [3] https://www.primelands.lk/land/PRIME-LIFE-2/en
#     Saved (10018 chars, 7 links found)
#    Progress: 320 docs saved, 420 visited, 8 in queue
#  [4] https://www.primelands.lk/portfolio-property/HOMAGAMA-KIRIWATHTHUDUWA/en
#      Skipped (does not match include patterns)
#    Progress: 320 docs saved, 421 visited, 6 in queue
#  [4] https://www.primelands.lk/portfolio-property/GALLE-KARAPITIYA/en
#      Skipped (does not match include patterns)
#    Progress: 320 docs saved, 422 visited, 5 in queue
#  [4] https://www.primelands.lk/portfolio-property/KADUWELA-WELIVITA/en
#      Skipped (does not match include patterns)
#    Progress: 320 docs saved, 423 visited, 4 in queue
#  [4] https://www.primelands.lk/portfolio-property/ANURADHAPURA-PALADIKULAMA/en
#      Skipped (does not match include patterns)
#    Progress: 320 docs saved, 424 visited, 3 in queue
#  [4] https://www.primelands.lk/portfolio-property/MAHARAGAMA-PASAL-MAWATHA/en
#      Skipped (does not match include patterns)
#    Progress: 320 docs saved, 425 visited, 2 in queue
#  [4] https://www.primelands.lk/portfolio-property/NEGOMBO-DUNGALPITIYA/en
#      Skipped (does not match include patterns)
#    Progress: 320 docs saved, 426 visited, 1 in queue
#  [4] https://www.primelands.lk/land/GREEN-CAPITAL-INGIRIYA/en
#     Saved (13881 chars, 8 links found)
#    Progress: 321 docs saved, 427 visited, 0 in queue
#
#  Crawl complete in 4014.9s
#  Documents collected: 321
#  URLs visited: 427

# %% [markdown]
# ### Save Outputs

# %%
# Save markdown files
for i, doc in enumerate(documents):
    url_path = urlparse(doc['url']).path.strip('/').replace('/', '_')
    if not url_path:
        url_path = "homepage"
    filename = f"{i:03d}_{url_path}.md"
    
    md_file = MARKDOWN_DIR / filename
    with open(md_file, 'w', encoding='utf-8') as f:
        f.write(f"# {doc['title']}\n\n")
        f.write(f"**URL**: {doc['url']}\n\n")
        f.write(f"**Depth**: {doc['depth_level']}\n\n")
        f.write("---\n\n")
        f.write(doc['content'])

print(f" Saved {len(documents)} markdown files to {MARKDOWN_DIR}")

# Save JSONL
with open(JSONL_PATH, 'w', encoding='utf-8') as f:
    for doc in documents:
        f.write(json.dumps(doc, ensure_ascii=False) + '\n')

print(f" Saved JSONL corpus to {JSONL_PATH}")
# Out:
#  Saved 321 markdown files to c:\Development\real-estate-intelligence-platform\data\primelands_markdown
#  Saved JSONL corpus to c:\Development\real-estate-intelligence-platform\data\primelands_docs.jsonl

# %% [markdown]
# ### Quality Checks

# %%
import random

print(" Quality Checks:\n")

# Check markdown files
md_files = list(MARKDOWN_DIR.glob("*.md"))
print(f"1  Markdown files: {len(md_files)}")

if len(md_files) >= 20:
    print(f"    Good! Got {len(md_files)} pages")
elif len(md_files) >= 10:
    print(f"     Only {len(md_files)} pages (site may be small)")
else:
    raise AssertionError(f" Too few pages: {len(md_files)}")

# Check JSONL
assert JSONL_PATH.exists(), f" JSONL not found"
print(f"\n2  JSONL file: {JSONL_PATH.stat().st_size:,} bytes")

# Sample inspection
with open(JSONL_PATH, 'r', encoding='utf-8') as f:
    all_docs = [json.loads(line) for line in f]

samples = random.sample(all_docs, min(3, len(all_docs)))
print(f"\n3  Random samples:\n")

for i, doc in enumerate(samples, 1):
    print(f"   Sample {i}:")
    print(f"   - URL: {doc['url']}")
    print(f"   - Title: {doc['title']}")
    print(f"   - Words: {len(doc['content'].split())}")
    print()

print(" All quality checks passed!")
# Out:
#  Quality Checks:
#
# 1  Markdown files: 1444
#     Good! Got 1444 pages
#
# 2  JSONL file: 5,060,735 bytes
#
# 3  Random samples:
#
#    Sample 1:
#    - URL: https://www.primelands.lk/land/PRIME-DELTA-ESTATE-PUSELLAWA/en
#    - Title: PRIME DELTA ESTATE PUSELLAWA
#    - Words: 740
#
#    Sample 2:
#    - URL: https://www.primelands.lk/land/LAKE-SHORE-BULANKULAMA/en
#    - Title: LAKE SHORE BULANKULAMA
#    - Words: 650
#
#    Sample 3:
#    - URL: https://www.primelands.lk/apartment/THE-COLOMBO-BORDER-PELIYAGODA/en
#    - Title: THE COLOMBO BORDER - PELIYAGODA
#    - Words: 1296
#
#  All quality checks passed!
