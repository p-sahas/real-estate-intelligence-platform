# %% [markdown]
# ### Setup & Installations

# %%
import sys
# if "google.colab" in sys.modules or True:
#     print(" Installing required packages...")
#     %pip install -q playwright>=1.40.0 python-dotenv>=1.0.0 beautifulsoup4>=4.12.0 markdownify>=0.11.6 nest-asyncio>=1.5.0
    
#     # Install Playwright browsers
#     print(" Installing Playwright browsers...")
#     import subprocess
#     subprocess.run([sys.executable, "-m", "playwright", "install", "chromium"], check=True, capture_output=True)

# print(" Packages ready")

# %% [markdown]
# ### Imports & Environment Setup

# %%
import os
import sys
import json
import time
from pathlib import Path
from urllib.parse import urlparse
from dotenv import load_dotenv
import nest_asyncio

# Enable nested asyncio
nest_asyncio.apply()

# Add project root to path
project_root = Path.cwd().parent
sys.path.insert(0, str(project_root / "src"))

# Load environment
load_dotenv(project_root / ".env")

# Check for API key (OpenRouter preferred, OpenAI as fallback)
openrouter_key = os.getenv("OPENROUTER_API_KEY")
groq_key = os.getenv("GROQ_API_KEY")

if not openrouter_key and not groq_key:
    raise EnvironmentError(
        " No API key found!\n"
        " Add OPENROUTER_API_KEY (recommended) or GROQ_API_KEY to .env"
    )

provider = "OpenRouter" if openrouter_key else "OpenAI"
print(" Environment loaded")
print(f" Provider: {provider}")
print(f" Project root: {project_root}")
# Out:
#  Environment loaded
#  Provider: OpenRouter
#  Project root: c:\Development\real-estate-intelligence-platform

# %% [markdown]
# ### Load Configuration

# %%
from context_engineering.config import (validate, dump, CRAWL_OUT_DIR, MARKDOWN_DIR)

# Validate and display config
try:
    validate()
    dump()
except Exception as e:
    print(f"  Config note: {e}")

# Ensure directories exist
MARKDOWN_DIR.mkdir(parents=True, exist_ok=True)

print(f"\n Output directories ready:")
print(f"   - Markdown: {MARKDOWN_DIR}")
print(f"   - JSONL: {CRAWL_OUT_DIR}")
# Out:
# ============================================================
# CONFIGURATION (NON-SECRETS ONLY)
# ============================================================
#
#  Provider:
#    Provider: openrouter
#    Model Tier: general
#    Chat Model: openai/gpt-4o-mini
#    Embedding Model: openai/text-embedding-3-large
#
#  Directories:
#    Data Root: c:\Development\real-estate-intelligence-platform\data
#    Vector Store: c:\Development\real-estate-intelligence-platform\data\vectorstore
#    Markdown: c:\Development\real-estate-intelligence-platform\data\primelands_markdown
#    Cache: c:\Development\real-estate-intelligence-platform\data\cag_cache
#
#  Chunking:
#    Fixed Size: 800 tokens
#    Fixed Overlap: 100 tokens
#    Sliding Window: 512 tokens
#    Sliding Stride: 256 tokens
#    Parent-Child: 250 → 1200 tokens
#    Late Chunk: 1000 → 300 tokens
#
#  Retrieval:
#    Top-K Results: 4
#    Similarity Threshold: 0.7
#
#  CAG:
#    Cache TTL: 86400s
#    Max Cache Size: 1000
#
#  CRAG:
#    Confidence Threshold: 0.6
#    Expanded K: 8
#
# ============================================================
#
#
#  Output directories ready:
#    - Markdown: c:\Development\real-estate-intelligence-platform\data\primelands_markdown
#    - JSONL: c:\Development\real-estate-intelligence-platform\data

# %%
# Crawl Configuration
BASE_URL = "https://www.primelands.lk"

START_PATHS = [
    "/", "/portfolio-property", "/land", "/house",
    "/apartment/ongoing", "/upcoming-projects", "/about-us",
    "sell-your-land", "/contact-us", "/services",
     "/testimonial", "/careers", "/news",
    "/online-publications", "/blog", "/virtual-tour", 
    "/kyc", "/terms-and-conditions", "/privacy-policy"
]

START_URLS = [BASE_URL + path for path in START_PATHS]

EXCLUDE_PATTERNS = [
    "/login", "/terms", "/privacy", "/admin",
    "/images/", "/downloads/", "/media/", "/sin", 
    "/tam", "/uploads/", "/downloads/", "/pdf/",
    ".webp", ".mp4", ".jpg", ".jpeg",
     ".png", ".css", ".js"
]

MAX_DEPTH = 3
REQUEST_DELAY = 2.0
JSONL_PATH = CRAWL_OUT_DIR / "primelands_docs.jsonl"

print(f" Crawl config:")
print(f"   - Start URLs: {len(START_URLS)}")
print(f"   - Max depth: {MAX_DEPTH}")
print(f"   - Request delay: {REQUEST_DELAY}s")
# Out:
#  Crawl config:
#    - Start URLs: 19
#    - Max depth: 3
#    - Request delay: 2.0s

# %% [markdown]
# ### Import Crawler Service
#
# Using `PrimeLandCrawler` from application layer

# %%
# Import Web Crawler Service
from context_engineering.application.ingest_documents_service import PrimeLandWebCrawler

print(" PrimeLandWebCrawler loaded from service layer")
print(" Location: context_engineering.application.ingest_documents_service.web_crawler")
# Out:
#  PrimeLandWebCrawler loaded from service layer
#  Location: context_engineering.application.ingest_documents_service.web_crawler

# %%
# Run Crawl with Service
import asyncio
from concurrent.futures import ThreadPoolExecutor

start_time = time.time()

# Initialize crawler service
crawler = PrimeLandWebCrawler(
    base_url=BASE_URL,
    max_depth=MAX_DEPTH,
    exclude_patterns=EXCLUDE_PATTERNS
)

def run_crawler_thread():
    # 1. Set Proactor policy (required for Playwright on Windows)
    asyncio.set_event_loop_policy(asyncio.WindowsProactorEventLoopPolicy())
    
    # 2. Create a new event loop for this thread
    loop = asyncio.new_event_loop()
    asyncio.set_event_loop(loop)
    
    try:
        # 3. Process the async crawl directly on this loop
        return loop.run_until_complete(crawler.crawl_async(START_URLS, request_delay=REQUEST_DELAY))
    finally:
        loop.close()

print(f"\n Starting crawl at {time.strftime('%H:%M:%S')}\n")

# Run in a separate thread to avoid conflict with Jupyter's running loop
with ThreadPoolExecutor(max_workers=1) as executor:
    future = executor.submit(run_crawler_thread)
    documents = future.result()

elapsed = time.time() - start_time
print(f"\n Crawl complete in {elapsed:.1f}s")
print(f" Documents collected: {len(documents)}")
print(f" URLs visited: {len(crawler.visited)}")
# Out:
#  Starting crawl at 17:09:56
#
#  [0] https://www.primelands.lk/
#     Saved (554 chars, 45 links found)
#     Added 45 new URLs to queue (depth 1)
#    Progress: 1 docs saved, 1 visited, 63 in queue
#  [0] https://www.primelands.lk/portfolio-property
#     Saved (124 chars, 0 links found)
#    Progress: 2 docs saved, 2 visited, 62 in queue
#  [0] https://www.primelands.lk/land
#     Saved (564 chars, 71 links found)
#     Added 57 new URLs to queue (depth 1)
#    Progress: 3 docs saved, 3 visited, 118 in queue
#  [0] https://www.primelands.lk/house
#     Saved (566 chars, 30 links found)
#     Added 16 new URLs to queue (depth 1)
#    Progress: 4 docs saved, 4 visited, 133 in queue
#  [0] https://www.primelands.lk/apartment/ongoing
#     Saved (124 chars, 0 links found)
#    Progress: 5 docs saved, 5 visited, 132 in queue
#  [0] https://www.primelands.lk/upcoming-projects
#     Saved (124 chars, 0 links found)
#    Progress: 6 docs saved, 6 visited, 131 in queue
#  [0] https://www.primelands.lk/about-us
#     Saved (124 chars, 0 links found)
#    Progress: 7 docs saved, 7 visited, 130 in queue
#  [0] https://www.primelands.lksell-your-land
#      Page not found (404) - skipping
#  [0] https://www.primelands.lk/contact-us
#     Error: Page.goto: Navigation to "https://www.primelands.lk/contact-us" is interrupted by another navigation
#  [0] https://www.primelands.lk/services
#     Error: Page.goto: Navigation to "https://www.primelands.lk/services" is interrupted by another navigation t
#  [0] https://www.primelands.lk/testimonial
#     Error: Page.goto: Navigation to "https://www.primelands.lk/testimonial" is interrupted by another navigatio
#  [0] https://www.primelands.lk/careers
#     Saved (124 chars, 0 links found)
#    Progress: 8 docs saved, 12 visited, 125 in queue
#  [0] https://www.primelands.lk/news
#     Saved (124 chars, 0 links found)
#    Progress: 9 docs saved, 13 visited, 124 in queue
#  [0] https://www.primelands.lk/online-publications
#     Saved (124 chars, 0 links found)
#    Progress: 10 docs saved, 14 visited, 123 in queue
#  [0] https://www.primelands.lk/blog
#     Saved (124 chars, 0 links found)
#    Progress: 11 docs saved, 15 visited, 122 in queue
#  [0] https://www.primelands.lk/virtual-tour
#     Saved (124 chars, 0 links found)
#    Progress: 12 docs saved, 16 visited, 121 in queue
#  [0] https://www.primelands.lk/kyc
#     Saved (124 chars, 0 links found)
#    Progress: 13 docs saved, 17 visited, 120 in queue
#  [1] https://www.primelands.lk/portfolio-property/GALLE-HAPUGALA/en
#     Saved (622 chars, 11 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 14 docs saved, 18 visited, 119 in queue
#  [1] https://www.primelands.lk/apartment/en
#     Saved (590 chars, 26 links found)
#     Added 13 new URLs to queue (depth 2)
#    Progress: 15 docs saved, 19 visited, 131 in queue
#  [1] https://www.primelands.lk/house/KAHATHUDUWA-88-RESIDENCE/en
#     Saved (616 chars, 13 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 16 docs saved, 20 visited, 133 in queue
#  [1] https://www.primelands.lk/land/ADORA-NAIWALA/en
#     Saved (592 chars, 13 links found)
#     Added 7 new URLs to queue (depth 2)
#    Progress: 17 docs saved, 21 visited, 139 in queue
#  [1] https://www.primelands.lk/land/en
#     Saved (564 chars, 70 links found)
#    Progress: 18 docs saved, 22 visited, 138 in queue
#  [1] https://www.primelands.lk/house/THALAWATHUGODA-CLOVER/en
#     Saved (610 chars, 14 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 19 docs saved, 23 visited, 139 in queue
#  [1] https://www.primelands.lk/house/DIGANA-SCOTTISH-ISLAND/en
#     Saved (612 chars, 12 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 20 docs saved, 24 visited, 140 in queue
#  [1] https://www.primelands.lk/en
#     Saved (554 chars, 44 links found)
#    Progress: 21 docs saved, 25 visited, 139 in queue
#  [1] https://www.primelands.lk/house/THE-RESIDENCE-SAMAGI-MAWATHA-THALAWATHUGODA/en
#     Saved (654 chars, 12 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 22 docs saved, 26 visited, 140 in queue
#  [1] https://www.primelands.lk/news/97/Prime-Group-Stands-with-the-Children-of-Police-Families-Affected-by-Cyclone-Ditwah/en
#     Saved (736 chars, 18 links found)
#     Added 8 new URLs to queue (depth 2)
#    Progress: 23 docs saved, 27 visited, 147 in queue
#  [1] https://www.primelands.lk/house/DALUGAMA-PRIME-VILLAS/en
#     Saved (610 chars, 12 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 24 docs saved, 28 visited, 148 in queue
#  [1] https://www.primelands.lk/portfolio-property/ALUTHGAMA-WELIPENNA/en
#     Saved (632 chars, 11 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 25 docs saved, 29 visited, 149 in queue
#  [1] https://www.primelands.lk/apartment/VENEZIA-NEGOMBO/en
#     Saved (606 chars, 11 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 26 docs saved, 30 visited, 150 in queue
#  [1] https://www.primelands.lk/about-us/en
#     Saved (572 chars, 30 links found)
#     Added 23 new URLs to queue (depth 2)
#    Progress: 27 docs saved, 31 visited, 172 in queue
#  [1] https://www.primelands.lk/news/93/Prime-Group-makes-history-with-Sri-Lankas-first-luxury-real-estate-client-experience-initiative-Prime-Premier/en
#     Saved (790 chars, 18 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 28 docs saved, 32 visited, 173 in queue
#  [1] https://www.primelands.lk/news/98/Prime-Group-Expands-Its-Footprint-to-Elevate-Customer-Experience-and-Reinforce-Its-Commitment-to-Excellence-with-the-Launch-of-the-Kalutara-Branch/en
#     Saved (864 chars, 19 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 29 docs saved, 33 visited, 174 in queue
#  [1] https://www.primelands.lk/land/GREEN-CREST-HORANA/en
#     Saved (602 chars, 11 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 30 docs saved, 34 visited, 177 in queue
#  [1] https://www.primelands.lk/apartment/THE-SEASONS-COLOMBO-08/en
#     Saved (620 chars, 10 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 31 docs saved, 35 visited, 178 in queue
#  [1] https://www.primelands.lk/news/94/Prime-Group-builds-nations-most-connected-property-experience-with-firstofitskind-technology-ecosystem/en
#     Saved (776 chars, 18 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 32 docs saved, 36 visited, 179 in queue
#  [1] https://www.primelands.lk/apartment/YOLO-KIRIBATHGODA/en
#     Saved (610 chars, 11 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 33 docs saved, 37 visited, 181 in queue
#  [1] https://www.primelands.lk/portfolio-property/WARIYAPOLA-KURUNEGALA/en
#     Saved (636 chars, 11 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 34 docs saved, 38 visited, 182 in queue
#  [1] https://www.primelands.lk/land/EVARA-NAWALAPITIYA/en
#     Saved (602 chars, 13 links found)
#     Added 7 new URLs to queue (depth 2)
#    Progress: 35 docs saved, 39 visited, 188 in queue
#  [1] https://www.primelands.lk/apartment/MON-VIE-COLOMBO-05/en
#     Saved (612 chars, 11 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 36 docs saved, 40 visited, 189 in queue
#  [1] https://www.primelands.lk/portfolio-property/ELLA-NUWARA-ELIYA/en
#     Saved (628 chars, 11 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 37 docs saved, 41 visited, 190 in queue
#  [1] https://www.primelands.lk/contact-us/en
#     Saved (576 chars, 7 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 38 docs saved, 42 visited, 190 in queue
#  [1] https://www.primelands.lk/house/VIVA-LA-VIDA-KOTTAWA/en
#     Saved (608 chars, 14 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 39 docs saved, 43 visited, 191 in queue
#  [1] https://www.primelands.lk/land/LUXORA-KIRIBATHGODA/en
#     Saved (604 chars, 13 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 40 docs saved, 44 visited, 192 in queue
#  [1] https://www.primelands.lk/apartment/THE-REFLECTION-SAMAGI-MAWATHA-THALAWATHUGODA/en
#     Saved (664 chars, 12 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 41 docs saved, 45 visited, 193 in queue
#  [1] https://www.primelands.lk/apartment/J-ADORE-NEGOMBO/en
#     Saved (606 chars, 11 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 42 docs saved, 46 visited, 194 in queue
#  [1] https://www.primelands.lk/house/en
#     Saved (566 chars, 29 links found)
#    Progress: 43 docs saved, 47 visited, 193 in queue
#  [1] https://www.primelands.lk/apartment/THE-GOLF-COLOMBO-08/en
#     Saved (614 chars, 11 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 44 docs saved, 48 visited, 194 in queue
#  [1] https://www.primelands.lk/portfolio-property/MATARA-WELIGAMA/en
#     Saved (624 chars, 11 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 45 docs saved, 49 visited, 195 in queue
#  [1] https://www.primelands.lk/land/LUXE-THALAHENA/en
#     Saved (594 chars, 12 links found)
#     Added 5 new URLs to queue (depth 2)
#    Progress: 46 docs saved, 50 visited, 199 in queue
#  [1] https://www.primelands.lk/land/LUXCORE-CITY-MALABE/en
#     Saved (604 chars, 14 links found)
#     Added 8 new URLs to queue (depth 2)
#    Progress: 47 docs saved, 51 visited, 206 in queue
#  [1] https://www.primelands.lk/news/en
#     Saved (564 chars, 15 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 48 docs saved, 52 visited, 207 in queue
#  [1] https://www.primelands.lk/house/CEST-LA-VIE-THALAWATHUGODA/en
#     Saved (620 chars, 14 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 49 docs saved, 53 visited, 208 in queue
#  [1] https://www.primelands.lk/land/ELITE-AVENUE-KAHATHUDUWA/en
#     Saved (614 chars, 11 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 50 docs saved, 54 visited, 211 in queue
#  [1] https://www.primelands.lk/portfolio-property/en
#     Saved (592 chars, 46 links found)
#     Added 35 new URLs to queue (depth 2)
#    Progress: 51 docs saved, 55 visited, 245 in queue
#  [1] https://www.primelands.lk/news/99/Prime-Melwa-Acquire-4-Acres-of-Premium-Waterfront-Land-in-Port-City-Colombo-for-USD-576Mn/en
#     Saved (750 chars, 18 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 52 docs saved, 56 visited, 246 in queue
#  [1] https://www.primelands.lk/house/GAMPAHA-ELEMINT-SUITES/en
#     Saved (612 chars, 12 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 53 docs saved, 57 visited, 247 in queue
#  [1] https://www.primelands.lk/land/AURELIA-ALUBOMULLA/en
#     Saved (602 chars, 14 links found)
#     Added 6 new URLs to queue (depth 2)
#    Progress: 54 docs saved, 58 visited, 252 in queue
#  [1] https://www.primelands.lk/portfolio-property/KALUTARA-NAGODA/en
#     Saved (624 chars, 11 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 55 docs saved, 59 visited, 252 in queue
#  [1] https://www.primelands.lk/apartment/SKYE-BLOSSOM-KOTTAWA/en
#     Saved (616 chars, 11 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 56 docs saved, 60 visited, 253 in queue
#  [1] https://www.primelands.lk/land/city/Minuwangoda/en
#     Saved (598 chars, 72 links found)
#     Added 6 new URLs to queue (depth 2)
#    Progress: 57 docs saved, 61 visited, 258 in queue
#  [1] https://www.primelands.lk/paddy-field-facing-lands/en
#     Saved (604 chars, 74 links found)
#     Added 5 new URLs to queue (depth 2)
#    Progress: 58 docs saved, 62 visited, 262 in queue
#  [1] https://www.primelands.lk/land/district/Matara/en
#     Saved (596 chars, 74 links found)
#     Added 8 new URLs to queue (depth 2)
#    Progress: 59 docs saved, 63 visited, 269 in queue
#  [1] https://www.primelands.lk/land/city/Kahathuduwa/en
#     Saved (598 chars, 71 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 60 docs saved, 64 visited, 272 in queue
#  [1] https://www.primelands.lk/land/DENVER-KAHATHUDUWA/en
#     Saved (602 chars, 12 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 61 docs saved, 65 visited, 275 in queue
#  [1] https://www.primelands.lk/land/district/Gampaha/en
#     Saved (598 chars, 72 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 62 docs saved, 66 visited, 277 in queue
#  [1] https://www.primelands.lk/land/district/Hambantota/en
#     Saved (604 chars, 70 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 63 docs saved, 67 visited, 280 in queue
#  [1] https://www.primelands.lk/land/district/Kegalle/en
#     Saved (598 chars, 69 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 64 docs saved, 68 visited, 282 in queue
#  [1] https://www.primelands.lk/waterfront-land/en
#     Saved (586 chars, 74 links found)
#     Added 8 new URLs to queue (depth 2)
#    Progress: 65 docs saved, 69 visited, 289 in queue
#  [1] https://www.primelands.lk/commercial/en
#     Saved (576 chars, 74 links found)
#     Added 7 new URLs to queue (depth 2)
#    Progress: 66 docs saved, 70 visited, 295 in queue
#  [1] https://www.primelands.lk/land/city/Kandy/en
#     Saved (586 chars, 73 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 67 docs saved, 71 visited, 298 in queue
#  [1] https://www.primelands.lk/close-to-ancient-city-lands/en
#     Saved (610 chars, 73 links found)
#     Added 5 new URLs to queue (depth 2)
#    Progress: 68 docs saved, 72 visited, 302 in queue
#  [1] https://www.primelands.lk/land/city/Veyangoda/en
#     Saved (594 chars, 73 links found)
#     Added 6 new URLs to queue (depth 2)
#    Progress: 69 docs saved, 73 visited, 307 in queue
#  [1] https://www.primelands.lk/land/district/Anuradhapura/en
#     Saved (608 chars, 74 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 70 docs saved, 74 visited, 310 in queue
#  [1] https://www.primelands.lk/land/city/Kiribathgoda/en
#     Saved (600 chars, 72 links found)
#     Added 6 new URLs to queue (depth 2)
#    Progress: 71 docs saved, 75 visited, 315 in queue
#  [1] https://www.primelands.lk/land/city/Anuradhapura/en
#     Saved (600 chars, 74 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 72 docs saved, 76 visited, 318 in queue
#  [1] https://www.primelands.lk/land/city/Artigala/en
#     Saved (592 chars, 73 links found)
#     Added 6 new URLs to queue (depth 2)
#    Progress: 73 docs saved, 77 visited, 322 in queue
#  [1] https://www.primelands.lk/land/city/Galle/en
#     Saved (586 chars, 74 links found)
#     Added 6 new URLs to queue (depth 2)
#    Progress: 74 docs saved, 78 visited, 327 in queue
#  [1] https://www.primelands.lk/land/city/Embilipitiya/en
#     Saved (600 chars, 73 links found)
#     Added 7 new URLs to queue (depth 2)
#    Progress: 75 docs saved, 79 visited, 333 in queue
#  [1] https://www.primelands.lk/close-to-Airport/en
#     Saved (588 chars, 74 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 76 docs saved, 80 visited, 336 in queue
#  [1] https://www.primelands.lk/residential/en
#     Saved (578 chars, 70 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 77 docs saved, 81 visited, 337 in queue
#  [1] https://www.primelands.lk/land/GREATE-10-GALLE/en
#     Saved (596 chars, 12 links found)
#     Added 5 new URLs to queue (depth 2)
#    Progress: 78 docs saved, 82 visited, 341 in queue
#  [1] https://www.primelands.lk/land/district/Kandy/en
#     Saved (594 chars, 73 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 79 docs saved, 83 visited, 342 in queue
#  [1] https://www.primelands.lk/land/district/Galle/en
#     Saved (594 chars, 74 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 80 docs saved, 84 visited, 343 in queue
#  [1] https://www.primelands.lk/land/city/Homagama/en
#     Saved (592 chars, 74 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 81 docs saved, 85 visited, 344 in queue
#  [1] https://www.primelands.lk/land/district/Colombo/en
#     Saved (598 chars, 70 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 82 docs saved, 86 visited, 345 in queue
#  [1] https://www.primelands.lk/land/district/Matale/en
#     Saved (596 chars, 71 links found)
#     Added 5 new URLs to queue (depth 2)
#    Progress: 83 docs saved, 87 visited, 349 in queue
#  [1] https://www.primelands.lk/land/city/Kottawa/en
#     Saved (590 chars, 73 links found)
#     Added 5 new URLs to queue (depth 2)
#    Progress: 84 docs saved, 88 visited, 353 in queue
#  [1] https://www.primelands.lk/land/district/Kurunegala/en
#     Saved (604 chars, 74 links found)
#     Added 6 new URLs to queue (depth 2)
#    Progress: 85 docs saved, 89 visited, 357 in queue
#  [1] https://www.primelands.lk/land/city/Horana/en
#     Saved (588 chars, 73 links found)
#     Added 7 new URLs to queue (depth 2)
#    Progress: 86 docs saved, 90 visited, 363 in queue
#  [1] https://www.primelands.lk/land/city/Matara/en
#     Saved (588 chars, 72 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 87 docs saved, 91 visited, 364 in queue
#  [1] https://www.primelands.lk/land/district/Ratnapura/en
#     Saved (602 chars, 74 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 88 docs saved, 92 visited, 366 in queue
#  [1] https://www.primelands.lk/mountain-view/en
#     Saved (582 chars, 73 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 89 docs saved, 93 visited, 368 in queue
#  [1] https://www.primelands.lk/land/city/Kalutara/en
#     Saved (592 chars, 74 links found)
#     Added 6 new URLs to queue (depth 2)
#    Progress: 90 docs saved, 94 visited, 373 in queue
#  [1] https://www.primelands.lk/up-country-lands/en
#     Saved (588 chars, 74 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 91 docs saved, 95 visited, 376 in queue
#  [1] https://www.primelands.lk/land/city/Gampaha/en
#     Saved (590 chars, 71 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 92 docs saved, 96 visited, 378 in queue
#  [1] https://www.primelands.lk/land/city/Malabe/en
#     Saved (588 chars, 73 links found)
#     Added 7 new URLs to queue (depth 2)
#    Progress: 93 docs saved, 97 visited, 384 in queue
#  [1] https://www.primelands.lk/land/city/Meegoda/en
#     Saved (590 chars, 71 links found)
#     Added 5 new URLs to queue (depth 2)
#    Progress: 94 docs saved, 98 visited, 388 in queue
#  [1] https://www.primelands.lk/land/city/Kadawatha/en
#     Saved (594 chars, 74 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 95 docs saved, 99 visited, 391 in queue
#  [1] https://www.primelands.lk/coconut-land/en
#     Saved (580 chars, 72 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 96 docs saved, 100 visited, 393 in queue
#  [1] https://www.primelands.lk/agriculture-land/en
#     Saved (588 chars, 73 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 97 docs saved, 101 visited, 394 in queue
#  [1] https://www.primelands.lk/land/city/Athurugiriya/en
#     Saved (600 chars, 72 links found)
#     Added 6 new URLs to queue (depth 2)
#    Progress: 98 docs saved, 102 visited, 399 in queue
#  [1] https://www.primelands.lk/land/city/Thalawathugoda/en
#     Saved (604 chars, 71 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 99 docs saved, 103 visited, 402 in queue
#  [1] https://www.primelands.lk/close-to-highways/en
#     Saved (590 chars, 69 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 100 docs saved, 104 visited, 403 in queue
#  [1] https://www.primelands.lk/land/city/Nuwara-Eliya/en
#     Saved (600 chars, 73 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 101 docs saved, 105 visited, 406 in queue
#  [1] https://www.primelands.lk/land/city/Kurunegala/en
#     Saved (596 chars, 74 links found)
#     Added 7 new URLs to queue (depth 2)
#    Progress: 102 docs saved, 106 visited, 412 in queue
#  [1] https://www.primelands.lk/land/ZENZA-GANEMULLA/en
#     Saved (596 chars, 14 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 103 docs saved, 107 visited, 413 in queue
#  [1] https://www.primelands.lk/land/city/Panadura/en
#     Saved (592 chars, 72 links found)
#     Added 5 new URLs to queue (depth 2)
#    Progress: 104 docs saved, 108 visited, 417 in queue
#  [1] https://www.primelands.lk/land/city/Negombo/en
#     Saved (590 chars, 73 links found)
#     Added 7 new URLs to queue (depth 2)
#    Progress: 105 docs saved, 109 visited, 423 in queue
#  [1] https://www.primelands.lk/land/district/Kalutara/en
#     Saved (600 chars, 71 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 106 docs saved, 110 visited, 424 in queue
#  [1] https://www.primelands.lk/close-to-railway-stations/en
#     Saved (606 chars, 74 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 107 docs saved, 111 visited, 426 in queue
#  [1] https://www.primelands.lk/down-south-lands/en
#     Saved (588 chars, 73 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 108 docs saved, 112 visited, 427 in queue
#  [1] https://www.primelands.lk/land/district/Nuwara-Eliya/en
#     Saved (608 chars, 74 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 109 docs saved, 113 visited, 429 in queue
#  [1] https://www.primelands.lk/land/NEXUS-TOWN-ALUTHGAMA/en
#     Saved (606 chars, 14 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 110 docs saved, 114 visited, 430 in queue
#  [1] https://www.primelands.lk/land/city/Moratuwa/en
#     Saved (592 chars, 72 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 111 docs saved, 115 visited, 432 in queue
#  [1] https://www.primelands.lk/house/city/Kadawatha/en
#     Saved (596 chars, 31 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 112 docs saved, 116 visited, 435 in queue
#  [1] https://www.primelands.lk/house/city/Gampaha/en
#     Saved (592 chars, 29 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 113 docs saved, 117 visited, 436 in queue
#  [1] https://www.primelands.lk/house/city/Kelaniya/en
#     Saved (594 chars, 29 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 114 docs saved, 118 visited, 437 in queue
#  [1] https://www.primelands.lk/house/district/Kandy/en
#     Saved (596 chars, 29 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 115 docs saved, 119 visited, 438 in queue
#  [1] https://www.primelands.lk/house/city/Malabe/en
#     Saved (590 chars, 29 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 116 docs saved, 120 visited, 439 in queue
#  [1] https://www.primelands.lk/house/city/Kottawa/en
#     Saved (592 chars, 31 links found)
#     Added 4 new URLs to queue (depth 2)
#    Progress: 117 docs saved, 121 visited, 442 in queue
#  [1] https://www.primelands.lk/house/city/Nugegoda/en
#     Saved (594 chars, 30 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 118 docs saved, 122 visited, 444 in queue
#  [1] https://www.primelands.lk/house/city/Kandy/en
#     Saved (588 chars, 29 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 119 docs saved, 123 visited, 445 in queue
#  [1] https://www.primelands.lk/house/city/Moratuwa/en
#     Saved (594 chars, 30 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 120 docs saved, 124 visited, 447 in queue
#  [1] https://www.primelands.lk/house/city/Piliyandala/en
#     Saved (600 chars, 29 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 121 docs saved, 125 visited, 447 in queue
#  [1] https://www.primelands.lk/house/district/Gampaha/en
#     Saved (600 chars, 31 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 122 docs saved, 126 visited, 448 in queue
#  [1] https://www.primelands.lk/house/MALABE-WATERFALL-RESIDENCIES/en
#     Saved (624 chars, 12 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 123 docs saved, 127 visited, 448 in queue
#  [1] https://www.primelands.lk/house/city/Thalawathugoda/en
#     Saved (606 chars, 30 links found)
#     Added 3 new URLs to queue (depth 2)
#    Progress: 124 docs saved, 128 visited, 450 in queue
#  [1] https://www.primelands.lk/house/district/Colombo/en
#     Saved (600 chars, 29 links found)
#     Added 2 new URLs to queue (depth 2)
#    Progress: 125 docs saved, 129 visited, 451 in queue
#  [2] https://www.primelands.lk/apartment/GAMPAHA-THE-PALACE/en
#     Saved (612 chars, 12 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 126 docs saved, 130 visited, 450 in queue
#  [2] https://www.primelands.lk/apartment/ongoing/city/Kottawa/en
#     Saved (616 chars, 26 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 127 docs saved, 131 visited, 450 in queue
#  [2] https://www.primelands.lk/apartment/ongoing/city/Kiribathgoda/en
#     Saved (626 chars, 27 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 128 docs saved, 132 visited, 450 in queue
#  [2] https://www.primelands.lk/apartment/ongoing/district/Galle/en
#     Saved (620 chars, 27 links found)
#     Added 3 new URLs to queue (depth 3)
#    Progress: 129 docs saved, 133 visited, 452 in queue
#  [2] https://www.primelands.lk/apartment/ongoing/en
#     Saved (590 chars, 26 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 130 docs saved, 134 visited, 453 in queue
#  [2] https://www.primelands.lk/apartment/ongoing/city/Galle/en
#     Saved (592 chars, 21 links found)
#     Added 5 new URLs to queue (depth 3)
#    Progress: 131 docs saved, 135 visited, 457 in queue
#  [2] https://www.primelands.lk/apartment/ongoing/city/Negombo/en
#     Saved (616 chars, 26 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 132 docs saved, 136 visited, 458 in queue
#  [2] https://www.primelands.lk/apartment/ongoing/city/Thalawathugoda/en
#     Saved (630 chars, 26 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 133 docs saved, 137 visited, 459 in queue
#  [2] https://www.primelands.lk/apartment/ongoing/district/Colombo/en
#     Saved (624 chars, 26 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 134 docs saved, 138 visited, 460 in queue
#  [2] https://www.primelands.lk/apartment/ongoing/district/Gampaha/en
#     Saved (624 chars, 27 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 135 docs saved, 139 visited, 461 in queue
#  [2] https://www.primelands.lk/apartment/ongoing/city/Colombo/en
#     Saved (616 chars, 26 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 136 docs saved, 140 visited, 462 in queue
#  [2] https://www.primelands.lk/land/GREEN-HIDE-YAKKALA/en
#     Saved (602 chars, 12 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 137 docs saved, 141 visited, 459 in queue
#  [2] https://www.primelands.lk/land/LUANA-KADAWATHA/en
#     Saved (596 chars, 14 links found)
#     Added 5 new URLs to queue (depth 3)
#    Progress: 138 docs saved, 142 visited, 463 in queue
#  [2] https://www.primelands.lk/land/CALLISTO-KADAWATHA/en
#     Saved (602 chars, 12 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 139 docs saved, 143 visited, 464 in queue
#  [2] https://www.primelands.lk/land/GAMPAHA-THE-SEQUOR/en
#     Saved (602 chars, 12 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 140 docs saved, 144 visited, 465 in queue
#  [2] https://www.primelands.lk/land/AVENLY-KADAWATHA/en
#     Saved (598 chars, 13 links found)
#     Added 3 new URLs to queue (depth 3)
#    Progress: 141 docs saved, 145 visited, 466 in queue
#  [2] https://www.primelands.lk/news/90/Prime-Groups-Legacy-in-Real-Estate-Featured-in-Kotlers-Essential-of-Modern-Marketing/en
#     Saved (740 chars, 18 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 142 docs saved, 146 visited, 461 in queue
#  [2] https://www.primelands.lk/news/88/Prime-Group-appoints-international-music-icon-Umaria-Sinhawansa-as-Global-Brand-Ambassador/en
#     Saved (752 chars, 18 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 143 docs saved, 147 visited, 461 in queue
#  [2] https://www.primelands.lk/news/91/Prime-Group-launches-Prime-Edge-as-Sri-Lankas-first-all-in-one-real-estate-mobile-app/en
#     Saved (742 chars, 18 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 144 docs saved, 148 visited, 461 in queue
#  [2] https://www.primelands.lk/news/86/Prime-Group-unveils-innovative-Public-Private-collaboration-initiative-to-enhance-Government-service-excellence/en
#     Saved (794 chars, 18 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 145 docs saved, 149 visited, 462 in queue
#  [2] https://www.primelands.lk/news/87/Prime-Lands-Recognized-as-Most-Innovative-Property-Developer-Sri-Lanka-2025-by-World-Economic-Magazine-Awards-USA/en
#     Saved (798 chars, 18 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 146 docs saved, 150 visited, 463 in queue
#  [2] https://www.primelands.lk/news/89/Marking-a-Historic-Milestone-Prime-Group-and-FSLGA-seal-public-private-synergy-to-elevate-Local-Government-capacity-nationwide/en
#     Saved (824 chars, 18 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 147 docs saved, 151 visited, 464 in queue
#  [2] https://www.primelands.lk/news/5/BEST-REAL-ESTATE-COMPANY/en
#     Saved (618 chars, 18 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 148 docs saved, 152 visited, 459 in queue
#  [2] https://www.primelands.lk/news/79/Prime-Group-crowned-with-prestigious-Sri-Lanka-Best-Employer-Brand-Award-2024/en
#     Saved (726 chars, 18 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 149 docs saved, 153 visited, 460 in queue
#  [2] https://www.primelands.lk/news/15/WOMAN-SUPER-ACHIEVER-OF-THE-YEAR-UNDER-REAL-ESTATE-SECTOR/en
#     Saved (686 chars, 18 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 150 docs saved, 154 visited, 461 in queue
#  [2] https://www.primelands.lk/news/80/Prime-Lands-recognised-for-excellence-on-global-stage-with-double-wins-at-World-Business-Outlook-Awards 2024/en
#     Saved (788 chars, 19 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 151 docs saved, 155 visited, 462 in queue
#  [2] https://www.primelands.lk/news/64/Prime-Wins-Gold-in-Land-and-Property-Sector-at-TAGS-Awards-2022/en
#     Saved (698 chars, 18 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 152 docs saved, 156 visited, 462 in queue
#  [2] https://www.primelands.lk/news/76/Prime-Group-Relocates-Galle-Branch-to-Elevate-Customer-Experience-and-Reinforce-Commitment-to-Excellence/en
#     Saved (780 chars, 18 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 153 docs saved, 157 visited, 463 in queue
#  [2] https://www.primelands.lk/news/16/GREAT-PLACE-TO-WORK-2018/en
#     Saved (620 chars, 18 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 154 docs saved, 158 visited, 463 in queue
#  [2] https://www.primelands.lk/news/18/PRIME-GROUP-CROWNED-BEST-DEVELOPER-IN-SRI-LANKA-YET-AGAIN/en
#     Saved (686 chars, 18 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 155 docs saved, 159 visited, 464 in queue
#  [2] https://www.primelands.lk/news/21/PRIME-GROUPS-WEBSITE-CROWNED-AS-THE-BEST-CORPORATE-WEBSITE/en
#     Saved (688 chars, 18 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 156 docs saved, 160 visited, 465 in queue
#  [2] https://www.primelands.lk/news/12/GREAT-PLACE-TO-WORK-IN-SRI-LANKA-FOR-2017/en
#     Saved (654 chars, 18 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 157 docs saved, 161 visited, 466 in queue
#  [2] https://www.primelands.lk/news/68/Prime-Group-Completes-its-Latest-Masterpiece-The-Grand-Ward-Place-a-Triumph-of-Sri-Lankan-Excellence/en
#     Saved (772 chars, 18 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 158 docs saved, 162 visited, 467 in queue
#  [2] https://www.primelands.lk/news/57/Prime-Group-Crowned-Most-Valuable-Real-Estate-Consumer-Brand-in-Sri-Lanka/en
#     Saved (718 chars, 18 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 159 docs saved, 163 visited, 468 in queue
#  [2] https://www.primelands.lk/news/8/GREAT-PLACE-TO-WORK-IN-SRI-LANKA-FOR-2016/en
#     Saved (652 chars, 18 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 160 docs saved, 164 visited, 469 in queue
#  [2] https://www.primelands.lk/news/55/Prime-Group-Strengthen-The-Financial-Stability-to-SL-A-Stable/en
#     Saved (694 chars, 18 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 161 docs saved, 165 visited, 470 in queue
#  [2] https://www.primelands.lk/news/17/BEST-DEVELOPER-OF-SRI-LANKA-2018/en
#     Saved (636 chars, 18 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 162 docs saved, 166 visited, 471 in queue
#  [2] https://www.primelands.lk/news/60/Prime-Group-Listed-Among-Asias-100-Best-Workplaces-in-the-SME-Category-for-2022-by-Great-Place-to-Work992/en
#     Saved (782 chars, 18 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 163 docs saved, 167 visited, 472 in queue
#  [2] https://www.primelands.lk/news/24/ACEF-GLOBAL-CUSTOMER-ENGAGEMENT-AWARDS/en
#     Saved (648 chars, 18 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 164 docs saved, 168 visited, 473 in queue
#  [2] https://www.primelands.lk/news/61/Prime-Group-Wins-Two-Gold-Awards-for-Customer-Engagement/en
#     Saved (684 chars, 18 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 165 docs saved, 169 visited, 474 in queue
#  [2] https://www.primelands.lk/news/4/WCRC-LEADERS-ASIA-WE-AWARD---2014/en
#     Saved (636 chars, 18 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 166 docs saved, 170 visited, 475 in queue
#  [2] https://www.primelands.lk/news/70/Prime-Lands-clinches-coveted-Gold-Award-for-elevated-online-presence-at-13th-BestWeblk-2023-Competition-for-02nd-Time/en
#     Saved (806 chars, 19 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 167 docs saved, 171 visited, 476 in queue
#  [2] https://www.primelands.lk/news/69/Prime-Group-to-soon-complete-the-only-Lifestyle-Apartment-Complex-in-Gampaha/en
#     Saved (724 chars, 18 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 168 docs saved, 172 visited, 477 in queue
#  [2] https://www.primelands.lk/land/BANDARAGAMA-GREEN-PARADISE/en
#     Saved (618 chars, 22 links found)
#     Added 6 new URLs to queue (depth 3)
#    Progress: 169 docs saved, 173 visited, 478 in queue
#  [2] https://www.primelands.lk/land/TEAL-KUMBUKA/en
#     Saved (590 chars, 11 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 170 docs saved, 174 visited, 478 in queue
#  [2] https://www.primelands.lk/apartment/THE-COLOMBO-BORDER-PELIYAGODA/en
#     Saved (634 chars, 11 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 171 docs saved, 175 visited, 472 in queue
#  [2] https://www.primelands.lk/land/DELTOTA-MISTY-MOUNTAIN/en
#     Saved (610 chars, 16 links found)
#     Added 7 new URLs to queue (depth 3)
#    Progress: 172 docs saved, 176 visited, 476 in queue
#  [2] https://www.primelands.lk/land/CELESTIA-PILIMATHALAWA/en
#     Saved (610 chars, 11 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 173 docs saved, 177 visited, 477 in queue
#  [2] https://www.primelands.lk/land/LA-SIERRA-HADENIYA/en
#     Saved (602 chars, 13 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 174 docs saved, 178 visited, 478 in queue
#  [2] https://www.primelands.lk/land/NILLAMBA-SATURDAY/en
#     Saved (600 chars, 18 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 175 docs saved, 179 visited, 478 in queue
#  [2] https://www.primelands.lk/land/MOUNT-GATE-MADANA/en
#     Saved (600 chars, 11 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 176 docs saved, 180 visited, 479 in queue
#  [2] https://www.primelands.lk/land/PRIME-EXPRESS-FIVE-MATTEGODA/en
#     Saved (622 chars, 13 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 177 docs saved, 181 visited, 461 in queue
#  [2] https://www.primelands.lk/land/ROOTS-THALAWATHUGODA/en
#     Saved (606 chars, 12 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 178 docs saved, 182 visited, 460 in queue
#  [2] https://www.primelands.lk/land/ZEAL-MALABE/en
#     Saved (588 chars, 8 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 179 docs saved, 183 visited, 461 in queue
#  [2] https://www.primelands.lk/land/AURORA-HOMAGAMA/en
#     Saved (596 chars, 13 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 180 docs saved, 184 visited, 461 in queue
#  [2] https://www.primelands.lk/land/LUSH-DALE-HOMAGAMA/en
#     Saved (602 chars, 14 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 181 docs saved, 185 visited, 462 in queue
#  [2] https://www.primelands.lk/land/FRUITS-BURY-ARTIGALA/en
#     Saved (606 chars, 12 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 182 docs saved, 186 visited, 462 in queue
#  [2] https://www.primelands.lk/land/ELENI-HOMAGAMA/en
#     Saved (594 chars, 45 links found)
#     Added 10 new URLs to queue (depth 3)
#    Progress: 183 docs saved, 187 visited, 471 in queue
#  [2] https://www.primelands.lk/land/VELASIS-HOMAGAMA/en
#     Saved (598 chars, 12 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 184 docs saved, 188 visited, 472 in queue
#  [2] https://www.primelands.lk/land/GREEN-EMBAZY-HOMAGAMA/en
#     Saved (608 chars, 12 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 185 docs saved, 189 visited, 473 in queue
#  [2] https://www.primelands.lk/land/HIGH-POINT-HOMAGAMA/en
#     Saved (604 chars, 11 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 186 docs saved, 190 visited, 469 in queue
#  [2] https://www.primelands.lk/land/ABODE-POINT-KAHATHUDUWA/en
#     Saved (612 chars, 15 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 187 docs saved, 191 visited, 469 in queue
#  [2] https://www.primelands.lk/portfolio-property/city/Anuradhapura/en
#     Saved (628 chars, 41 links found)
#     Added 3 new URLs to queue (depth 3)
#    Progress: 188 docs saved, 192 visited, 470 in queue
#  [2] https://www.primelands.lk/portfolio-property/city/Kalutara/en
#     Saved (620 chars, 41 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 189 docs saved, 193 visited, 471 in queue
#  [2] https://www.primelands.lk/portfolio-property/close-to-railway-stations/en
#     Saved (644 chars, 40 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 190 docs saved, 194 visited, 472 in queue
#  [2] https://www.primelands.lk/portfolio-property/city/Aluthgama/en
#     Saved (622 chars, 41 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 191 docs saved, 195 visited, 473 in queue
#  [2] https://www.primelands.lk/portfolio-property/mountain-view/en
#     Saved (620 chars, 41 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 192 docs saved, 196 visited, 474 in queue
#  [2] https://www.primelands.lk/portfolio-property/district/Colombo/en
#     Saved (626 chars, 43 links found)
#     Added 5 new URLs to queue (depth 3)
#    Progress: 193 docs saved, 197 visited, 478 in queue
#  [2] https://www.primelands.lk/portfolio-property/district/Anuradhapura/en
#     Saved (636 chars, 41 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 194 docs saved, 198 visited, 479 in queue
#  [2] https://www.primelands.lk/portfolio-property/paddy-field-facing-lands/en
#     Saved (642 chars, 40 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 195 docs saved, 199 visited, 480 in queue
#  [2] https://www.primelands.lk/portfolio-property/down-south-lands/en
#     Saved (626 chars, 42 links found)
#     Added 3 new URLs to queue (depth 3)
#    Progress: 196 docs saved, 200 visited, 482 in queue
#  [2] https://www.primelands.lk/portfolio-property/city/Colombo/en
#     Saved (618 chars, 41 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 197 docs saved, 201 visited, 483 in queue
#  [2] https://www.primelands.lk/portfolio-property/district/Nuwara-Eliya/en
#     Saved (636 chars, 41 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 198 docs saved, 202 visited, 484 in queue
#  [2] https://www.primelands.lk/portfolio-property/city/Negombo/en
#     Saved (618 chars, 41 links found)
#     Added 3 new URLs to queue (depth 3)
#    Progress: 199 docs saved, 203 visited, 486 in queue
#  [2] https://www.primelands.lk/portfolio-property/district/Gampaha/en
#     Saved (626 chars, 41 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 200 docs saved, 204 visited, 487 in queue
#  [2] https://www.primelands.lk/portfolio-property/district/Matara/en
#     Saved (624 chars, 41 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 201 docs saved, 205 visited, 488 in queue
#  [2] https://www.primelands.lk/portfolio-property/residential/en
#     Saved (616 chars, 46 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 202 docs saved, 206 visited, 489 in queue
#  [2] https://www.primelands.lk/portfolio-property/land/en
#     Saved (602 chars, 46 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 203 docs saved, 207 visited, 490 in queue
#  [2] https://www.primelands.lk/portfolio-property/waterfront-land/en
#     Saved (624 chars, 40 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 204 docs saved, 208 visited, 491 in queue
#  [2] https://www.primelands.lk/portfolio-property/close-to-Airport/en
#     Saved (626 chars, 40 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 205 docs saved, 209 visited, 492 in queue
#  [2] https://www.primelands.lk/portfolio-property/district/Kalutara/en
#     Saved (628 chars, 42 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 206 docs saved, 210 visited, 493 in queue
#  [2] https://www.primelands.lk/portfolio-property/close-to-highways/en
#     Saved (628 chars, 42 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 207 docs saved, 211 visited, 494 in queue
#  [2] https://www.primelands.lk/portfolio-property/city/Galle/en
#     Saved (614 chars, 42 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 208 docs saved, 212 visited, 494 in queue
#  [2] https://www.primelands.lk/portfolio-property/city/Kaduwela-/en
#     Saved (622 chars, 41 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 209 docs saved, 213 visited, 495 in queue
#  [2] https://www.primelands.lk/portfolio-property/coconut-land/en
#     Saved (618 chars, 40 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 210 docs saved, 214 visited, 496 in queue
#  [2] https://www.primelands.lk/portfolio-property/city/Wariyapola/en
#     Saved (624 chars, 41 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 211 docs saved, 215 visited, 497 in queue
#  [2] https://www.primelands.lk/portfolio-property/city/Weligama/en
#     Saved (620 chars, 41 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 212 docs saved, 216 visited, 498 in queue
#  [2] https://www.primelands.lk/portfolio-property/up-country-lands/en
#     Saved (626 chars, 41 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 213 docs saved, 217 visited, 499 in queue
#  [2] https://www.primelands.lk/portfolio-property/district/Galle/en
#     Saved (622 chars, 42 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 214 docs saved, 218 visited, 500 in queue
#  [2] https://www.primelands.lk/portfolio-property/commercial/en
#     Saved (614 chars, 44 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 215 docs saved, 219 visited, 501 in queue
#  [2] https://www.primelands.lk/portfolio-property/district/Kurunegala/en
#     Saved (632 chars, 41 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 216 docs saved, 220 visited, 502 in queue
#  [2] https://www.primelands.lk/portfolio-property/city/Homagama/en
#     Saved (620 chars, 41 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 217 docs saved, 221 visited, 503 in queue
#  [2] https://www.primelands.lk/portfolio-property/city/Nuwara-Eliya/en
#     Saved (628 chars, 41 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 218 docs saved, 222 visited, 504 in queue
#  [2] https://www.primelands.lk/portfolio-property/close-to-ancient-city-lands/en
#     Saved (648 chars, 41 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 219 docs saved, 223 visited, 505 in queue
#  [2] https://www.primelands.lk/portfolio-property/agriculture-land/en
#     Saved (626 chars, 40 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 220 docs saved, 224 visited, 506 in queue
#  [2] https://www.primelands.lk/land/KALUTARA-NAGODA-NOVA/en
#     Saved (606 chars, 22 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 221 docs saved, 225 visited, 503 in queue
#  [2] https://www.primelands.lk/land/LILIUM-KALUTARA/en
#     Saved (596 chars, 13 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 222 docs saved, 226 visited, 504 in queue
#  [2] https://www.primelands.lk/land/ALUTHGAMA-REGAL-CITY/en
#     Saved (606 chars, 12 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 223 docs saved, 227 visited, 504 in queue
#  [2] https://www.primelands.lk/land/GREEN-HUB-KALUTARA/en
#     Saved (602 chars, 12 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 224 docs saved, 228 visited, 505 in queue
#  [2] https://www.primelands.lk/land/CITY-GLAZE-MINUWANGODA/en
#     Saved (610 chars, 14 links found)
#     Added 4 new URLs to queue (depth 3)
#    Progress: 225 docs saved, 229 visited, 503 in queue
#  [2] https://www.primelands.lk/land/ETERNITY-MINUWANGODA/en
#     Saved (606 chars, 12 links found)
#     Added 3 new URLs to queue (depth 3)
#    Progress: 226 docs saved, 230 visited, 505 in queue
#  [2] https://www.primelands.lk/land/FELICITY-MINUWANGODA/en
#     Saved (606 chars, 12 links found)
#     Added 3 new URLs to queue (depth 3)
#    Progress: 227 docs saved, 231 visited, 506 in queue
#  [2] https://www.primelands.lk/land/SUPREME-MINUWANGODA/en
#     Saved (604 chars, 8 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 228 docs saved, 232 visited, 507 in queue
#  [2] https://www.primelands.lk/land/SOUL-CITY-ANURADHAPURA/en
#     Saved (610 chars, 11 links found)
#     Added 3 new URLs to queue (depth 3)
#    Progress: 229 docs saved, 233 visited, 506 in queue
#  [2] https://www.primelands.lk/land/URBAN-POINT-VEYANGODA/en
#     Saved (608 chars, 13 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 230 docs saved, 234 visited, 507 in queue
#  [2] https://www.primelands.lk/land/WELIHINDA-AVERY/en
#     Saved (596 chars, 12 links found)
#     Added 3 new URLs to queue (depth 3)
#    Progress: 231 docs saved, 235 visited, 509 in queue
#  [2] https://www.primelands.lk/land/MAGNETISM-WELIGAMA/en
#     Saved (602 chars, 8 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 232 docs saved, 236 visited, 510 in queue
#  [2] https://www.primelands.lk/land/MATARA-THE-KINGDOM/en
#     Saved (602 chars, 10 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 233 docs saved, 237 visited, 511 in queue
#  [2] https://www.primelands.lk/land/SHINE-VALLEY-DIKWELLA/en
#     Saved (608 chars, 8 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 234 docs saved, 238 visited, 512 in queue
#  [2] https://www.primelands.lk/land/LAKE-FRONT-MAKAVITA/en
#     Saved (604 chars, 8 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 235 docs saved, 239 visited, 513 in queue
#  [2] https://www.primelands.lk/land/SUNREACH-MATARA/en
#     Saved (596 chars, 10 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 236 docs saved, 240 visited, 513 in queue
#  [2] https://www.primelands.lk/land/SUNBAY-MATARA/en
#     Saved (592 chars, 12 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 237 docs saved, 241 visited, 514 in queue
#  [2] https://www.primelands.lk/land/PRIME-NEST-KAHATHUDUWA/en
#     Saved (610 chars, 11 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 238 docs saved, 242 visited, 513 in queue
#  [2] https://www.primelands.lk/land/OREN-KAHATHUDUWA/en
#     Saved (598 chars, 12 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 239 docs saved, 243 visited, 513 in queue
#  [2] https://www.primelands.lk/land/URBAN-PLANET-KOTTAWA/en
#     Saved (606 chars, 11 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 240 docs saved, 244 visited, 514 in queue
#  [2] https://www.primelands.lk/land/LUSH-LAND-KOTTAWA/en
#     Saved (600 chars, 11 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 241 docs saved, 245 visited, 514 in queue
# ...
#    Progress: 329 docs saved, 333 visited, 552 in queue
#  [2] https://www.primelands.lk/land/PRIME-FIELD-BREEZE/en
#     Saved (602 chars, 11 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 330 docs saved, 334 visited, 553 in queue
#  [2] https://www.primelands.lk/land/THALAWATHUGODA-PRIME-OSBORNE-PARK/en
#     Saved (632 chars, 43 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 331 docs saved, 335 visited, 553 in queue
#  [2] https://www.primelands.lk/land/NIFTY-THALAWATHUGODA/en
#     Saved (606 chars, 41 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 332 docs saved, 336 visited, 554 in queue
#  [2] https://www.primelands.lk/land/NUWARAELIYA-THE-RIPPLES/en
#     Saved (612 chars, 10 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 333 docs saved, 337 visited, 552 in queue
#  [2] https://www.primelands.lk/land/NUWARAELIYA-BLACKPOOL/en
#     Saved (608 chars, 12 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 334 docs saved, 338 visited, 551 in queue
#  [2] https://www.primelands.lk/land/KURUNEGALA-WEHERA/en
#     Saved (600 chars, 12 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 335 docs saved, 339 visited, 552 in queue
#  [2] https://www.primelands.lk/land/KURUNEGALA-YOKE/en
#     Saved (596 chars, 17 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 336 docs saved, 340 visited, 553 in queue
#  [2] https://www.primelands.lk/land/3RD-LANE-KURUNEGALA/en
#     Saved (604 chars, 14 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 337 docs saved, 341 visited, 554 in queue
#  [2] https://www.primelands.lk/land/WOODLAND-ESTATE-IV-KURUNEGALA/en
#     Saved (624 chars, 12 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 338 docs saved, 342 visited, 553 in queue
#  [2] https://www.primelands.lk/land/PRIME-KESHARA-ADAWIYA/en
#     Saved (608 chars, 13 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 339 docs saved, 343 visited, 554 in queue
#  [2] https://www.primelands.lk/land/APOLLO-PANADURA/en
#     Saved (596 chars, 11 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 340 docs saved, 344 visited, 553 in queue
#  [2] https://www.primelands.lk/land/VESPER-PANADURA/en
#     Saved (596 chars, 14 links found)
#     Added 3 new URLs to queue (depth 3)
#    Progress: 341 docs saved, 345 visited, 555 in queue
#  [2] https://www.primelands.lk/land/AUTUMN-LUSTER-PANADURA/en
#     Saved (610 chars, 11 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 342 docs saved, 346 visited, 555 in queue
#  [2] https://www.primelands.lk/land/THE-LAGOON-KATUNAYAKE/en
#     Saved (608 chars, 51 links found)
#     Added 6 new URLs to queue (depth 3)
#    Progress: 343 docs saved, 347 visited, 559 in queue
#  [2] https://www.primelands.lk/land/PARADISE-AVENUE-NEGOMBO/en
#     Saved (612 chars, 15 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 344 docs saved, 348 visited, 559 in queue
#  [2] https://www.primelands.lk/land/NEGOMBO-CITY-BASE/en
#     Saved (600 chars, 16 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 345 docs saved, 349 visited, 560 in queue
#  [2] https://www.primelands.lk/land/PRIME-ORIGIN-II-NEGOMBO/en
#     Saved (612 chars, 14 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 346 docs saved, 350 visited, 561 in queue
#  [2] https://www.primelands.lk/land/PRIME-ORIGIN/en
#     Saved (590 chars, 9 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 347 docs saved, 351 visited, 562 in queue
#  [2] https://www.primelands.lk/land/MAJESTINO-MORATUWA/en
#     Saved (602 chars, 11 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 348 docs saved, 352 visited, 559 in queue
#  [2] https://www.primelands.lk/land/WINTER-STORY-KANDAPOLA/en
#     Saved (610 chars, 9 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 349 docs saved, 353 visited, 555 in queue
#  [2] https://www.primelands.lk/land/LAVISH-GARDEN/en
#     Saved (592 chars, 12 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 350 docs saved, 354 visited, 554 in queue
#  [2] https://www.primelands.lk/house/PRIME-EVOKE/en
#     Saved (590 chars, 11 links found)
#     Added 3 new URLs to queue (depth 3)
#    Progress: 351 docs saved, 355 visited, 552 in queue
#  [2] https://www.primelands.lk/house/PRIME-LIFE-KADAWATHA/en
#     Saved (608 chars, 10 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 352 docs saved, 356 visited, 553 in queue
#  [2] https://www.primelands.lk/house/MAGNA-MATTEGODA/en
#     Saved (598 chars, 11 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 353 docs saved, 357 visited, 546 in queue
#  [2] https://www.primelands.lk/house/KOTTAWA-PRIME-URBAN-ART/en
#     Saved (614 chars, 13 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 354 docs saved, 358 visited, 547 in queue
#  [2] https://www.primelands.lk/house/PRIME-VILLAS-NUGEGODA/en
#     Saved (610 chars, 12 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 355 docs saved, 359 visited, 546 in queue
#  [2] https://www.primelands.lk/house/WATER-ESTATE-MORATUWA/en
#     Saved (610 chars, 12 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 356 docs saved, 360 visited, 542 in queue
#  [2] https://www.primelands.lk/house/PRIME-VILLAS-THALAWATHUGODA-WEERA-MAWATHA/en
#     Saved (650 chars, 16 links found)
#     Added 2 new URLs to queue (depth 3)
#    Progress: 357 docs saved, 361 visited, 535 in queue
#  [3] https://www.primelands.lk/apartment/ONE-TANGALLE-TANGALLE/en
#     Saved (618 chars, 13 links found)
#    Progress: 358 docs saved, 362 visited, 523 in queue
#  [3] https://www.primelands.lk/apartment/complete/city/Gampaha/en
#     Saved (618 chars, 20 links found)
#    Progress: 359 docs saved, 363 visited, 520 in queue
#  [3] https://www.primelands.lk/apartment/complete/district/Gampaha/en
#     Saved (626 chars, 20 links found)
#    Progress: 360 docs saved, 364 visited, 518 in queue
#  [3] https://www.primelands.lk/apartment/complete/en
#     Saved (592 chars, 20 links found)
#    Progress: 361 docs saved, 365 visited, 516 in queue
#  [3] https://www.primelands.lk/land/GLIMMER-WARAGODA/en
#     Saved (598 chars, 16 links found)
#    Progress: 362 docs saved, 366 visited, 502 in queue
#  [3] https://www.primelands.lk/land/BROAD-CITY-KADAWATHA/en
#     Saved (606 chars, 8 links found)
#    Progress: 363 docs saved, 367 visited, 500 in queue
#  [3] https://www.primelands.lk/land/CAPITAL-POINT-GAMPAHA/en
#     Saved (608 chars, 11 links found)
#    Progress: 364 docs saved, 368 visited, 499 in queue
#  [3] https://www.primelands.lk/land/CENNET-MIRISWATTA/en
#     Saved (600 chars, 14 links found)
#    Progress: 365 docs saved, 369 visited, 494 in queue
#  [3] https://www.primelands.lk/land/TOWN-GROVE-BANDARAGAMA/en
#     Saved (610 chars, 12 links found)
#    Progress: 366 docs saved, 370 visited, 437 in queue
#  [3] https://www.primelands.lk/land/PRIME-CITY-AXIS-HORANA/en
#     Saved (610 chars, 10 links found)
#    Progress: 367 docs saved, 371 visited, 436 in queue
#  [3] https://www.primelands.lk/land/GREEN-CLASSIC-WADDUWA/en
#     Saved (608 chars, 12 links found)
#    Progress: 368 docs saved, 372 visited, 435 in queue
#  [3] https://www.primelands.lk/land/PRIME-EVERNEST-HORANA/en
#     Saved (608 chars, 11 links found)
#    Progress: 369 docs saved, 373 visited, 434 in queue
#  [3] https://www.primelands.lk/land/RIVER-EDGE-POLGAHAWELA/en
#     Saved (610 chars, 8 links found)
#    Progress: 370 docs saved, 374 visited, 427 in queue
#  [3] https://www.primelands.lk/land/PRIME-DELTA-ESTATE-PUSELLAWA/en
#     Saved (622 chars, 11 links found)
#    Progress: 371 docs saved, 375 visited, 426 in queue
#  [3] https://www.primelands.lk/land/PRIME-ROYAL-TERRACE-KANDY/en
#     Saved (616 chars, 12 links found)
#    Progress: 372 docs saved, 376 visited, 423 in queue
#  [3] https://www.primelands.lk/land/PRIME-UP-TOWN-PERADENIYA/en
#     Saved (614 chars, 11 links found)
#    Progress: 373 docs saved, 377 visited, 422 in queue
#  [3] https://www.primelands.lk/land/REGENCY-HEIGHTS-KANDY/en
#     Saved (608 chars, 12 links found)
#    Progress: 374 docs saved, 378 visited, 421 in queue
#  [3] https://www.primelands.lk/land/SPARKLE-MEEPE/en
#     Saved (592 chars, 8 links found)
#    Progress: 375 docs saved, 379 visited, 400 in queue
#  [3] https://www.primelands.lk/land/LUXULIA-PANNIPITIYA/en
#     Saved (604 chars, 9 links found)
#    Progress: 376 docs saved, 380 visited, 399 in queue
#  [3] https://www.primelands.lk/land/NEST-BORALESGAMUWA/en
#     Saved (602 chars, 16 links found)
#    Progress: 377 docs saved, 381 visited, 398 in queue
#  [3] https://www.primelands.lk/land/LIGHT-OF-WISDOM-HOMAGAMA/en
#     Saved (614 chars, 8 links found)
#    Progress: 378 docs saved, 382 visited, 397 in queue
#  [3] https://www.primelands.lk/land/THE-BREATHE-HOMAGAMA/en
#     Saved (606 chars, 10 links found)
#    Progress: 379 docs saved, 383 visited, 396 in queue
#  [3] https://www.primelands.lk/land/ELINOR-BATTARAMULLA/en
#     Saved (604 chars, 12 links found)
#    Progress: 380 docs saved, 384 visited, 395 in queue
#  [3] https://www.primelands.lk/land/PRIME-SUPERIOR-PILIYANDALA/en
#     Saved (618 chars, 13 links found)
#    Progress: 381 docs saved, 385 visited, 393 in queue
#  [3] https://www.primelands.lk/land/AUROUS-HOMAGAMA/en
#     Saved (596 chars, 9 links found)
#    Progress: 382 docs saved, 386 visited, 391 in queue
#  [3] https://www.primelands.lk/portfolio-property/ANURADHAPURA-PALADIKULAMA/en
#     Saved (644 chars, 11 links found)
#    Progress: 383 docs saved, 387 visited, 382 in queue
#  [3] https://www.primelands.lk/portfolio-property/HOMAGAMA-KIRIWATHTHUDUWA/en
#     Saved (642 chars, 11 links found)
#    Progress: 384 docs saved, 388 visited, 370 in queue
#  [3] https://www.primelands.lk/portfolio-property/KADUWELA-WELIVITA/en
#     Saved (628 chars, 11 links found)
#    Progress: 385 docs saved, 389 visited, 368 in queue
#  [3] https://www.primelands.lk/portfolio-property/MAHARAGAMA-PASAL-MAWATHA/en
#     Saved (642 chars, 11 links found)
#    Progress: 386 docs saved, 390 visited, 367 in queue
#  [3] https://www.primelands.lk/portfolio-property/GALLE-KARAPITIYA/en
#     Saved (626 chars, 11 links found)
#    Progress: 387 docs saved, 391 visited, 360 in queue
#  [3] https://www.primelands.lk/portfolio-property/NEGOMBO-DUNGALPITIYA/en
#     Saved (634 chars, 11 links found)
#    Progress: 388 docs saved, 392 visited, 353 in queue
#  [3] https://www.primelands.lk/land/EXPRESS-CORRIDOR-KADAWATHA/en
#     Saved (618 chars, 15 links found)
#    Progress: 389 docs saved, 393 visited, 300 in queue
#  [3] https://www.primelands.lk/land/AMITY-DIVULAPITIYA/en
#     Saved (602 chars, 8 links found)
#    Progress: 390 docs saved, 394 visited, 299 in queue
#  [3] https://www.primelands.lk/land/EMERALD-BROOK-WATTALA/en
#     Saved (608 chars, 20 links found)
#    Progress: 391 docs saved, 395 visited, 298 in queue
#  [3] https://www.primelands.lk/land/PRIME-ZONE-5/en
#     Saved (590 chars, 13 links found)
#    Progress: 392 docs saved, 396 visited, 295 in queue
#  [3] https://www.primelands.lk/land/LAKE-SHORE-BULANKULAMA/en
#     Saved (610 chars, 12 links found)
#    Progress: 393 docs saved, 397 visited, 288 in queue
#  [3] https://www.primelands.lk/land/CITY-SPACE-KIRILLAWALA/en
#     Saved (610 chars, 14 links found)
#    Progress: 394 docs saved, 398 visited, 284 in queue
#  [3] https://www.primelands.lk/land/ARCADE-CITY-AMBALANGODA/en
#     Saved (612 chars, 15 links found)
#    Progress: 395 docs saved, 399 visited, 253 in queue
#  [3] https://www.primelands.lk/land/PRIME-VIEW-POINT-AMBALANGODA/en
#     Saved (622 chars, 14 links found)
#    Progress: 396 docs saved, 400 visited, 251 in queue
#  [3] https://www.primelands.lk/land/DIKKUMBURA-SOUTHBURY/en
#     Saved (606 chars, 17 links found)
#    Progress: 397 docs saved, 401 visited, 250 in queue
#  [3] https://www.primelands.lk/land/GLORIA-AHANGAMA/en
#     Saved (596 chars, 12 links found)
#    Progress: 398 docs saved, 402 visited, 249 in queue
#  [3] https://www.primelands.lk/land/PRIME-HOPE-KULIYAPITIYA/en
#     Saved (612 chars, 10 links found)
#    Progress: 399 docs saved, 403 visited, 238 in queue
#  [3] https://www.primelands.lk/land/PRIME-ASSEDDUMA-GOLDEN-HARVEST/en
#     Saved (626 chars, 10 links found)
#    Progress: 400 docs saved, 404 visited, 237 in queue
#  [3] https://www.primelands.lk/land/ISURUPURA-BOWATTA/en
#     Saved (600 chars, 8 links found)
#    Progress: 401 docs saved, 405 visited, 236 in queue
#  [3] https://www.primelands.lk/land/PRIME-RAN-VIMANA-KULIYAPITIYA/en
#     Saved (624 chars, 12 links found)
#    Progress: 402 docs saved, 406 visited, 233 in queue
#  [3] https://www.primelands.lk/land/PRIME-CENTER-POINT-HETTIPOLA/en
#     Saved (622 chars, 11 links found)
#    Progress: 403 docs saved, 407 visited, 232 in queue
#  [3] https://www.primelands.lk/land/PRIME-NORTH-LAKE-ANURADHAPURA/en
#     Saved (624 chars, 10 links found)
#    Progress: 404 docs saved, 408 visited, 218 in queue
#  [3] https://www.primelands.lk/land/FUTURE-KINGDOM-MADAWACHCHIYA/en
#     Saved (622 chars, 10 links found)
#    Progress: 405 docs saved, 409 visited, 216 in queue
#  [3] https://www.primelands.lk/land/PRIME-ROYAL-TERRACE-ANURADHAPURA/en
#     Saved (630 chars, 9 links found)
#    Progress: 406 docs saved, 410 visited, 213 in queue
#  [3] https://www.primelands.lk/land/ADDERSFIELD-ANURADHAPURA/en
#     Saved (614 chars, 12 links found)
#    Progress: 407 docs saved, 411 visited, 212 in queue
#  [3] https://www.primelands.lk/land/PRIME-LAKE-VIEW-ANURADHAPURA/en
#     Saved (622 chars, 11 links found)
#    Progress: 408 docs saved, 412 visited, 211 in queue
#  [3] https://www.primelands.lk/land/PREMIER-KADAWATHA/en
#     Saved (600 chars, 13 links found)
#    Progress: 409 docs saved, 413 visited, 208 in queue
#  [3] https://www.primelands.lk/land/PRIME-ARUNALU-DIVULAPITIYA/en
#     Saved (618 chars, 11 links found)
#    Progress: 410 docs saved, 414 visited, 206 in queue
#  [3] https://www.primelands.lk/land/PRIME-ATRIUM-KADAWATHA/en
#     Saved (610 chars, 10 links found)
#    Progress: 411 docs saved, 415 visited, 204 in queue
#  [3] https://www.primelands.lk/land/360-AVENUE-KADAWATHA/en
#     Saved (606 chars, 18 links found)
#    Progress: 412 docs saved, 416 visited, 199 in queue
#  [3] https://www.primelands.lk/land/EMINENT-PLACE-KELANIYA/en
#     Saved (610 chars, 10 links found)
#    Progress: 413 docs saved, 417 visited, 186 in queue
#  [3] https://www.primelands.lk/land/PRIME-KINGS-BOULEVARD-ANURADHAPURA/en
#     Saved (634 chars, 17 links found)
#    Progress: 414 docs saved, 418 visited, 182 in queue
#  [3] https://www.primelands.lk/land/PRIME-GREEN-GROW-MILIDDUWA/en
#     Saved (618 chars, 8 links found)
#    Progress: 415 docs saved, 419 visited, 169 in queue
#  [3] https://www.primelands.lk/land/7TH-HEAVEN-GALLE/en
#     Saved (598 chars, 10 links found)
#    Progress: 416 docs saved, 420 visited, 164 in queue
#  [3] https://www.primelands.lk/land/PRIME-LIFE-2/en
#     Saved (590 chars, 14 links found)
#    Progress: 417 docs saved, 421 visited, 114 in queue
#  [3] https://www.primelands.lk/land/BIG-CITY-WEWALDENIYA/en
#     Saved (606 chars, 10 links found)
#    Progress: 418 docs saved, 422 visited, 75 in queue
#  [3] https://www.primelands.lk/land/PRIME-RANKETHA-II-WELIWERIYA/en
#     Saved (622 chars, 9 links found)
#    Progress: 419 docs saved, 423 visited, 74 in queue
#  [3] https://www.primelands.lk/land/ARUNODAYA-BANDARAGAMA/en
#     Saved (608 chars, 25 links found)
#    Progress: 420 docs saved, 424 visited, 37 in queue
#  [3] https://www.primelands.lk/land/WATTALA-QUEENS-AVENUE-2/en
#     Saved (612 chars, 17 links found)
#    Progress: 421 docs saved, 425 visited, 33 in queue
#  [3] https://www.primelands.lk/land/NITTAMBUWA-IMPERIUM/en
#     Saved (604 chars, 15 links found)
#    Progress: 422 docs saved, 426 visited, 32 in queue
#  [3] https://www.primelands.lk/land/PREMIER-RADDOLUGAMA/en
#     Saved (604 chars, 17 links found)
#    Progress: 423 docs saved, 427 visited, 31 in queue
#  [3] https://www.primelands.lk/land/CAZELLE-WATTALA/en
#     Saved (596 chars, 17 links found)
#    Progress: 424 docs saved, 428 visited, 29 in queue
#
#  Crawl complete in 3227.1s
#  Documents collected: 424
#  URLs visited: 428

# %% [markdown]
# ### Save Outputs

# %%
# Save markdown files
for i, doc in enumerate(documents):
    url_path = urlparse(doc['url']).path.strip('/').replace('/', '_')
    if not url_path:
        url_path = "homepage"
    filename = f"{i:03d}_{url_path}.md"
    
    md_file = MARKDOWN_DIR / filename
    with open(md_file, 'w', encoding='utf-8') as f:
        f.write(f"# {doc['title']}\n\n")
        f.write(f"**URL**: {doc['url']}\n\n")
        f.write(f"**Depth**: {doc['depth_level']}\n\n")
        f.write("---\n\n")
        f.write(doc['content'])

print(f" Saved {len(documents)} markdown files to {MARKDOWN_DIR}")

# Save JSONL
with open(JSONL_PATH, 'w', encoding='utf-8') as f:
    for doc in documents:
        f.write(json.dumps(doc, ensure_ascii=False) + '\n')

print(f" Saved JSONL corpus to {JSONL_PATH}")
# Out:
#  Saved 424 markdown files to c:\Development\real-estate-intelligence-platform\data\primelands_markdown
#  Saved JSONL corpus to c:\Development\real-estate-intelligence-platform\data\primelands_docs.jsonl

# %% [markdown]
# ### Quality Checks

# %%
import random

print(" Quality Checks:\n")

# Check markdown files
md_files = list(MARKDOWN_DIR.glob("*.md"))
print(f"1  Markdown files: {len(md_files)}")

if len(md_files) >= 20:
    print(f"    Good! Got {len(md_files)} pages")
elif len(md_files) >= 10:
    print(f"     Only {len(md_files)} pages (site may be small)")
else:
    raise AssertionError(f" Too few pages: {len(md_files)}")

# Check JSONL
assert JSONL_PATH.exists(), f" JSONL not found"
print(f"\n2  JSONL file: {JSONL_PATH.stat().st_size:,} bytes")

# Sample inspection
with open(JSONL_PATH, 'r', encoding='utf-8') as f:
    all_docs = [json.loads(line) for line in f]

samples = random.sample(all_docs, min(3, len(all_docs)))
print(f"\n3  Random samples:\n")

for i, doc in enumerate(samples, 1):
    print(f"   Sample {i}:")
    print(f"   - URL: {doc['url']}")
    print(f"   - Title: {doc['title']}")
    print(f"   - Words: {len(doc['content'].split())}")
    print()

print(" All quality checks passed!")
# Out:
#  Quality Checks:
#
# 1  Markdown files: 1125
#     Good! Got 1125 pages
#
# 2  JSONL file: 1,289,918 bytes
#
# 3  Random samples:
#
#    Sample 1:
#    - URL: https://www.primelands.lk/land/ZENGARY-MALABE/en
#    - Title: ZENGARY MALABE
#    - Words: 14
#
#    Sample 2:
#    - URL: https://www.primelands.lk/portfolio-property/close-to-Airport/en
#    - Title: Land Sales In Sri Lanka | Prime Lands
#    - Words: 14
#
#    Sample 3:
#    - URL: https://www.primelands.lk/house/DALUGAMA-PRIME-VILLAS/en
#    - Title: DALUGAMA - PRIME VILLAS
#    - Words: 14
#
#  All quality checks passed!
